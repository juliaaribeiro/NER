# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# ## Funções e Configurações

# %%
# this dictionary contains the configuration necessary to divide each dataset used in the work, the script is made
# for the conll type of datasets, so if you want to add datasets to divide, make sure to add it here
gen_config = {
    'leNER':{
        'base_dir': "../Base de Dados/leNER/",
        'load_dir': "documents/allDoc/",
        'save_dir': "divisions/iterative/",
        'col_sep' : ' ',
        'file_type': '.conll',
    },
    'UlyssesNER-BR':{
        'base_dir': "../Base de Dados/UlyssesNER-BR/",
        'load_dir': "PL_Corpus_byTypes_conll/",
        'save_dir': "divisions/iterative/",
        'col_sep' : ' ',
        'file_type': '.conll',
    },
    'Harem-second':{
        'base_dir': "../Base de Dados/HAREM/",
        'load_dir': "SecondHarem/",
        'save_dir': "divisions/second/iterative/",
        'col_sep' : '\t',
        'file_type': '.conll',
    }
}

# %%
def get_sentencas(corpus, coll_sep):
        sentenca = []
        for line in corpus:
            if line == '\n':
                if sentenca:
                    yield sentenca
                    sentenca = []
            else:
                
                sentenca.append(line.strip('\n').split(coll_sep))
        if sentenca:
            yield sentenca

# %%
def read_dataset(filepath,coll_sep):
    data_por_sentenca = []
    with open(filepath, "r") as corpus:
        data_por_sentenca += list(get_sentencas(corpus,coll_sep))
    
    return data_por_sentenca

# %%
def get_data(config, selective = False, fileName = ""):
    load_dir = config['base_dir'] + config['load_dir']
    sep = config['col_sep']
    if selective:
        fp = load_dir + fileName
        return read_dataset(filepath=fp, coll_sep=sep)
    else:
        filepaths = []
        for file in os.listdir(load_dir):
            if file.endswith(config['file_type']):
                filepaths.append(load_dir + file)
        
        data_por_sentenca = []
        for filepath in filepaths:
            print(filepath+"\n")
            data_por_sentenca += read_dataset(filepath=filepath, coll_sep=sep)
        
        return data_por_sentenca

# %%
def split_token_label(data):
    return list(map(list,zip(*data)))

# %% [markdown]
# ## Carregando DataSet e preparando dados

# %%
dataset = 'leNER'
# dataset = 'Paramopama'
# dataset = 'Harem-mini'
# dataset = 'Harem-second'
# dataset = 'UlyssesNER-BR'

config = gen_config[dataset]

filepaths = []

files = os.listdir(config['base_dir'] + config['load_dir'])
print(files)
for file in files:
    # if file.endswith('.conll'):
    filepaths.append(config['base_dir'] + config['load_dir'] + file)

# data_por_sentenca = get_data(config=config)

# data_por_sentenca = get_data(config=config, selective=True, fileName='corpus_Paramopama.txt')
# data_por_sentenca = get_data(config=config, selective=True, fileName='haremMini-total.colnn')
# data_por_sentenca = get_data(config=config, selective=True, fileName='primeiroHAREM-total.colnn')
data_por_sentenca_por_doc = {}
for filepath, file in zip(filepaths, files):
    data_por_sentenca_por_doc[file] = read_dataset(filepath, coll_sep=config['col_sep'])

total_documentos = len(data_por_sentenca_por_doc)
print("Total de documentos carregados:", total_documentos)
# Out:
# ['TSTRR16037920105200001.conll', 'RR942006420095040028.conll', 'AgCr10582160008758001.conll', 'HC04798525420128130000.conll', 'HC70000692720177000000.conll', 'Lei11788.conll', 'AgAIRR11889820145030011.conll', 'ADI1TJDFT.conll', 'AgRgTSE3.conll', 'AC10024133855890001.conll', 'AIAgRAgI6193ARAGUARIMG.conll', 'CP32320177080008PA.conll', 'AP771420167080008PA.conll', 'ERR731004520105130003.conll', 'HC418951PR.conll', 'TCU4687.conll', 'AP00001415620157010201.conll', 'AC1TJMG.conll', 'HC110260SP.conll', 'EDRR1TST.conll', 'Pet128TSE5.conll', 'ED1STM.conll', 'DespSEPLAGDF.conll', 'LoaDF2018.conll', '20150110436469APC.conll', 'ED1TJAC.conll', 'AgRg1STM.conll', 'RR2574407120025020372.conll', 'ACORDAOTCU25052016.conll', 'Agr10540170008341001.conll', 'AP00000794920137060006.conll', 'Rcl3495STJ.conll', 'AIRR581406820065030079.conll', 'AgRgTSE1.conll', 'EDEDARR208420135040232.conll', 'AIRR285001420095060020.conll', 'AgAIRR617420125150072.conll', 'Ag10105170208398001.conll', 'HC10000150589281000.conll', 'ADI2TJDFT.conll', 'AC1TJAC.conll', 'AC1TCU.conll', 'AC20150110436469APC.conll', 'EEDRR9715120105020002.conll', 'lei11340.conll', 'AgRgSTJ1.conll', 'Port77DF.conll', 'RR-578030-46.1999.5.04.0018.conll', 'APO1TJDFT.conll', 'ACORDAOTCU11602016.conll', 'AIRR15708820115050222.conll', 'HC340624SP.conll', 'AIRR10006691020135020322.conll', 'HC70000845920187000000.conll', 'AIRR3999520145020086.conll', 'REE5908TSE4.conll', 'AIRR3731820145060141.conll', 'INSTRUCAOON06043378120186000000.conll', 'REsp1583083RS.conll', 'HC10000170833503000.conll', 'RR14976020105020085.conll', 'Ag10000170733596001.conll', 'airr801422012.conll', 'ACO2821STF.conll', 'EDAgRgTSE2.conll', 'AP00001441420167030203.conll', 'AgRgSTJ2.conll', 'RR474820145230056.conll', 'HC151914AgRES.conll', 'adi3767.conll']
# Total de documentos carregados: 70

# %%
# data_por_sentenca_por_doc['HAREMdoc_aa64686'][0]
# len(data_por_sentenca_por_doc['HAREMdoc_aa64686'])
# data_por_sentenca_por_doc[list(data_por_sentenca_por_doc.keys())[0]]
# d = list(data_por_sentenca_por_doc.values())[0][10][-1]
# list(map(list,zip(d)))
# # d

# %%
from collections import Counter
labels_por_doc = {}

for docName, docData in data_por_sentenca_por_doc.items():
    allDocData = []
    
    for sentence in docData:
        allDocData += [i for i in sentence]
    
    docTokens, docLabels = split_token_label(allDocData)
    
    
    labels_por_doc[docName] = docLabels

    labels_count = Counter(docLabels)
    
    # Armazenar a contagem de rótulos para o documento atual
    labels_por_doc[docName] = dict(labels_count)

# Exibir as contagens de rótulos por documento
for doc, labels_count in labels_por_doc.items():
    print(f"Documento: {doc}")
    print("Contagem de rótulos:", labels_count)
    print()
# Out:
# Documento: TSTRR16037920105200001.conll
# Contagem de rótulos: {'O': 13616, 'B-ORGANIZACAO': 63, 'I-ORGANIZACAO': 85, 'B-LEGISLACAO': 158, 'I-LEGISLACAO': 731, 'B-JURISPRUDENCIA': 52, 'I-JURISPRUDENCIA': 211, 'B-PESSOA': 36, 'I-PESSOA': 80, 'B-TEMPO': 74, 'I-TEMPO': 28, 'B-LOCAL': 3, 'I-LOCAL': 2}
#
# Documento: RR942006420095040028.conll
# Contagem de rótulos: {'O': 4766, 'B-ORGANIZACAO': 41, 'I-ORGANIZACAO': 40, 'B-JURISPRUDENCIA': 23, 'I-JURISPRUDENCIA': 90, 'B-PESSOA': 2, 'I-PESSOA': 4, 'B-TEMPO': 5, 'B-LEGISLACAO': 48, 'I-LEGISLACAO': 282, 'I-TEMPO': 6, 'B-LOCAL': 1}
#
# Documento: AgCr10582160008758001.conll
# Contagem de rótulos: {'O': 2521, 'B-LEGISLACAO': 28, 'I-LEGISLACAO': 132, 'B-JURISPRUDENCIA': 6, 'I-JURISPRUDENCIA': 22, 'B-LOCAL': 3, 'I-LOCAL': 13, 'B-ORGANIZACAO': 12, 'I-ORGANIZACAO': 41, 'B-PESSOA': 19, 'I-PESSOA': 42, 'B-TEMPO': 9}
#
# Documento: HC04798525420128130000.conll
# Contagem de rótulos: {'O': 3338, 'B-LEGISLACAO': 24, 'I-LEGISLACAO': 143, 'B-TEMPO': 6, 'B-PESSOA': 52, 'B-ORGANIZACAO': 19, 'I-PESSOA': 59, 'B-LOCAL': 4, 'I-LOCAL': 8, 'B-JURISPRUDENCIA': 3, 'I-JURISPRUDENCIA': 11, 'I-ORGANIZACAO': 28}
#
# Documento: HC70000692720177000000.conll
# Contagem de rótulos: {'O': 3147, 'B-PESSOA': 22, 'I-PESSOA': 52, 'B-TEMPO': 23, 'B-ORGANIZACAO': 20, 'I-ORGANIZACAO': 45, 'B-LOCAL': 8, 'B-LEGISLACAO': 17, 'I-LEGISLACAO': 97, 'I-TEMPO': 86, 'B-JURISPRUDENCIA': 4, 'I-JURISPRUDENCIA': 15, 'I-LOCAL': 4}
#
# Documento: Lei11788.conll
# Contagem de rótulos: {'B-ORGANIZACAO': 5, 'I-ORGANIZACAO': 5, 'O': 2679, 'B-LEGISLACAO': 17, 'I-LEGISLACAO': 66, 'B-TEMPO': 15, 'I-TEMPO': 56, 'B-LOCAL': 1, 'B-PESSOA': 3, 'I-PESSOA': 8}
#
# Documento: AgAIRR11889820145030011.conll
# Contagem de rótulos: {'O': 1376, 'B-ORGANIZACAO': 11, 'I-ORGANIZACAO': 23, 'B-LEGISLACAO': 33, 'I-LEGISLACAO': 170, 'B-JURISPRUDENCIA': 7, 'I-JURISPRUDENCIA': 18, 'B-PESSOA': 5, 'I-PESSOA': 14, 'B-TEMPO': 5, 'B-LOCAL': 1, 'I-TEMPO': 4}
#
# Documento: ADI1TJDFT.conll
# Contagem de rótulos: {'O': 11747, 'B-ORGANIZACAO': 168, 'I-ORGANIZACAO': 351, 'B-JURISPRUDENCIA': 79, 'B-LOCAL': 62, 'I-LOCAL': 57, 'B-PESSOA': 113, 'I-PESSOA': 251, 'I-JURISPRUDENCIA': 206, 'B-LEGISLACAO': 124, 'I-LEGISLACAO': 1074, 'B-TEMPO': 56, 'I-TEMPO': 88}
#
# Documento: AgRgTSE3.conll
# Contagem de rótulos: {'B-ORGANIZACAO': 46, 'I-ORGANIZACAO': 59, 'O': 5020, 'B-JURISPRUDENCIA': 29, 'I-JURISPRUDENCIA': 71, 'B-LOCAL': 2, 'I-LOCAL': 3, 'B-PESSOA': 30, 'I-PESSOA': 46, 'B-TEMPO': 37, 'B-LEGISLACAO': 35, 'I-LEGISLACAO': 248, 'I-TEMPO': 6}
#
# Documento: AC10024133855890001.conll
# Contagem de rótulos: {'O': 2717, 'B-ORGANIZACAO': 69, 'I-ORGANIZACAO': 94, 'B-LEGISLACAO': 10, 'I-LEGISLACAO': 41, 'B-JURISPRUDENCIA': 13, 'I-JURISPRUDENCIA': 34, 'B-PESSOA': 22, 'I-PESSOA': 42, 'B-TEMPO': 18, 'B-LOCAL': 1, 'I-LOCAL': 3}
#
# Documento: AIAgRAgI6193ARAGUARIMG.conll
# Contagem de rótulos: {'O': 2431, 'B-ORGANIZACAO': 16, 'I-ORGANIZACAO': 22, 'B-JURISPRUDENCIA': 34, 'I-JURISPRUDENCIA': 83, 'B-LOCAL': 3, 'I-LOCAL': 1, 'B-PESSOA': 36, 'I-PESSOA': 76, 'B-TEMPO': 29, 'B-LEGISLACAO': 8, 'I-LEGISLACAO': 79, 'I-TEMPO': 8}
#
# Documento: CP32320177080008PA.conll
# Contagem de rótulos: {'B-ORGANIZACAO': 58, 'O': 2121, 'I-ORGANIZACAO': 129, 'B-TEMPO': 18, 'I-TEMPO': 49, 'B-PESSOA': 30, 'I-PESSOA': 77, 'B-JURISPRUDENCIA': 18, 'I-JURISPRUDENCIA': 61, 'B-LEGISLACAO': 29, 'I-LEGISLACAO': 90, 'B-LOCAL': 1}
#
# Documento: AP771420167080008PA.conll
# Contagem de rótulos: {'O': 1907, 'B-PESSOA': 26, 'I-PESSOA': 72, 'B-TEMPO': 32, 'B-ORGANIZACAO': 15, 'I-ORGANIZACAO': 36, 'B-JURISPRUDENCIA': 1, 'I-JURISPRUDENCIA': 2, 'B-LEGISLACAO': 10, 'I-LEGISLACAO': 66, 'B-LOCAL': 4, 'I-TEMPO': 4, 'I-LOCAL': 8}
#
# Documento: ERR731004520105130003.conll
# Contagem de rótulos: {'O': 7691, 'B-ORGANIZACAO': 28, 'B-LEGISLACAO': 136, 'I-LEGISLACAO': 713, 'B-JURISPRUDENCIA': 11, 'B-TEMPO': 37, 'I-JURISPRUDENCIA': 22, 'I-ORGANIZACAO': 40, 'B-PESSOA': 7, 'I-PESSOA': 11, 'B-LOCAL': 5, 'I-LOCAL': 12, 'I-TEMPO': 12}
#
# Documento: HC418951PR.conll
# Contagem de rótulos: {'O': 1160, 'B-JURISPRUDENCIA': 12, 'I-JURISPRUDENCIA': 29, 'B-PESSOA': 18, 'I-PESSOA': 33, 'B-TEMPO': 8, 'B-ORGANIZACAO': 17, 'I-ORGANIZACAO': 37, 'I-TEMPO': 8, 'B-LOCAL': 2, 'B-LEGISLACAO': 3, 'I-LEGISLACAO': 28, 'I-LOCAL': 3}
#
# Documento: TCU4687.conll
# Contagem de rótulos: {'O': 3924, 'B-ORGANIZACAO': 69, 'I-ORGANIZACAO': 163, 'B-JURISPRUDENCIA': 3, 'I-JURISPRUDENCIA': 4, 'B-PESSOA': 37, 'I-PESSOA': 74, 'B-LEGISLACAO': 41, 'I-LEGISLACAO': 351, 'B-TEMPO': 25, 'B-LOCAL': 46, 'I-LOCAL': 15, 'I-TEMPO': 20}
#
# Documento: AP00001415620157010201.conll
# Contagem de rótulos: {'O': 4064, 'B-PESSOA': 49, 'I-PESSOA': 123, 'B-TEMPO': 24, 'B-ORGANIZACAO': 21, 'I-ORGANIZACAO': 26, 'B-JURISPRUDENCIA': 5, 'I-JURISPRUDENCIA': 11, 'B-LEGISLACAO': 12, 'I-LEGISLACAO': 70, 'B-LOCAL': 30, 'I-TEMPO': 20, 'I-LOCAL': 32}
#
# Documento: AC1TJMG.conll
# Contagem de rótulos: {'O': 3084, 'B-JURISPRUDENCIA': 19, 'I-JURISPRUDENCIA': 41, 'B-LEGISLACAO': 40, 'I-LEGISLACAO': 247, 'B-TEMPO': 16, 'I-TEMPO': 4, 'B-LOCAL': 1, 'I-LOCAL': 2, 'B-ORGANIZACAO': 9, 'I-ORGANIZACAO': 32, 'B-PESSOA': 14, 'I-PESSOA': 28}
#
# Documento: HC110260SP.conll
# Contagem de rótulos: {'O': 11475, 'B-TEMPO': 60, 'B-ORGANIZACAO': 232, 'I-ORGANIZACAO': 437, 'B-JURISPRUDENCIA': 63, 'I-JURISPRUDENCIA': 150, 'B-LOCAL': 11, 'I-LOCAL': 11, 'B-PESSOA': 96, 'I-PESSOA': 120, 'B-LEGISLACAO': 117, 'I-LEGISLACAO': 722, 'I-TEMPO': 8}
#
# Documento: EDRR1TST.conll
# Contagem de rótulos: {'O': 1562, 'B-ORGANIZACAO': 9, 'I-ORGANIZACAO': 18, 'B-JURISPRUDENCIA': 6, 'I-JURISPRUDENCIA': 16, 'B-PESSOA': 2, 'I-PESSOA': 4, 'B-LEGISLACAO': 7, 'I-LEGISLACAO': 40, 'B-TEMPO': 5, 'B-LOCAL': 1, 'I-TEMPO': 4}
#
# Documento: Pet128TSE5.conll
# Contagem de rótulos: {'B-ORGANIZACAO': 28, 'I-ORGANIZACAO': 37, 'B-JURISPRUDENCIA': 18, 'I-JURISPRUDENCIA': 18, 'O': 2494, 'B-LOCAL': 3, 'I-LOCAL': 4, 'B-PESSOA': 16, 'I-PESSOA': 26, 'B-LEGISLACAO': 8, 'I-LEGISLACAO': 47, 'B-TEMPO': 20, 'I-TEMPO': 9}
#
# Documento: ED1STM.conll
# Contagem de rótulos: {'O': 2616, 'B-PESSOA': 38, 'I-PESSOA': 108, 'B-TEMPO': 30, 'B-ORGANIZACAO': 42, 'I-ORGANIZACAO': 65, 'B-JURISPRUDENCIA': 8, 'I-JURISPRUDENCIA': 19, 'B-LEGISLACAO': 18, 'I-LEGISLACAO': 122, 'B-LOCAL': 6, 'I-TEMPO': 8, 'I-LOCAL': 4}
#
# Documento: DespSEPLAGDF.conll
# Contagem de rótulos: {'O': 1366, 'B-TEMPO': 53, 'I-TEMPO': 107, 'B-JURISPRUDENCIA': 15, 'B-PESSOA': 25, 'I-PESSOA': 71, 'B-LEGISLACAO': 44, 'I-LEGISLACAO': 432, 'B-ORGANIZACAO': 35, 'I-ORGANIZACAO': 158, 'I-JURISPRUDENCIA': 18, 'B-LOCAL': 4, 'I-LOCAL': 17}
#
# Documento: LoaDF2018.conll
# Contagem de rótulos: {'B-LEGISLACAO': 12, 'I-LEGISLACAO': 104, 'O': 880, 'B-ORGANIZACAO': 12, 'I-ORGANIZACAO': 21, 'B-TEMPO': 7, 'B-LOCAL': 4, 'I-LOCAL': 2, 'I-TEMPO': 8, 'B-PESSOA': 1, 'I-PESSOA': 1}
#
# Documento: 20150110436469APC.conll
# Contagem de rótulos: {'O': 1405, 'B-ORGANIZACAO': 10, 'I-ORGANIZACAO': 46, 'B-JURISPRUDENCIA': 8, 'B-PESSOA': 13, 'I-PESSOA': 31, 'I-JURISPRUDENCIA': 25, 'B-LEGISLACAO': 11, 'I-LEGISLACAO': 94, 'B-LOCAL': 1, 'I-LOCAL': 3, 'B-TEMPO': 10, 'I-TEMPO': 4}
#
# Documento: ED1TJAC.conll
# Contagem de rótulos: {'O': 3685, 'B-LOCAL': 67, 'I-LOCAL': 116, 'B-ORGANIZACAO': 52, 'I-ORGANIZACAO': 86, 'B-JURISPRUDENCIA': 58, 'I-JURISPRUDENCIA': 151, 'B-PESSOA': 26, 'I-PESSOA': 44, 'B-LEGISLACAO': 29, 'I-LEGISLACAO': 86, 'B-TEMPO': 23, 'I-TEMPO': 8}
#
# Documento: AgRg1STM.conll
# Contagem de rótulos: {'O': 2033, 'B-PESSOA': 19, 'I-PESSOA': 39, 'B-TEMPO': 20, 'B-JURISPRUDENCIA': 6, 'I-JURISPRUDENCIA': 26, 'B-ORGANIZACAO': 24, 'I-ORGANIZACAO': 49, 'B-LEGISLACAO': 9, 'I-LEGISLACAO': 57, 'B-LOCAL': 1, 'I-TEMPO': 36}
#
# Documento: RR2574407120025020372.conll
# Contagem de rótulos: {'O': 7246, 'B-ORGANIZACAO': 10, 'I-ORGANIZACAO': 16, 'B-LEGISLACAO': 79, 'I-LEGISLACAO': 395, 'B-JURISPRUDENCIA': 15, 'I-JURISPRUDENCIA': 61, 'B-PESSOA': 6, 'I-PESSOA': 10, 'B-TEMPO': 6, 'B-LOCAL': 1, 'I-TEMPO': 4}
#
# Documento: ACORDAOTCU25052016.conll
# Contagem de rótulos: {'O': 6229, 'B-JURISPRUDENCIA': 39, 'I-JURISPRUDENCIA': 81, 'B-PESSOA': 45, 'I-PESSOA': 97, 'B-TEMPO': 12, 'B-ORGANIZACAO': 134, 'I-ORGANIZACAO': 193, 'B-LOCAL': 5, 'I-LOCAL': 8, 'B-LEGISLACAO': 30, 'I-LEGISLACAO': 194, 'I-TEMPO': 8}
#
# Documento: Agr10540170008341001.conll
# Contagem de rótulos: {'O': 1215, 'B-LEGISLACAO': 8, 'I-LEGISLACAO': 29, 'B-TEMPO': 11, 'I-TEMPO': 12, 'B-JURISPRUDENCIA': 2, 'I-JURISPRUDENCIA': 7, 'B-LOCAL': 3, 'I-LOCAL': 7, 'B-PESSOA': 7, 'I-PESSOA': 19, 'B-ORGANIZACAO': 9, 'I-ORGANIZACAO': 26}
#
# Documento: AP00000794920137060006.conll
# Contagem de rótulos: {'O': 6778, 'B-PESSOA': 48, 'I-PESSOA': 99, 'B-TEMPO': 76, 'B-ORGANIZACAO': 68, 'I-ORGANIZACAO': 100, 'B-JURISPRUDENCIA': 5, 'I-JURISPRUDENCIA': 15, 'B-LEGISLACAO': 17, 'I-LEGISLACAO': 79, 'B-LOCAL': 12, 'I-TEMPO': 28, 'I-LOCAL': 8}
#
# Documento: Rcl3495STJ.conll
# Contagem de rótulos: {'B-ORGANIZACAO': 55, 'I-ORGANIZACAO': 83, 'B-JURISPRUDENCIA': 14, 'I-JURISPRUDENCIA': 25, 'O': 1762, 'B-PESSOA': 65, 'I-PESSOA': 115, 'B-LEGISLACAO': 10, 'I-LEGISLACAO': 70, 'B-LOCAL': 1, 'I-LOCAL': 3, 'B-TEMPO': 16, 'I-TEMPO': 8}
#
# Documento: AIRR581406820065030079.conll
# Contagem de rótulos: {'O': 1165, 'B-ORGANIZACAO': 10, 'I-ORGANIZACAO': 18, 'B-LEGISLACAO': 18, 'I-LEGISLACAO': 156, 'B-TEMPO': 5, 'B-JURISPRUDENCIA': 8, 'I-JURISPRUDENCIA': 12, 'B-PESSOA': 8, 'I-PESSOA': 16, 'B-LOCAL': 1, 'I-TEMPO': 4}
#
# Documento: AgRgTSE1.conll
# Contagem de rótulos: {'B-ORGANIZACAO': 32, 'I-ORGANIZACAO': 28, 'B-JURISPRUDENCIA': 17, 'I-JURISPRUDENCIA': 63, 'O': 2685, 'B-LOCAL': 13, 'I-LOCAL': 11, 'B-PESSOA': 33, 'I-PESSOA': 53, 'B-TEMPO': 7, 'B-LEGISLACAO': 7, 'I-LEGISLACAO': 56, 'I-TEMPO': 4}
#
# Documento: EDEDARR208420135040232.conll
# Contagem de rótulos: {'O': 1099, 'B-ORGANIZACAO': 5, 'I-ORGANIZACAO': 14, 'B-LEGISLACAO': 21, 'I-LEGISLACAO': 124, 'B-JURISPRUDENCIA': 4, 'I-JURISPRUDENCIA': 22, 'B-PESSOA': 2, 'I-PESSOA': 6, 'B-LOCAL': 1, 'B-TEMPO': 2, 'I-TEMPO': 4}
#
# Documento: AIRR285001420095060020.conll
# Contagem de rótulos: {'O': 1053, 'B-ORGANIZACAO': 11, 'I-ORGANIZACAO': 14, 'B-LEGISLACAO': 17, 'I-LEGISLACAO': 105, 'B-JURISPRUDENCIA': 2, 'I-JURISPRUDENCIA': 8, 'B-PESSOA': 3, 'I-PESSOA': 6, 'B-LOCAL': 2, 'I-LOCAL': 1, 'B-TEMPO': 4, 'I-TEMPO': 4}
#
# Documento: AgAIRR617420125150072.conll
# Contagem de rótulos: {'O': 1001, 'B-ORGANIZACAO': 29, 'I-ORGANIZACAO': 56, 'B-LEGISLACAO': 25, 'I-LEGISLACAO': 137, 'B-JURISPRUDENCIA': 20, 'I-JURISPRUDENCIA': 32, 'B-PESSOA': 8, 'I-PESSOA': 27, 'B-TEMPO': 16, 'B-LOCAL': 1, 'I-TEMPO': 4}
#
# Documento: Ag10105170208398001.conll
# Contagem de rótulos: {'O': 999, 'B-JURISPRUDENCIA': 3, 'I-JURISPRUDENCIA': 9, 'B-LOCAL': 1, 'I-LOCAL': 3, 'B-PESSOA': 8, 'I-PESSOA': 18, 'B-ORGANIZACAO': 7, 'I-ORGANIZACAO': 23, 'B-LEGISLACAO': 9, 'I-LEGISLACAO': 44, 'B-TEMPO': 4}
#
# Documento: HC10000150589281000.conll
# Contagem de rótulos: {'O': 2216, 'B-LEGISLACAO': 12, 'I-LEGISLACAO': 72, 'B-PESSOA': 32, 'I-PESSOA': 68, 'B-TEMPO': 5, 'I-TEMPO': 8, 'B-LOCAL': 9, 'I-LOCAL': 20, 'B-ORGANIZACAO': 14, 'I-ORGANIZACAO': 32, 'B-JURISPRUDENCIA': 4, 'I-JURISPRUDENCIA': 18}
#
# Documento: ADI2TJDFT.conll
# Contagem de rótulos: {'O': 7685, 'B-ORGANIZACAO': 103, 'I-ORGANIZACAO': 215, 'B-JURISPRUDENCIA': 17, 'B-LOCAL': 144, 'I-LOCAL': 237, 'B-PESSOA': 62, 'I-PESSOA': 98, 'B-LEGISLACAO': 177, 'I-LEGISLACAO': 776, 'B-TEMPO': 84, 'I-TEMPO': 200, 'I-JURISPRUDENCIA': 13}
#
# Documento: AC1TJAC.conll
# Contagem de rótulos: {'O': 5932, 'B-LOCAL': 94, 'I-LOCAL': 163, 'B-ORGANIZACAO': 63, 'I-ORGANIZACAO': 130, 'B-JURISPRUDENCIA': 42, 'I-JURISPRUDENCIA': 89, 'B-PESSOA': 26, 'I-PESSOA': 52, 'B-LEGISLACAO': 28, 'I-LEGISLACAO': 166, 'B-TEMPO': 29, 'I-TEMPO': 29}
#
# Documento: AC1TCU.conll
# Contagem de rótulos: {'O': 4853, 'B-JURISPRUDENCIA': 41, 'I-JURISPRUDENCIA': 59, 'B-ORGANIZACAO': 117, 'B-PESSOA': 31, 'I-PESSOA': 87, 'B-TEMPO': 21, 'B-LEGISLACAO': 29, 'I-LEGISLACAO': 244, 'I-ORGANIZACAO': 176, 'I-TEMPO': 16, 'B-LOCAL': 1}
#
# Documento: AC20150110436469APC.conll
# Contagem de rótulos: {'O': 1404, 'B-ORGANIZACAO': 12, 'I-ORGANIZACAO': 45, 'B-JURISPRUDENCIA': 8, 'B-PESSOA': 13, 'I-PESSOA': 31, 'I-JURISPRUDENCIA': 25, 'B-LEGISLACAO': 11, 'I-LEGISLACAO': 94, 'B-LOCAL': 1, 'I-LOCAL': 3, 'B-TEMPO': 10, 'I-TEMPO': 4}
#
# Documento: EEDRR9715120105020002.conll
# Contagem de rótulos: {'O': 4064, 'B-LEGISLACAO': 60, 'I-LEGISLACAO': 267, 'B-ORGANIZACAO': 79, 'I-ORGANIZACAO': 116, 'B-JURISPRUDENCIA': 27, 'I-JURISPRUDENCIA': 71, 'B-PESSOA': 14, 'I-PESSOA': 15, 'B-TEMPO': 23, 'B-LOCAL': 1, 'I-TEMPO': 4}
#
# Documento: lei11340.conll
# Contagem de rótulos: {'O': 5133, 'B-ORGANIZACAO': 48, 'I-ORGANIZACAO': 100, 'B-LEGISLACAO': 42, 'I-LEGISLACAO': 204, 'B-TEMPO': 26, 'I-TEMPO': 41, 'B-JURISPRUDENCIA': 1, 'I-JURISPRUDENCIA': 2, 'B-LOCAL': 2, 'I-LOCAL': 1, 'B-PESSOA': 2, 'I-PESSOA': 5}
#
# Documento: AgRgSTJ1.conll
# Contagem de rótulos: {'B-ORGANIZACAO': 30, 'I-ORGANIZACAO': 54, 'B-JURISPRUDENCIA': 17, 'I-JURISPRUDENCIA': 71, 'O': 1835, 'B-PESSOA': 37, 'I-PESSOA': 77, 'B-LOCAL': 2, 'B-TEMPO': 16, 'I-TEMPO': 8, 'B-LEGISLACAO': 14, 'I-LEGISLACAO': 73}
#
# Documento: Port77DF.conll
# Contagem de rótulos: {'B-LEGISLACAO': 5, 'I-LEGISLACAO': 31, 'O': 519, 'B-TEMPO': 4, 'I-TEMPO': 16, 'B-LOCAL': 49, 'I-LOCAL': 40, 'B-ORGANIZACAO': 6, 'I-ORGANIZACAO': 12, 'B-PESSOA': 1, 'I-PESSOA': 3}
#
# Documento: RR-578030-46.1999.5.04.0018.conll
# Contagem de rótulos: {'O': 3264, 'B-ORGANIZACAO': 14, 'I-ORGANIZACAO': 42, 'B-JURISPRUDENCIA': 14, 'I-JURISPRUDENCIA': 31, 'B-LEGISLACAO': 60, 'I-LEGISLACAO': 353, 'B-PESSOA': 9, 'I-PESSOA': 15, 'B-TEMPO': 8, 'B-LOCAL': 1, 'I-TEMPO': 4}
#
# Documento: APO1TJDFT.conll
# Contagem de rótulos: {'O': 3087, 'B-ORGANIZACAO': 44, 'I-ORGANIZACAO': 57, 'B-JURISPRUDENCIA': 24, 'B-PESSOA': 34, 'I-PESSOA': 39, 'I-JURISPRUDENCIA': 20, 'B-LEGISLACAO': 48, 'B-LOCAL': 4, 'I-LOCAL': 6, 'I-LEGISLACAO': 196, 'B-TEMPO': 13, 'I-TEMPO': 16}
#
# Documento: ACORDAOTCU11602016.conll
# Contagem de rótulos: {'O': 20049, 'B-JURISPRUDENCIA': 67, 'I-JURISPRUDENCIA': 93, 'B-ORGANIZACAO': 352, 'B-PESSOA': 84, 'I-PESSOA': 229, 'B-TEMPO': 101, 'I-ORGANIZACAO': 530, 'B-LOCAL': 22, 'I-LOCAL': 48, 'B-LEGISLACAO': 70, 'I-LEGISLACAO': 503, 'I-TEMPO': 24}
#
# Documento: AIRR15708820115050222.conll
# Contagem de rótulos: {'O': 4805, 'B-ORGANIZACAO': 30, 'I-ORGANIZACAO': 55, 'B-LEGISLACAO': 39, 'I-LEGISLACAO': 221, 'B-JURISPRUDENCIA': 44, 'I-JURISPRUDENCIA': 92, 'B-PESSOA': 23, 'I-PESSOA': 44, 'B-TEMPO': 22, 'I-TEMPO': 5, 'B-LOCAL': 2, 'I-LOCAL': 1}
#
# Documento: HC340624SP.conll
# Contagem de rótulos: {'B-ORGANIZACAO': 38, 'I-ORGANIZACAO': 122, 'O': 3282, 'B-JURISPRUDENCIA': 25, 'I-JURISPRUDENCIA': 82, 'B-PESSOA': 45, 'I-PESSOA': 114, 'B-LEGISLACAO': 20, 'I-LEGISLACAO': 103, 'B-LOCAL': 4, 'I-LOCAL': 3, 'B-TEMPO': 14, 'I-TEMPO': 4}
#
# Documento: AIRR10006691020135020322.conll
# Contagem de rótulos: {'O': 2276, 'B-ORGANIZACAO': 8, 'I-ORGANIZACAO': 21, 'B-LEGISLACAO': 25, 'I-LEGISLACAO': 105, 'B-JURISPRUDENCIA': 10, 'I-JURISPRUDENCIA': 40, 'B-PESSOA': 11, 'I-PESSOA': 8, 'B-TEMPO': 3, 'B-LOCAL': 4, 'I-LOCAL': 5, 'I-TEMPO': 4}
#
# Documento: HC70000845920187000000.conll
# Contagem de rótulos: {'O': 2346, 'B-PESSOA': 13, 'I-PESSOA': 33, 'B-TEMPO': 29, 'B-ORGANIZACAO': 30, 'I-ORGANIZACAO': 74, 'B-LOCAL': 3, 'I-TEMPO': 64, 'B-LEGISLACAO': 4, 'I-LEGISLACAO': 24, 'B-JURISPRUDENCIA': 2, 'I-JURISPRUDENCIA': 5}
#
# Documento: AIRR3999520145020086.conll
# Contagem de rótulos: {'O': 681, 'B-ORGANIZACAO': 14, 'I-ORGANIZACAO': 18, 'B-LEGISLACAO': 13, 'I-LEGISLACAO': 68, 'B-JURISPRUDENCIA': 10, 'I-JURISPRUDENCIA': 4, 'B-PESSOA': 10, 'I-PESSOA': 21, 'B-TEMPO': 12, 'B-LOCAL': 1, 'I-TEMPO': 4}
#
# Documento: REE5908TSE4.conll
# Contagem de rótulos: {'O': 5685, 'B-ORGANIZACAO': 34, 'I-ORGANIZACAO': 44, 'B-JURISPRUDENCIA': 47, 'I-JURISPRUDENCIA': 122, 'B-LOCAL': 7, 'I-LOCAL': 19, 'B-PESSOA': 43, 'I-PESSOA': 97, 'B-TEMPO': 34, 'B-LEGISLACAO': 62, 'I-LEGISLACAO': 559, 'I-TEMPO': 24}
#
# Documento: AIRR3731820145060141.conll
# Contagem de rótulos: {'O': 2970, 'B-ORGANIZACAO': 18, 'I-ORGANIZACAO': 72, 'B-LEGISLACAO': 22, 'I-LEGISLACAO': 98, 'B-JURISPRUDENCIA': 21, 'I-JURISPRUDENCIA': 110, 'B-TEMPO': 21, 'B-PESSOA': 8, 'I-PESSOA': 17, 'I-TEMPO': 8, 'B-LOCAL': 1}
#
# Documento: INSTRUCAOON06043378120186000000.conll
# Contagem de rótulos: {'B-ORGANIZACAO': 5, 'I-ORGANIZACAO': 10, 'O': 238, 'B-LEGISLACAO': 9, 'I-LEGISLACAO': 34, 'B-LOCAL': 1, 'I-LOCAL': 3, 'B-PESSOA': 12, 'I-PESSOA': 20, 'B-TEMPO': 4, 'I-TEMPO': 4}
#
# Documento: REsp1583083RS.conll
# Contagem de rótulos: {'B-ORGANIZACAO': 143, 'I-ORGANIZACAO': 258, 'O': 4337, 'B-JURISPRUDENCIA': 49, 'I-JURISPRUDENCIA': 91, 'B-PESSOA': 66, 'I-PESSOA': 116, 'B-LEGISLACAO': 65, 'I-LEGISLACAO': 331, 'B-TEMPO': 15, 'I-TEMPO': 12, 'B-LOCAL': 1}
#
# Documento: HC10000170833503000.conll
# Contagem de rótulos: {'O': 2032, 'B-TEMPO': 14, 'I-TEMPO': 12, 'B-LEGISLACAO': 20, 'I-LEGISLACAO': 118, 'B-JURISPRUDENCIA': 1, 'I-JURISPRUDENCIA': 4, 'B-LOCAL': 1, 'I-LOCAL': 2, 'B-PESSOA': 10, 'I-PESSOA': 25, 'B-ORGANIZACAO': 4, 'I-ORGANIZACAO': 24}
#
# Documento: RR14976020105020085.conll
# Contagem de rótulos: {'O': 4475, 'B-ORGANIZACAO': 26, 'I-ORGANIZACAO': 53, 'B-LEGISLACAO': 105, 'I-LEGISLACAO': 619, 'B-JURISPRUDENCIA': 36, 'I-JURISPRUDENCIA': 120, 'B-PESSOA': 18, 'I-PESSOA': 57, 'B-TEMPO': 23, 'B-LOCAL': 2, 'I-LOCAL': 3, 'I-TEMPO': 8}
#
# Documento: Ag10000170733596001.conll
# Contagem de rótulos: {'O': 1246, 'B-LEGISLACAO': 4, 'I-LEGISLACAO': 28, 'B-TEMPO': 18, 'B-JURISPRUDENCIA': 1, 'I-JURISPRUDENCIA': 4, 'B-LOCAL': 1, 'I-LOCAL': 2, 'B-ORGANIZACAO': 8, 'I-ORGANIZACAO': 68, 'B-PESSOA': 4, 'I-PESSOA': 9}
#
# Documento: airr801422012.conll
# Contagem de rótulos: {'O': 2634, 'B-ORGANIZACAO': 33, 'I-ORGANIZACAO': 27, 'B-LEGISLACAO': 36, 'I-LEGISLACAO': 187, 'B-JURISPRUDENCIA': 35, 'I-JURISPRUDENCIA': 116, 'B-TEMPO': 18, 'B-PESSOA': 7, 'I-PESSOA': 10, 'B-LOCAL': 2, 'I-LOCAL': 1, 'I-TEMPO': 8}
#
# Documento: ACO2821STF.conll
# Contagem de rótulos: {'O': 8217, 'B-TEMPO': 73, 'B-JURISPRUDENCIA': 75, 'I-JURISPRUDENCIA': 208, 'B-LOCAL': 27, 'I-LOCAL': 50, 'B-PESSOA': 67, 'I-PESSOA': 77, 'B-ORGANIZACAO': 265, 'I-ORGANIZACAO': 394, 'B-LEGISLACAO': 140, 'I-LEGISLACAO': 419, 'I-TEMPO': 47}
#
# Documento: EDAgRgTSE2.conll
# Contagem de rótulos: {'B-ORGANIZACAO': 15, 'I-ORGANIZACAO': 18, 'O': 1495, 'B-JURISPRUDENCIA': 14, 'I-JURISPRUDENCIA': 37, 'B-LOCAL': 5, 'I-LOCAL': 7, 'B-PESSOA': 20, 'I-PESSOA': 37, 'B-TEMPO': 22, 'I-TEMPO': 16, 'B-LEGISLACAO': 13, 'I-LEGISLACAO': 74}
#
# Documento: AP00001441420167030203.conll
# Contagem de rótulos: {'O': 19950, 'B-PESSOA': 148, 'I-PESSOA': 376, 'B-TEMPO': 131, 'B-ORGANIZACAO': 170, 'I-ORGANIZACAO': 216, 'B-JURISPRUDENCIA': 105, 'I-JURISPRUDENCIA': 297, 'B-LEGISLACAO': 149, 'I-LEGISLACAO': 1035, 'B-LOCAL': 20, 'I-TEMPO': 33, 'I-LOCAL': 10}
#
# Documento: AgRgSTJ2.conll
# Contagem de rótulos: {'B-ORGANIZACAO': 43, 'I-ORGANIZACAO': 80, 'B-JURISPRUDENCIA': 49, 'I-JURISPRUDENCIA': 150, 'O': 3897, 'B-PESSOA': 71, 'I-PESSOA': 133, 'B-TEMPO': 40, 'B-LEGISLACAO': 36, 'I-LEGISLACAO': 298, 'B-LOCAL': 2, 'I-TEMPO': 4}
#
# Documento: RR474820145230056.conll
# Contagem de rótulos: {'O': 308, 'B-ORGANIZACAO': 4, 'I-ORGANIZACAO': 11, 'B-LEGISLACAO': 6, 'I-LEGISLACAO': 34, 'B-JURISPRUDENCIA': 2, 'I-JURISPRUDENCIA': 4, 'B-PESSOA': 2, 'I-PESSOA': 4, 'B-LOCAL': 1, 'B-TEMPO': 2, 'I-TEMPO': 4}
#
# Documento: HC151914AgRES.conll
# Contagem de rótulos: {'O': 2772, 'B-TEMPO': 45, 'B-JURISPRUDENCIA': 52, 'I-JURISPRUDENCIA': 110, 'B-LOCAL': 15, 'I-LOCAL': 15, 'B-PESSOA': 98, 'I-PESSOA': 175, 'B-ORGANIZACAO': 98, 'I-ORGANIZACAO': 173, 'B-LEGISLACAO': 33, 'I-LEGISLACAO': 198, 'I-TEMPO': 8}
#
# Documento: adi3767.conll
# Contagem de rótulos: {'O': 3816, 'B-TEMPO': 56, 'B-ORGANIZACAO': 93, 'B-JURISPRUDENCIA': 26, 'I-JURISPRUDENCIA': 97, 'B-LOCAL': 20, 'B-PESSOA': 57, 'I-PESSOA': 79, 'I-LOCAL': 26, 'I-ORGANIZACAO': 193, 'I-TEMPO': 76, 'B-LEGISLACAO': 69, 'I-LEGISLACAO': 369}

# %%
# labels_por_doc['HAREMdoc_aa64686'][-12]
# len(labels_por_doc['HAREMdoc_aa64686'])

# %%
from collections import Counter

# Inicializar um dicionário para armazenar contagens de rótulos por documento
# antes e depois de simplificar.
labels_por_doc = {}
labels_por_doc_simplificado = {}

for docName, docData in data_por_sentenca_por_doc.items():
    allDocData = []
    
    # Concatenar todas as sentenças de um documento em uma lista
    for sentence in docData:
        allDocData += [i for i in sentence]
    
    # Separar tokens e rótulos
    docTokens, docLabels = split_token_label(allDocData)
    
    # Contagem de rótulos com os prefixos (original)
    labels_count_original = Counter(docLabels)
    labels_por_doc[docName] = dict(labels_count_original)
    
    # Extração da última parte do rótulo (ex. 'B-PER' vira 'PER')
    labels_simplificados = [lbl.split('-')[-1] for lbl in docLabels]
    labels_count_simplificado = Counter(labels_simplificados)
    labels_por_doc_simplificado[docName] = dict(labels_count_simplificado)

# Exibir a contagem original e simplificada para comparação
for doc in labels_por_doc.keys():
    print(f"Documento: {doc}")
    print("Contagem de rótulos (original):", labels_por_doc[doc])
    print("Contagem de rótulos (simplificado):", labels_por_doc_simplificado[doc])
    print()

# Exibir o total de documentos
print("Total de documentos:", len(labels_por_doc))
# Out:
# Documento: TSTRR16037920105200001.conll
# Contagem de rótulos (original): {'O': 13616, 'B-ORGANIZACAO': 63, 'I-ORGANIZACAO': 85, 'B-LEGISLACAO': 158, 'I-LEGISLACAO': 731, 'B-JURISPRUDENCIA': 52, 'I-JURISPRUDENCIA': 211, 'B-PESSOA': 36, 'I-PESSOA': 80, 'B-TEMPO': 74, 'I-TEMPO': 28, 'B-LOCAL': 3, 'I-LOCAL': 2}
# Contagem de rótulos (simplificado): {'O': 13616, 'ORGANIZACAO': 148, 'LEGISLACAO': 889, 'JURISPRUDENCIA': 263, 'PESSOA': 116, 'TEMPO': 102, 'LOCAL': 5}
#
# Documento: RR942006420095040028.conll
# Contagem de rótulos (original): {'O': 4766, 'B-ORGANIZACAO': 41, 'I-ORGANIZACAO': 40, 'B-JURISPRUDENCIA': 23, 'I-JURISPRUDENCIA': 90, 'B-PESSOA': 2, 'I-PESSOA': 4, 'B-TEMPO': 5, 'B-LEGISLACAO': 48, 'I-LEGISLACAO': 282, 'I-TEMPO': 6, 'B-LOCAL': 1}
# Contagem de rótulos (simplificado): {'O': 4766, 'ORGANIZACAO': 81, 'JURISPRUDENCIA': 113, 'PESSOA': 6, 'TEMPO': 11, 'LEGISLACAO': 330, 'LOCAL': 1}
#
# Documento: AgCr10582160008758001.conll
# Contagem de rótulos (original): {'O': 2521, 'B-LEGISLACAO': 28, 'I-LEGISLACAO': 132, 'B-JURISPRUDENCIA': 6, 'I-JURISPRUDENCIA': 22, 'B-LOCAL': 3, 'I-LOCAL': 13, 'B-ORGANIZACAO': 12, 'I-ORGANIZACAO': 41, 'B-PESSOA': 19, 'I-PESSOA': 42, 'B-TEMPO': 9}
# Contagem de rótulos (simplificado): {'O': 2521, 'LEGISLACAO': 160, 'JURISPRUDENCIA': 28, 'LOCAL': 16, 'ORGANIZACAO': 53, 'PESSOA': 61, 'TEMPO': 9}
#
# Documento: HC04798525420128130000.conll
# Contagem de rótulos (original): {'O': 3338, 'B-LEGISLACAO': 24, 'I-LEGISLACAO': 143, 'B-TEMPO': 6, 'B-PESSOA': 52, 'B-ORGANIZACAO': 19, 'I-PESSOA': 59, 'B-LOCAL': 4, 'I-LOCAL': 8, 'B-JURISPRUDENCIA': 3, 'I-JURISPRUDENCIA': 11, 'I-ORGANIZACAO': 28}
# Contagem de rótulos (simplificado): {'O': 3338, 'LEGISLACAO': 167, 'TEMPO': 6, 'PESSOA': 111, 'ORGANIZACAO': 47, 'LOCAL': 12, 'JURISPRUDENCIA': 14}
#
# Documento: HC70000692720177000000.conll
# Contagem de rótulos (original): {'O': 3147, 'B-PESSOA': 22, 'I-PESSOA': 52, 'B-TEMPO': 23, 'B-ORGANIZACAO': 20, 'I-ORGANIZACAO': 45, 'B-LOCAL': 8, 'B-LEGISLACAO': 17, 'I-LEGISLACAO': 97, 'I-TEMPO': 86, 'B-JURISPRUDENCIA': 4, 'I-JURISPRUDENCIA': 15, 'I-LOCAL': 4}
# Contagem de rótulos (simplificado): {'O': 3147, 'PESSOA': 74, 'TEMPO': 109, 'ORGANIZACAO': 65, 'LOCAL': 12, 'LEGISLACAO': 114, 'JURISPRUDENCIA': 19}
#
# Documento: Lei11788.conll
# Contagem de rótulos (original): {'B-ORGANIZACAO': 5, 'I-ORGANIZACAO': 5, 'O': 2679, 'B-LEGISLACAO': 17, 'I-LEGISLACAO': 66, 'B-TEMPO': 15, 'I-TEMPO': 56, 'B-LOCAL': 1, 'B-PESSOA': 3, 'I-PESSOA': 8}
# Contagem de rótulos (simplificado): {'ORGANIZACAO': 10, 'O': 2679, 'LEGISLACAO': 83, 'TEMPO': 71, 'LOCAL': 1, 'PESSOA': 11}
#
# Documento: AgAIRR11889820145030011.conll
# Contagem de rótulos (original): {'O': 1376, 'B-ORGANIZACAO': 11, 'I-ORGANIZACAO': 23, 'B-LEGISLACAO': 33, 'I-LEGISLACAO': 170, 'B-JURISPRUDENCIA': 7, 'I-JURISPRUDENCIA': 18, 'B-PESSOA': 5, 'I-PESSOA': 14, 'B-TEMPO': 5, 'B-LOCAL': 1, 'I-TEMPO': 4}
# Contagem de rótulos (simplificado): {'O': 1376, 'ORGANIZACAO': 34, 'LEGISLACAO': 203, 'JURISPRUDENCIA': 25, 'PESSOA': 19, 'TEMPO': 9, 'LOCAL': 1}
#
# Documento: ADI1TJDFT.conll
# Contagem de rótulos (original): {'O': 11747, 'B-ORGANIZACAO': 168, 'I-ORGANIZACAO': 351, 'B-JURISPRUDENCIA': 79, 'B-LOCAL': 62, 'I-LOCAL': 57, 'B-PESSOA': 113, 'I-PESSOA': 251, 'I-JURISPRUDENCIA': 206, 'B-LEGISLACAO': 124, 'I-LEGISLACAO': 1074, 'B-TEMPO': 56, 'I-TEMPO': 88}
# Contagem de rótulos (simplificado): {'O': 11747, 'ORGANIZACAO': 519, 'JURISPRUDENCIA': 285, 'LOCAL': 119, 'PESSOA': 364, 'LEGISLACAO': 1198, 'TEMPO': 144}
#
# Documento: AgRgTSE3.conll
# Contagem de rótulos (original): {'B-ORGANIZACAO': 46, 'I-ORGANIZACAO': 59, 'O': 5020, 'B-JURISPRUDENCIA': 29, 'I-JURISPRUDENCIA': 71, 'B-LOCAL': 2, 'I-LOCAL': 3, 'B-PESSOA': 30, 'I-PESSOA': 46, 'B-TEMPO': 37, 'B-LEGISLACAO': 35, 'I-LEGISLACAO': 248, 'I-TEMPO': 6}
# Contagem de rótulos (simplificado): {'ORGANIZACAO': 105, 'O': 5020, 'JURISPRUDENCIA': 100, 'LOCAL': 5, 'PESSOA': 76, 'TEMPO': 43, 'LEGISLACAO': 283}
#
# Documento: AC10024133855890001.conll
# Contagem de rótulos (original): {'O': 2717, 'B-ORGANIZACAO': 69, 'I-ORGANIZACAO': 94, 'B-LEGISLACAO': 10, 'I-LEGISLACAO': 41, 'B-JURISPRUDENCIA': 13, 'I-JURISPRUDENCIA': 34, 'B-PESSOA': 22, 'I-PESSOA': 42, 'B-TEMPO': 18, 'B-LOCAL': 1, 'I-LOCAL': 3}
# Contagem de rótulos (simplificado): {'O': 2717, 'ORGANIZACAO': 163, 'LEGISLACAO': 51, 'JURISPRUDENCIA': 47, 'PESSOA': 64, 'TEMPO': 18, 'LOCAL': 4}
#
# Documento: AIAgRAgI6193ARAGUARIMG.conll
# Contagem de rótulos (original): {'O': 2431, 'B-ORGANIZACAO': 16, 'I-ORGANIZACAO': 22, 'B-JURISPRUDENCIA': 34, 'I-JURISPRUDENCIA': 83, 'B-LOCAL': 3, 'I-LOCAL': 1, 'B-PESSOA': 36, 'I-PESSOA': 76, 'B-TEMPO': 29, 'B-LEGISLACAO': 8, 'I-LEGISLACAO': 79, 'I-TEMPO': 8}
# Contagem de rótulos (simplificado): {'O': 2431, 'ORGANIZACAO': 38, 'JURISPRUDENCIA': 117, 'LOCAL': 4, 'PESSOA': 112, 'TEMPO': 37, 'LEGISLACAO': 87}
#
# Documento: CP32320177080008PA.conll
# Contagem de rótulos (original): {'B-ORGANIZACAO': 58, 'O': 2121, 'I-ORGANIZACAO': 129, 'B-TEMPO': 18, 'I-TEMPO': 49, 'B-PESSOA': 30, 'I-PESSOA': 77, 'B-JURISPRUDENCIA': 18, 'I-JURISPRUDENCIA': 61, 'B-LEGISLACAO': 29, 'I-LEGISLACAO': 90, 'B-LOCAL': 1}
# Contagem de rótulos (simplificado): {'ORGANIZACAO': 187, 'O': 2121, 'TEMPO': 67, 'PESSOA': 107, 'JURISPRUDENCIA': 79, 'LEGISLACAO': 119, 'LOCAL': 1}
#
# Documento: AP771420167080008PA.conll
# Contagem de rótulos (original): {'O': 1907, 'B-PESSOA': 26, 'I-PESSOA': 72, 'B-TEMPO': 32, 'B-ORGANIZACAO': 15, 'I-ORGANIZACAO': 36, 'B-JURISPRUDENCIA': 1, 'I-JURISPRUDENCIA': 2, 'B-LEGISLACAO': 10, 'I-LEGISLACAO': 66, 'B-LOCAL': 4, 'I-TEMPO': 4, 'I-LOCAL': 8}
# Contagem de rótulos (simplificado): {'O': 1907, 'PESSOA': 98, 'TEMPO': 36, 'ORGANIZACAO': 51, 'JURISPRUDENCIA': 3, 'LEGISLACAO': 76, 'LOCAL': 12}
#
# Documento: ERR731004520105130003.conll
# Contagem de rótulos (original): {'O': 7691, 'B-ORGANIZACAO': 28, 'B-LEGISLACAO': 136, 'I-LEGISLACAO': 713, 'B-JURISPRUDENCIA': 11, 'B-TEMPO': 37, 'I-JURISPRUDENCIA': 22, 'I-ORGANIZACAO': 40, 'B-PESSOA': 7, 'I-PESSOA': 11, 'B-LOCAL': 5, 'I-LOCAL': 12, 'I-TEMPO': 12}
# Contagem de rótulos (simplificado): {'O': 7691, 'ORGANIZACAO': 68, 'LEGISLACAO': 849, 'JURISPRUDENCIA': 33, 'TEMPO': 49, 'PESSOA': 18, 'LOCAL': 17}
#
# Documento: HC418951PR.conll
# Contagem de rótulos (original): {'O': 1160, 'B-JURISPRUDENCIA': 12, 'I-JURISPRUDENCIA': 29, 'B-PESSOA': 18, 'I-PESSOA': 33, 'B-TEMPO': 8, 'B-ORGANIZACAO': 17, 'I-ORGANIZACAO': 37, 'I-TEMPO': 8, 'B-LOCAL': 2, 'B-LEGISLACAO': 3, 'I-LEGISLACAO': 28, 'I-LOCAL': 3}
# Contagem de rótulos (simplificado): {'O': 1160, 'JURISPRUDENCIA': 41, 'PESSOA': 51, 'TEMPO': 16, 'ORGANIZACAO': 54, 'LOCAL': 5, 'LEGISLACAO': 31}
#
# Documento: TCU4687.conll
# Contagem de rótulos (original): {'O': 3924, 'B-ORGANIZACAO': 69, 'I-ORGANIZACAO': 163, 'B-JURISPRUDENCIA': 3, 'I-JURISPRUDENCIA': 4, 'B-PESSOA': 37, 'I-PESSOA': 74, 'B-LEGISLACAO': 41, 'I-LEGISLACAO': 351, 'B-TEMPO': 25, 'B-LOCAL': 46, 'I-LOCAL': 15, 'I-TEMPO': 20}
# Contagem de rótulos (simplificado): {'O': 3924, 'ORGANIZACAO': 232, 'JURISPRUDENCIA': 7, 'PESSOA': 111, 'LEGISLACAO': 392, 'TEMPO': 45, 'LOCAL': 61}
#
# Documento: AP00001415620157010201.conll
# Contagem de rótulos (original): {'O': 4064, 'B-PESSOA': 49, 'I-PESSOA': 123, 'B-TEMPO': 24, 'B-ORGANIZACAO': 21, 'I-ORGANIZACAO': 26, 'B-JURISPRUDENCIA': 5, 'I-JURISPRUDENCIA': 11, 'B-LEGISLACAO': 12, 'I-LEGISLACAO': 70, 'B-LOCAL': 30, 'I-TEMPO': 20, 'I-LOCAL': 32}
# Contagem de rótulos (simplificado): {'O': 4064, 'PESSOA': 172, 'TEMPO': 44, 'ORGANIZACAO': 47, 'JURISPRUDENCIA': 16, 'LEGISLACAO': 82, 'LOCAL': 62}
#
# Documento: AC1TJMG.conll
# Contagem de rótulos (original): {'O': 3084, 'B-JURISPRUDENCIA': 19, 'I-JURISPRUDENCIA': 41, 'B-LEGISLACAO': 40, 'I-LEGISLACAO': 247, 'B-TEMPO': 16, 'I-TEMPO': 4, 'B-LOCAL': 1, 'I-LOCAL': 2, 'B-ORGANIZACAO': 9, 'I-ORGANIZACAO': 32, 'B-PESSOA': 14, 'I-PESSOA': 28}
# Contagem de rótulos (simplificado): {'O': 3084, 'JURISPRUDENCIA': 60, 'LEGISLACAO': 287, 'TEMPO': 20, 'LOCAL': 3, 'ORGANIZACAO': 41, 'PESSOA': 42}
#
# Documento: HC110260SP.conll
# Contagem de rótulos (original): {'O': 11475, 'B-TEMPO': 60, 'B-ORGANIZACAO': 232, 'I-ORGANIZACAO': 437, 'B-JURISPRUDENCIA': 63, 'I-JURISPRUDENCIA': 150, 'B-LOCAL': 11, 'I-LOCAL': 11, 'B-PESSOA': 96, 'I-PESSOA': 120, 'B-LEGISLACAO': 117, 'I-LEGISLACAO': 722, 'I-TEMPO': 8}
# Contagem de rótulos (simplificado): {'O': 11475, 'TEMPO': 68, 'ORGANIZACAO': 669, 'JURISPRUDENCIA': 213, 'LOCAL': 22, 'PESSOA': 216, 'LEGISLACAO': 839}
#
# Documento: EDRR1TST.conll
# Contagem de rótulos (original): {'O': 1562, 'B-ORGANIZACAO': 9, 'I-ORGANIZACAO': 18, 'B-JURISPRUDENCIA': 6, 'I-JURISPRUDENCIA': 16, 'B-PESSOA': 2, 'I-PESSOA': 4, 'B-LEGISLACAO': 7, 'I-LEGISLACAO': 40, 'B-TEMPO': 5, 'B-LOCAL': 1, 'I-TEMPO': 4}
# Contagem de rótulos (simplificado): {'O': 1562, 'ORGANIZACAO': 27, 'JURISPRUDENCIA': 22, 'PESSOA': 6, 'LEGISLACAO': 47, 'TEMPO': 9, 'LOCAL': 1}
#
# Documento: Pet128TSE5.conll
# Contagem de rótulos (original): {'B-ORGANIZACAO': 28, 'I-ORGANIZACAO': 37, 'B-JURISPRUDENCIA': 18, 'I-JURISPRUDENCIA': 18, 'O': 2494, 'B-LOCAL': 3, 'I-LOCAL': 4, 'B-PESSOA': 16, 'I-PESSOA': 26, 'B-LEGISLACAO': 8, 'I-LEGISLACAO': 47, 'B-TEMPO': 20, 'I-TEMPO': 9}
# Contagem de rótulos (simplificado): {'ORGANIZACAO': 65, 'JURISPRUDENCIA': 36, 'O': 2494, 'LOCAL': 7, 'PESSOA': 42, 'LEGISLACAO': 55, 'TEMPO': 29}
#
# Documento: ED1STM.conll
# Contagem de rótulos (original): {'O': 2616, 'B-PESSOA': 38, 'I-PESSOA': 108, 'B-TEMPO': 30, 'B-ORGANIZACAO': 42, 'I-ORGANIZACAO': 65, 'B-JURISPRUDENCIA': 8, 'I-JURISPRUDENCIA': 19, 'B-LEGISLACAO': 18, 'I-LEGISLACAO': 122, 'B-LOCAL': 6, 'I-TEMPO': 8, 'I-LOCAL': 4}
# Contagem de rótulos (simplificado): {'O': 2616, 'PESSOA': 146, 'TEMPO': 38, 'ORGANIZACAO': 107, 'JURISPRUDENCIA': 27, 'LEGISLACAO': 140, 'LOCAL': 10}
#
# Documento: DespSEPLAGDF.conll
# Contagem de rótulos (original): {'O': 1366, 'B-TEMPO': 53, 'I-TEMPO': 107, 'B-JURISPRUDENCIA': 15, 'B-PESSOA': 25, 'I-PESSOA': 71, 'B-LEGISLACAO': 44, 'I-LEGISLACAO': 432, 'B-ORGANIZACAO': 35, 'I-ORGANIZACAO': 158, 'I-JURISPRUDENCIA': 18, 'B-LOCAL': 4, 'I-LOCAL': 17}
# Contagem de rótulos (simplificado): {'O': 1366, 'TEMPO': 160, 'JURISPRUDENCIA': 33, 'PESSOA': 96, 'LEGISLACAO': 476, 'ORGANIZACAO': 193, 'LOCAL': 21}
#
# Documento: LoaDF2018.conll
# Contagem de rótulos (original): {'B-LEGISLACAO': 12, 'I-LEGISLACAO': 104, 'O': 880, 'B-ORGANIZACAO': 12, 'I-ORGANIZACAO': 21, 'B-TEMPO': 7, 'B-LOCAL': 4, 'I-LOCAL': 2, 'I-TEMPO': 8, 'B-PESSOA': 1, 'I-PESSOA': 1}
# Contagem de rótulos (simplificado): {'LEGISLACAO': 116, 'O': 880, 'ORGANIZACAO': 33, 'TEMPO': 15, 'LOCAL': 6, 'PESSOA': 2}
#
# Documento: 20150110436469APC.conll
# Contagem de rótulos (original): {'O': 1405, 'B-ORGANIZACAO': 10, 'I-ORGANIZACAO': 46, 'B-JURISPRUDENCIA': 8, 'B-PESSOA': 13, 'I-PESSOA': 31, 'I-JURISPRUDENCIA': 25, 'B-LEGISLACAO': 11, 'I-LEGISLACAO': 94, 'B-LOCAL': 1, 'I-LOCAL': 3, 'B-TEMPO': 10, 'I-TEMPO': 4}
# Contagem de rótulos (simplificado): {'O': 1405, 'ORGANIZACAO': 56, 'JURISPRUDENCIA': 33, 'PESSOA': 44, 'LEGISLACAO': 105, 'LOCAL': 4, 'TEMPO': 14}
#
# Documento: ED1TJAC.conll
# Contagem de rótulos (original): {'O': 3685, 'B-LOCAL': 67, 'I-LOCAL': 116, 'B-ORGANIZACAO': 52, 'I-ORGANIZACAO': 86, 'B-JURISPRUDENCIA': 58, 'I-JURISPRUDENCIA': 151, 'B-PESSOA': 26, 'I-PESSOA': 44, 'B-LEGISLACAO': 29, 'I-LEGISLACAO': 86, 'B-TEMPO': 23, 'I-TEMPO': 8}
# Contagem de rótulos (simplificado): {'O': 3685, 'LOCAL': 183, 'ORGANIZACAO': 138, 'JURISPRUDENCIA': 209, 'PESSOA': 70, 'LEGISLACAO': 115, 'TEMPO': 31}
#
# Documento: AgRg1STM.conll
# Contagem de rótulos (original): {'O': 2033, 'B-PESSOA': 19, 'I-PESSOA': 39, 'B-TEMPO': 20, 'B-JURISPRUDENCIA': 6, 'I-JURISPRUDENCIA': 26, 'B-ORGANIZACAO': 24, 'I-ORGANIZACAO': 49, 'B-LEGISLACAO': 9, 'I-LEGISLACAO': 57, 'B-LOCAL': 1, 'I-TEMPO': 36}
# Contagem de rótulos (simplificado): {'O': 2033, 'PESSOA': 58, 'TEMPO': 56, 'JURISPRUDENCIA': 32, 'ORGANIZACAO': 73, 'LEGISLACAO': 66, 'LOCAL': 1}
#
# Documento: RR2574407120025020372.conll
# Contagem de rótulos (original): {'O': 7246, 'B-ORGANIZACAO': 10, 'I-ORGANIZACAO': 16, 'B-LEGISLACAO': 79, 'I-LEGISLACAO': 395, 'B-JURISPRUDENCIA': 15, 'I-JURISPRUDENCIA': 61, 'B-PESSOA': 6, 'I-PESSOA': 10, 'B-TEMPO': 6, 'B-LOCAL': 1, 'I-TEMPO': 4}
# Contagem de rótulos (simplificado): {'O': 7246, 'ORGANIZACAO': 26, 'LEGISLACAO': 474, 'JURISPRUDENCIA': 76, 'PESSOA': 16, 'TEMPO': 10, 'LOCAL': 1}
#
# Documento: ACORDAOTCU25052016.conll
# Contagem de rótulos (original): {'O': 6229, 'B-JURISPRUDENCIA': 39, 'I-JURISPRUDENCIA': 81, 'B-PESSOA': 45, 'I-PESSOA': 97, 'B-TEMPO': 12, 'B-ORGANIZACAO': 134, 'I-ORGANIZACAO': 193, 'B-LOCAL': 5, 'I-LOCAL': 8, 'B-LEGISLACAO': 30, 'I-LEGISLACAO': 194, 'I-TEMPO': 8}
# Contagem de rótulos (simplificado): {'O': 6229, 'JURISPRUDENCIA': 120, 'PESSOA': 142, 'TEMPO': 20, 'ORGANIZACAO': 327, 'LOCAL': 13, 'LEGISLACAO': 224}
#
# Documento: Agr10540170008341001.conll
# Contagem de rótulos (original): {'O': 1215, 'B-LEGISLACAO': 8, 'I-LEGISLACAO': 29, 'B-TEMPO': 11, 'I-TEMPO': 12, 'B-JURISPRUDENCIA': 2, 'I-JURISPRUDENCIA': 7, 'B-LOCAL': 3, 'I-LOCAL': 7, 'B-PESSOA': 7, 'I-PESSOA': 19, 'B-ORGANIZACAO': 9, 'I-ORGANIZACAO': 26}
# Contagem de rótulos (simplificado): {'O': 1215, 'LEGISLACAO': 37, 'TEMPO': 23, 'JURISPRUDENCIA': 9, 'LOCAL': 10, 'PESSOA': 26, 'ORGANIZACAO': 35}
#
# Documento: AP00000794920137060006.conll
# Contagem de rótulos (original): {'O': 6778, 'B-PESSOA': 48, 'I-PESSOA': 99, 'B-TEMPO': 76, 'B-ORGANIZACAO': 68, 'I-ORGANIZACAO': 100, 'B-JURISPRUDENCIA': 5, 'I-JURISPRUDENCIA': 15, 'B-LEGISLACAO': 17, 'I-LEGISLACAO': 79, 'B-LOCAL': 12, 'I-TEMPO': 28, 'I-LOCAL': 8}
# Contagem de rótulos (simplificado): {'O': 6778, 'PESSOA': 147, 'TEMPO': 104, 'ORGANIZACAO': 168, 'JURISPRUDENCIA': 20, 'LEGISLACAO': 96, 'LOCAL': 20}
#
# Documento: Rcl3495STJ.conll
# Contagem de rótulos (original): {'B-ORGANIZACAO': 55, 'I-ORGANIZACAO': 83, 'B-JURISPRUDENCIA': 14, 'I-JURISPRUDENCIA': 25, 'O': 1762, 'B-PESSOA': 65, 'I-PESSOA': 115, 'B-LEGISLACAO': 10, 'I-LEGISLACAO': 70, 'B-LOCAL': 1, 'I-LOCAL': 3, 'B-TEMPO': 16, 'I-TEMPO': 8}
# Contagem de rótulos (simplificado): {'ORGANIZACAO': 138, 'JURISPRUDENCIA': 39, 'O': 1762, 'PESSOA': 180, 'LEGISLACAO': 80, 'LOCAL': 4, 'TEMPO': 24}
#
# Documento: AIRR581406820065030079.conll
# Contagem de rótulos (original): {'O': 1165, 'B-ORGANIZACAO': 10, 'I-ORGANIZACAO': 18, 'B-LEGISLACAO': 18, 'I-LEGISLACAO': 156, 'B-TEMPO': 5, 'B-JURISPRUDENCIA': 8, 'I-JURISPRUDENCIA': 12, 'B-PESSOA': 8, 'I-PESSOA': 16, 'B-LOCAL': 1, 'I-TEMPO': 4}
# Contagem de rótulos (simplificado): {'O': 1165, 'ORGANIZACAO': 28, 'LEGISLACAO': 174, 'TEMPO': 9, 'JURISPRUDENCIA': 20, 'PESSOA': 24, 'LOCAL': 1}
#
# Documento: AgRgTSE1.conll
# Contagem de rótulos (original): {'B-ORGANIZACAO': 32, 'I-ORGANIZACAO': 28, 'B-JURISPRUDENCIA': 17, 'I-JURISPRUDENCIA': 63, 'O': 2685, 'B-LOCAL': 13, 'I-LOCAL': 11, 'B-PESSOA': 33, 'I-PESSOA': 53, 'B-TEMPO': 7, 'B-LEGISLACAO': 7, 'I-LEGISLACAO': 56, 'I-TEMPO': 4}
# Contagem de rótulos (simplificado): {'ORGANIZACAO': 60, 'JURISPRUDENCIA': 80, 'O': 2685, 'LOCAL': 24, 'PESSOA': 86, 'TEMPO': 11, 'LEGISLACAO': 63}
#
# Documento: EDEDARR208420135040232.conll
# Contagem de rótulos (original): {'O': 1099, 'B-ORGANIZACAO': 5, 'I-ORGANIZACAO': 14, 'B-LEGISLACAO': 21, 'I-LEGISLACAO': 124, 'B-JURISPRUDENCIA': 4, 'I-JURISPRUDENCIA': 22, 'B-PESSOA': 2, 'I-PESSOA': 6, 'B-LOCAL': 1, 'B-TEMPO': 2, 'I-TEMPO': 4}
# Contagem de rótulos (simplificado): {'O': 1099, 'ORGANIZACAO': 19, 'LEGISLACAO': 145, 'JURISPRUDENCIA': 26, 'PESSOA': 8, 'LOCAL': 1, 'TEMPO': 6}
#
# Documento: AIRR285001420095060020.conll
# Contagem de rótulos (original): {'O': 1053, 'B-ORGANIZACAO': 11, 'I-ORGANIZACAO': 14, 'B-LEGISLACAO': 17, 'I-LEGISLACAO': 105, 'B-JURISPRUDENCIA': 2, 'I-JURISPRUDENCIA': 8, 'B-PESSOA': 3, 'I-PESSOA': 6, 'B-LOCAL': 2, 'I-LOCAL': 1, 'B-TEMPO': 4, 'I-TEMPO': 4}
# Contagem de rótulos (simplificado): {'O': 1053, 'ORGANIZACAO': 25, 'LEGISLACAO': 122, 'JURISPRUDENCIA': 10, 'PESSOA': 9, 'LOCAL': 3, 'TEMPO': 8}
#
# Documento: AgAIRR617420125150072.conll
# Contagem de rótulos (original): {'O': 1001, 'B-ORGANIZACAO': 29, 'I-ORGANIZACAO': 56, 'B-LEGISLACAO': 25, 'I-LEGISLACAO': 137, 'B-JURISPRUDENCIA': 20, 'I-JURISPRUDENCIA': 32, 'B-PESSOA': 8, 'I-PESSOA': 27, 'B-TEMPO': 16, 'B-LOCAL': 1, 'I-TEMPO': 4}
# Contagem de rótulos (simplificado): {'O': 1001, 'ORGANIZACAO': 85, 'LEGISLACAO': 162, 'JURISPRUDENCIA': 52, 'PESSOA': 35, 'TEMPO': 20, 'LOCAL': 1}
#
# Documento: Ag10105170208398001.conll
# Contagem de rótulos (original): {'O': 999, 'B-JURISPRUDENCIA': 3, 'I-JURISPRUDENCIA': 9, 'B-LOCAL': 1, 'I-LOCAL': 3, 'B-PESSOA': 8, 'I-PESSOA': 18, 'B-ORGANIZACAO': 7, 'I-ORGANIZACAO': 23, 'B-LEGISLACAO': 9, 'I-LEGISLACAO': 44, 'B-TEMPO': 4}
# Contagem de rótulos (simplificado): {'O': 999, 'JURISPRUDENCIA': 12, 'LOCAL': 4, 'PESSOA': 26, 'ORGANIZACAO': 30, 'LEGISLACAO': 53, 'TEMPO': 4}
#
# Documento: HC10000150589281000.conll
# Contagem de rótulos (original): {'O': 2216, 'B-LEGISLACAO': 12, 'I-LEGISLACAO': 72, 'B-PESSOA': 32, 'I-PESSOA': 68, 'B-TEMPO': 5, 'I-TEMPO': 8, 'B-LOCAL': 9, 'I-LOCAL': 20, 'B-ORGANIZACAO': 14, 'I-ORGANIZACAO': 32, 'B-JURISPRUDENCIA': 4, 'I-JURISPRUDENCIA': 18}
# Contagem de rótulos (simplificado): {'O': 2216, 'LEGISLACAO': 84, 'PESSOA': 100, 'TEMPO': 13, 'LOCAL': 29, 'ORGANIZACAO': 46, 'JURISPRUDENCIA': 22}
#
# Documento: ADI2TJDFT.conll
# Contagem de rótulos (original): {'O': 7685, 'B-ORGANIZACAO': 103, 'I-ORGANIZACAO': 215, 'B-JURISPRUDENCIA': 17, 'B-LOCAL': 144, 'I-LOCAL': 237, 'B-PESSOA': 62, 'I-PESSOA': 98, 'B-LEGISLACAO': 177, 'I-LEGISLACAO': 776, 'B-TEMPO': 84, 'I-TEMPO': 200, 'I-JURISPRUDENCIA': 13}
# Contagem de rótulos (simplificado): {'O': 7685, 'ORGANIZACAO': 318, 'JURISPRUDENCIA': 30, 'LOCAL': 381, 'PESSOA': 160, 'LEGISLACAO': 953, 'TEMPO': 284}
#
# Documento: AC1TJAC.conll
# Contagem de rótulos (original): {'O': 5932, 'B-LOCAL': 94, 'I-LOCAL': 163, 'B-ORGANIZACAO': 63, 'I-ORGANIZACAO': 130, 'B-JURISPRUDENCIA': 42, 'I-JURISPRUDENCIA': 89, 'B-PESSOA': 26, 'I-PESSOA': 52, 'B-LEGISLACAO': 28, 'I-LEGISLACAO': 166, 'B-TEMPO': 29, 'I-TEMPO': 29}
# Contagem de rótulos (simplificado): {'O': 5932, 'LOCAL': 257, 'ORGANIZACAO': 193, 'JURISPRUDENCIA': 131, 'PESSOA': 78, 'LEGISLACAO': 194, 'TEMPO': 58}
#
# Documento: AC1TCU.conll
# Contagem de rótulos (original): {'O': 4853, 'B-JURISPRUDENCIA': 41, 'I-JURISPRUDENCIA': 59, 'B-ORGANIZACAO': 117, 'B-PESSOA': 31, 'I-PESSOA': 87, 'B-TEMPO': 21, 'B-LEGISLACAO': 29, 'I-LEGISLACAO': 244, 'I-ORGANIZACAO': 176, 'I-TEMPO': 16, 'B-LOCAL': 1}
# Contagem de rótulos (simplificado): {'O': 4853, 'JURISPRUDENCIA': 100, 'ORGANIZACAO': 293, 'PESSOA': 118, 'TEMPO': 37, 'LEGISLACAO': 273, 'LOCAL': 1}
#
# Documento: AC20150110436469APC.conll
# Contagem de rótulos (original): {'O': 1404, 'B-ORGANIZACAO': 12, 'I-ORGANIZACAO': 45, 'B-JURISPRUDENCIA': 8, 'B-PESSOA': 13, 'I-PESSOA': 31, 'I-JURISPRUDENCIA': 25, 'B-LEGISLACAO': 11, 'I-LEGISLACAO': 94, 'B-LOCAL': 1, 'I-LOCAL': 3, 'B-TEMPO': 10, 'I-TEMPO': 4}
# Contagem de rótulos (simplificado): {'O': 1404, 'ORGANIZACAO': 57, 'JURISPRUDENCIA': 33, 'PESSOA': 44, 'LEGISLACAO': 105, 'LOCAL': 4, 'TEMPO': 14}
#
# Documento: EEDRR9715120105020002.conll
# Contagem de rótulos (original): {'O': 4064, 'B-LEGISLACAO': 60, 'I-LEGISLACAO': 267, 'B-ORGANIZACAO': 79, 'I-ORGANIZACAO': 116, 'B-JURISPRUDENCIA': 27, 'I-JURISPRUDENCIA': 71, 'B-PESSOA': 14, 'I-PESSOA': 15, 'B-TEMPO': 23, 'B-LOCAL': 1, 'I-TEMPO': 4}
# Contagem de rótulos (simplificado): {'O': 4064, 'LEGISLACAO': 327, 'ORGANIZACAO': 195, 'JURISPRUDENCIA': 98, 'PESSOA': 29, 'TEMPO': 27, 'LOCAL': 1}
#
# Documento: lei11340.conll
# Contagem de rótulos (original): {'O': 5133, 'B-ORGANIZACAO': 48, 'I-ORGANIZACAO': 100, 'B-LEGISLACAO': 42, 'I-LEGISLACAO': 204, 'B-TEMPO': 26, 'I-TEMPO': 41, 'B-JURISPRUDENCIA': 1, 'I-JURISPRUDENCIA': 2, 'B-LOCAL': 2, 'I-LOCAL': 1, 'B-PESSOA': 2, 'I-PESSOA': 5}
# Contagem de rótulos (simplificado): {'O': 5133, 'ORGANIZACAO': 148, 'LEGISLACAO': 246, 'TEMPO': 67, 'JURISPRUDENCIA': 3, 'LOCAL': 3, 'PESSOA': 7}
#
# Documento: AgRgSTJ1.conll
# Contagem de rótulos (original): {'B-ORGANIZACAO': 30, 'I-ORGANIZACAO': 54, 'B-JURISPRUDENCIA': 17, 'I-JURISPRUDENCIA': 71, 'O': 1835, 'B-PESSOA': 37, 'I-PESSOA': 77, 'B-LOCAL': 2, 'B-TEMPO': 16, 'I-TEMPO': 8, 'B-LEGISLACAO': 14, 'I-LEGISLACAO': 73}
# Contagem de rótulos (simplificado): {'ORGANIZACAO': 84, 'JURISPRUDENCIA': 88, 'O': 1835, 'PESSOA': 114, 'LOCAL': 2, 'TEMPO': 24, 'LEGISLACAO': 87}
#
# Documento: Port77DF.conll
# Contagem de rótulos (original): {'B-LEGISLACAO': 5, 'I-LEGISLACAO': 31, 'O': 519, 'B-TEMPO': 4, 'I-TEMPO': 16, 'B-LOCAL': 49, 'I-LOCAL': 40, 'B-ORGANIZACAO': 6, 'I-ORGANIZACAO': 12, 'B-PESSOA': 1, 'I-PESSOA': 3}
# Contagem de rótulos (simplificado): {'LEGISLACAO': 36, 'O': 519, 'TEMPO': 20, 'LOCAL': 89, 'ORGANIZACAO': 18, 'PESSOA': 4}
#
# Documento: RR-578030-46.1999.5.04.0018.conll
# Contagem de rótulos (original): {'O': 3264, 'B-ORGANIZACAO': 14, 'I-ORGANIZACAO': 42, 'B-JURISPRUDENCIA': 14, 'I-JURISPRUDENCIA': 31, 'B-LEGISLACAO': 60, 'I-LEGISLACAO': 353, 'B-PESSOA': 9, 'I-PESSOA': 15, 'B-TEMPO': 8, 'B-LOCAL': 1, 'I-TEMPO': 4}
# Contagem de rótulos (simplificado): {'O': 3264, 'ORGANIZACAO': 56, 'JURISPRUDENCIA': 45, 'LEGISLACAO': 413, 'PESSOA': 24, 'TEMPO': 12, 'LOCAL': 1}
#
# Documento: APO1TJDFT.conll
# Contagem de rótulos (original): {'O': 3087, 'B-ORGANIZACAO': 44, 'I-ORGANIZACAO': 57, 'B-JURISPRUDENCIA': 24, 'B-PESSOA': 34, 'I-PESSOA': 39, 'I-JURISPRUDENCIA': 20, 'B-LEGISLACAO': 48, 'B-LOCAL': 4, 'I-LOCAL': 6, 'I-LEGISLACAO': 196, 'B-TEMPO': 13, 'I-TEMPO': 16}
# Contagem de rótulos (simplificado): {'O': 3087, 'ORGANIZACAO': 101, 'JURISPRUDENCIA': 44, 'PESSOA': 73, 'LEGISLACAO': 244, 'LOCAL': 10, 'TEMPO': 29}
#
# Documento: ACORDAOTCU11602016.conll
# Contagem de rótulos (original): {'O': 20049, 'B-JURISPRUDENCIA': 67, 'I-JURISPRUDENCIA': 93, 'B-ORGANIZACAO': 352, 'B-PESSOA': 84, 'I-PESSOA': 229, 'B-TEMPO': 101, 'I-ORGANIZACAO': 530, 'B-LOCAL': 22, 'I-LOCAL': 48, 'B-LEGISLACAO': 70, 'I-LEGISLACAO': 503, 'I-TEMPO': 24}
# Contagem de rótulos (simplificado): {'O': 20049, 'JURISPRUDENCIA': 160, 'ORGANIZACAO': 882, 'PESSOA': 313, 'TEMPO': 125, 'LOCAL': 70, 'LEGISLACAO': 573}
#
# Documento: AIRR15708820115050222.conll
# Contagem de rótulos (original): {'O': 4805, 'B-ORGANIZACAO': 30, 'I-ORGANIZACAO': 55, 'B-LEGISLACAO': 39, 'I-LEGISLACAO': 221, 'B-JURISPRUDENCIA': 44, 'I-JURISPRUDENCIA': 92, 'B-PESSOA': 23, 'I-PESSOA': 44, 'B-TEMPO': 22, 'I-TEMPO': 5, 'B-LOCAL': 2, 'I-LOCAL': 1}
# Contagem de rótulos (simplificado): {'O': 4805, 'ORGANIZACAO': 85, 'LEGISLACAO': 260, 'JURISPRUDENCIA': 136, 'PESSOA': 67, 'TEMPO': 27, 'LOCAL': 3}
#
# Documento: HC340624SP.conll
# Contagem de rótulos (original): {'B-ORGANIZACAO': 38, 'I-ORGANIZACAO': 122, 'O': 3282, 'B-JURISPRUDENCIA': 25, 'I-JURISPRUDENCIA': 82, 'B-PESSOA': 45, 'I-PESSOA': 114, 'B-LEGISLACAO': 20, 'I-LEGISLACAO': 103, 'B-LOCAL': 4, 'I-LOCAL': 3, 'B-TEMPO': 14, 'I-TEMPO': 4}
# Contagem de rótulos (simplificado): {'ORGANIZACAO': 160, 'O': 3282, 'JURISPRUDENCIA': 107, 'PESSOA': 159, 'LEGISLACAO': 123, 'LOCAL': 7, 'TEMPO': 18}
#
# Documento: AIRR10006691020135020322.conll
# Contagem de rótulos (original): {'O': 2276, 'B-ORGANIZACAO': 8, 'I-ORGANIZACAO': 21, 'B-LEGISLACAO': 25, 'I-LEGISLACAO': 105, 'B-JURISPRUDENCIA': 10, 'I-JURISPRUDENCIA': 40, 'B-PESSOA': 11, 'I-PESSOA': 8, 'B-TEMPO': 3, 'B-LOCAL': 4, 'I-LOCAL': 5, 'I-TEMPO': 4}
# Contagem de rótulos (simplificado): {'O': 2276, 'ORGANIZACAO': 29, 'LEGISLACAO': 130, 'JURISPRUDENCIA': 50, 'PESSOA': 19, 'TEMPO': 7, 'LOCAL': 9}
#
# Documento: HC70000845920187000000.conll
# Contagem de rótulos (original): {'O': 2346, 'B-PESSOA': 13, 'I-PESSOA': 33, 'B-TEMPO': 29, 'B-ORGANIZACAO': 30, 'I-ORGANIZACAO': 74, 'B-LOCAL': 3, 'I-TEMPO': 64, 'B-LEGISLACAO': 4, 'I-LEGISLACAO': 24, 'B-JURISPRUDENCIA': 2, 'I-JURISPRUDENCIA': 5}
# Contagem de rótulos (simplificado): {'O': 2346, 'PESSOA': 46, 'TEMPO': 93, 'ORGANIZACAO': 104, 'LOCAL': 3, 'LEGISLACAO': 28, 'JURISPRUDENCIA': 7}
#
# Documento: AIRR3999520145020086.conll
# Contagem de rótulos (original): {'O': 681, 'B-ORGANIZACAO': 14, 'I-ORGANIZACAO': 18, 'B-LEGISLACAO': 13, 'I-LEGISLACAO': 68, 'B-JURISPRUDENCIA': 10, 'I-JURISPRUDENCIA': 4, 'B-PESSOA': 10, 'I-PESSOA': 21, 'B-TEMPO': 12, 'B-LOCAL': 1, 'I-TEMPO': 4}
# Contagem de rótulos (simplificado): {'O': 681, 'ORGANIZACAO': 32, 'LEGISLACAO': 81, 'JURISPRUDENCIA': 14, 'PESSOA': 31, 'TEMPO': 16, 'LOCAL': 1}
#
# Documento: REE5908TSE4.conll
# Contagem de rótulos (original): {'O': 5685, 'B-ORGANIZACAO': 34, 'I-ORGANIZACAO': 44, 'B-JURISPRUDENCIA': 47, 'I-JURISPRUDENCIA': 122, 'B-LOCAL': 7, 'I-LOCAL': 19, 'B-PESSOA': 43, 'I-PESSOA': 97, 'B-TEMPO': 34, 'B-LEGISLACAO': 62, 'I-LEGISLACAO': 559, 'I-TEMPO': 24}
# Contagem de rótulos (simplificado): {'O': 5685, 'ORGANIZACAO': 78, 'JURISPRUDENCIA': 169, 'LOCAL': 26, 'PESSOA': 140, 'TEMPO': 58, 'LEGISLACAO': 621}
#
# Documento: AIRR3731820145060141.conll
# Contagem de rótulos (original): {'O': 2970, 'B-ORGANIZACAO': 18, 'I-ORGANIZACAO': 72, 'B-LEGISLACAO': 22, 'I-LEGISLACAO': 98, 'B-JURISPRUDENCIA': 21, 'I-JURISPRUDENCIA': 110, 'B-TEMPO': 21, 'B-PESSOA': 8, 'I-PESSOA': 17, 'I-TEMPO': 8, 'B-LOCAL': 1}
# Contagem de rótulos (simplificado): {'O': 2970, 'ORGANIZACAO': 90, 'LEGISLACAO': 120, 'JURISPRUDENCIA': 131, 'TEMPO': 29, 'PESSOA': 25, 'LOCAL': 1}
#
# Documento: INSTRUCAOON06043378120186000000.conll
# Contagem de rótulos (original): {'B-ORGANIZACAO': 5, 'I-ORGANIZACAO': 10, 'O': 238, 'B-LEGISLACAO': 9, 'I-LEGISLACAO': 34, 'B-LOCAL': 1, 'I-LOCAL': 3, 'B-PESSOA': 12, 'I-PESSOA': 20, 'B-TEMPO': 4, 'I-TEMPO': 4}
# Contagem de rótulos (simplificado): {'ORGANIZACAO': 15, 'O': 238, 'LEGISLACAO': 43, 'LOCAL': 4, 'PESSOA': 32, 'TEMPO': 8}
#
# Documento: REsp1583083RS.conll
# Contagem de rótulos (original): {'B-ORGANIZACAO': 143, 'I-ORGANIZACAO': 258, 'O': 4337, 'B-JURISPRUDENCIA': 49, 'I-JURISPRUDENCIA': 91, 'B-PESSOA': 66, 'I-PESSOA': 116, 'B-LEGISLACAO': 65, 'I-LEGISLACAO': 331, 'B-TEMPO': 15, 'I-TEMPO': 12, 'B-LOCAL': 1}
# Contagem de rótulos (simplificado): {'ORGANIZACAO': 401, 'O': 4337, 'JURISPRUDENCIA': 140, 'PESSOA': 182, 'LEGISLACAO': 396, 'TEMPO': 27, 'LOCAL': 1}
#
# Documento: HC10000170833503000.conll
# Contagem de rótulos (original): {'O': 2032, 'B-TEMPO': 14, 'I-TEMPO': 12, 'B-LEGISLACAO': 20, 'I-LEGISLACAO': 118, 'B-JURISPRUDENCIA': 1, 'I-JURISPRUDENCIA': 4, 'B-LOCAL': 1, 'I-LOCAL': 2, 'B-PESSOA': 10, 'I-PESSOA': 25, 'B-ORGANIZACAO': 4, 'I-ORGANIZACAO': 24}
# Contagem de rótulos (simplificado): {'O': 2032, 'TEMPO': 26, 'LEGISLACAO': 138, 'JURISPRUDENCIA': 5, 'LOCAL': 3, 'PESSOA': 35, 'ORGANIZACAO': 28}
#
# Documento: RR14976020105020085.conll
# Contagem de rótulos (original): {'O': 4475, 'B-ORGANIZACAO': 26, 'I-ORGANIZACAO': 53, 'B-LEGISLACAO': 105, 'I-LEGISLACAO': 619, 'B-JURISPRUDENCIA': 36, 'I-JURISPRUDENCIA': 120, 'B-PESSOA': 18, 'I-PESSOA': 57, 'B-TEMPO': 23, 'B-LOCAL': 2, 'I-LOCAL': 3, 'I-TEMPO': 8}
# Contagem de rótulos (simplificado): {'O': 4475, 'ORGANIZACAO': 79, 'LEGISLACAO': 724, 'JURISPRUDENCIA': 156, 'PESSOA': 75, 'TEMPO': 31, 'LOCAL': 5}
#
# Documento: Ag10000170733596001.conll
# Contagem de rótulos (original): {'O': 1246, 'B-LEGISLACAO': 4, 'I-LEGISLACAO': 28, 'B-TEMPO': 18, 'B-JURISPRUDENCIA': 1, 'I-JURISPRUDENCIA': 4, 'B-LOCAL': 1, 'I-LOCAL': 2, 'B-ORGANIZACAO': 8, 'I-ORGANIZACAO': 68, 'B-PESSOA': 4, 'I-PESSOA': 9}
# Contagem de rótulos (simplificado): {'O': 1246, 'LEGISLACAO': 32, 'TEMPO': 18, 'JURISPRUDENCIA': 5, 'LOCAL': 3, 'ORGANIZACAO': 76, 'PESSOA': 13}
#
# Documento: airr801422012.conll
# Contagem de rótulos (original): {'O': 2634, 'B-ORGANIZACAO': 33, 'I-ORGANIZACAO': 27, 'B-LEGISLACAO': 36, 'I-LEGISLACAO': 187, 'B-JURISPRUDENCIA': 35, 'I-JURISPRUDENCIA': 116, 'B-TEMPO': 18, 'B-PESSOA': 7, 'I-PESSOA': 10, 'B-LOCAL': 2, 'I-LOCAL': 1, 'I-TEMPO': 8}
# Contagem de rótulos (simplificado): {'O': 2634, 'ORGANIZACAO': 60, 'LEGISLACAO': 223, 'JURISPRUDENCIA': 151, 'TEMPO': 26, 'PESSOA': 17, 'LOCAL': 3}
#
# Documento: ACO2821STF.conll
# Contagem de rótulos (original): {'O': 8217, 'B-TEMPO': 73, 'B-JURISPRUDENCIA': 75, 'I-JURISPRUDENCIA': 208, 'B-LOCAL': 27, 'I-LOCAL': 50, 'B-PESSOA': 67, 'I-PESSOA': 77, 'B-ORGANIZACAO': 265, 'I-ORGANIZACAO': 394, 'B-LEGISLACAO': 140, 'I-LEGISLACAO': 419, 'I-TEMPO': 47}
# Contagem de rótulos (simplificado): {'O': 8217, 'TEMPO': 120, 'JURISPRUDENCIA': 283, 'LOCAL': 77, 'PESSOA': 144, 'ORGANIZACAO': 659, 'LEGISLACAO': 559}
#
# Documento: EDAgRgTSE2.conll
# Contagem de rótulos (original): {'B-ORGANIZACAO': 15, 'I-ORGANIZACAO': 18, 'O': 1495, 'B-JURISPRUDENCIA': 14, 'I-JURISPRUDENCIA': 37, 'B-LOCAL': 5, 'I-LOCAL': 7, 'B-PESSOA': 20, 'I-PESSOA': 37, 'B-TEMPO': 22, 'I-TEMPO': 16, 'B-LEGISLACAO': 13, 'I-LEGISLACAO': 74}
# Contagem de rótulos (simplificado): {'ORGANIZACAO': 33, 'O': 1495, 'JURISPRUDENCIA': 51, 'LOCAL': 12, 'PESSOA': 57, 'TEMPO': 38, 'LEGISLACAO': 87}
#
# Documento: AP00001441420167030203.conll
# Contagem de rótulos (original): {'O': 19950, 'B-PESSOA': 148, 'I-PESSOA': 376, 'B-TEMPO': 131, 'B-ORGANIZACAO': 170, 'I-ORGANIZACAO': 216, 'B-JURISPRUDENCIA': 105, 'I-JURISPRUDENCIA': 297, 'B-LEGISLACAO': 149, 'I-LEGISLACAO': 1035, 'B-LOCAL': 20, 'I-TEMPO': 33, 'I-LOCAL': 10}
# Contagem de rótulos (simplificado): {'O': 19950, 'PESSOA': 524, 'TEMPO': 164, 'ORGANIZACAO': 386, 'JURISPRUDENCIA': 402, 'LEGISLACAO': 1184, 'LOCAL': 30}
#
# Documento: AgRgSTJ2.conll
# Contagem de rótulos (original): {'B-ORGANIZACAO': 43, 'I-ORGANIZACAO': 80, 'B-JURISPRUDENCIA': 49, 'I-JURISPRUDENCIA': 150, 'O': 3897, 'B-PESSOA': 71, 'I-PESSOA': 133, 'B-TEMPO': 40, 'B-LEGISLACAO': 36, 'I-LEGISLACAO': 298, 'B-LOCAL': 2, 'I-TEMPO': 4}
# Contagem de rótulos (simplificado): {'ORGANIZACAO': 123, 'JURISPRUDENCIA': 199, 'O': 3897, 'PESSOA': 204, 'TEMPO': 44, 'LEGISLACAO': 334, 'LOCAL': 2}
#
# Documento: RR474820145230056.conll
# Contagem de rótulos (original): {'O': 308, 'B-ORGANIZACAO': 4, 'I-ORGANIZACAO': 11, 'B-LEGISLACAO': 6, 'I-LEGISLACAO': 34, 'B-JURISPRUDENCIA': 2, 'I-JURISPRUDENCIA': 4, 'B-PESSOA': 2, 'I-PESSOA': 4, 'B-LOCAL': 1, 'B-TEMPO': 2, 'I-TEMPO': 4}
# Contagem de rótulos (simplificado): {'O': 308, 'ORGANIZACAO': 15, 'LEGISLACAO': 40, 'JURISPRUDENCIA': 6, 'PESSOA': 6, 'LOCAL': 1, 'TEMPO': 6}
#
# Documento: HC151914AgRES.conll
# Contagem de rótulos (original): {'O': 2772, 'B-TEMPO': 45, 'B-JURISPRUDENCIA': 52, 'I-JURISPRUDENCIA': 110, 'B-LOCAL': 15, 'I-LOCAL': 15, 'B-PESSOA': 98, 'I-PESSOA': 175, 'B-ORGANIZACAO': 98, 'I-ORGANIZACAO': 173, 'B-LEGISLACAO': 33, 'I-LEGISLACAO': 198, 'I-TEMPO': 8}
# Contagem de rótulos (simplificado): {'O': 2772, 'TEMPO': 53, 'JURISPRUDENCIA': 162, 'LOCAL': 30, 'PESSOA': 273, 'ORGANIZACAO': 271, 'LEGISLACAO': 231}
#
# Documento: adi3767.conll
# Contagem de rótulos (original): {'O': 3816, 'B-TEMPO': 56, 'B-ORGANIZACAO': 93, 'B-JURISPRUDENCIA': 26, 'I-JURISPRUDENCIA': 97, 'B-LOCAL': 20, 'B-PESSOA': 57, 'I-PESSOA': 79, 'I-LOCAL': 26, 'I-ORGANIZACAO': 193, 'I-TEMPO': 76, 'B-LEGISLACAO': 69, 'I-LEGISLACAO': 369}
# Contagem de rótulos (simplificado): {'O': 3816, 'TEMPO': 132, 'ORGANIZACAO': 286, 'JURISPRUDENCIA': 123, 'LOCAL': 46, 'PESSOA': 136, 'LEGISLACAO': 438}
#
# Total de documentos: 70

# %%
# labels_por_doc['HAREMdoc_aa64686'][-12]
# len(labels_por_doc['HAREMdoc_aa64686'])

# %%
lbl_list = []
for lbl in labels_por_doc.values():
    lbl_list.extend(lbl)  # Adiciona os rótulos de cada documento à lista

# Obtendo os rótulos únicos
unique_lbl_list = list(set(lbl_list))

# Exibindo a lista de rótulos únicos
print(unique_lbl_list)
# Out:
# ['B-PESSOA', 'B-LOCAL', 'I-LEGISLACAO', 'I-LOCAL', 'B-LEGISLACAO', 'I-TEMPO', 'O', 'B-TEMPO', 'I-ORGANIZACAO', 'I-PESSOA', 'B-JURISPRUDENCIA', 'B-ORGANIZACAO', 'I-JURISPRUDENCIA']

# %%
unique_lbl_list.pop(unique_lbl_list.index('O'))
unique_lbl_list
# Out:
# ['B-PESSOA',
#  'B-LOCAL',
#  'I-LEGISLACAO',
#  'I-LOCAL',
#  'B-LEGISLACAO',
#  'I-TEMPO',
#  'B-TEMPO',
#  'I-ORGANIZACAO',
#  'I-PESSOA',
#  'B-JURISPRUDENCIA',
#  'B-ORGANIZACAO',
#  'I-JURISPRUDENCIA']

# %%
unique_lbl_list = sorted(unique_lbl_list)
unique_lbl_list
# Out:
# ['B-JURISPRUDENCIA',
#  'B-LEGISLACAO',
#  'B-LOCAL',
#  'B-ORGANIZACAO',
#  'B-PESSOA',
#  'B-TEMPO',
#  'I-JURISPRUDENCIA',
#  'I-LEGISLACAO',
#  'I-LOCAL',
#  'I-ORGANIZACAO',
#  'I-PESSOA',
#  'I-TEMPO']

# %%
#test_l = ['LOCAL', 'ORGANIZACAO', 'PESSOA', 'TEMPO', 'LOCAL', 'ORGANIZACAO', 'PESSOA', 'TEMPO', 'LOCAL', 'ORGANIZACAO', 'PESSOA', 'TEMPO', 'TEMPO', 'TEMPO']
#[test_l.count(x) for x in unique_lbl_list]

# %%
from collections import Counter

initial_set = []
for s_idx, s_labels in enumerate(list(labels_por_doc.values())):
    # Contagem eficiente dos rótulos usando Counter
    label_count = Counter(s_labels)
    
    # Adicionando o índice do documento e as contagens para cada rótulo em unique_lbl_list
    initial_set.append([s_idx] + [label_count.get(x, 0) for x in unique_lbl_list])

# Verificando o tamanho de initial_set (número de documentos)
print(len(initial_set))
# Out:
# 70

# %%
# initial_set[:, 1:]

# %%
# Adicionando a linha final com os totais de cada label (soma dos rótulos)
initial_set.append(['-'] + [sum(x) for x in zip(*(row[1:] for row in initial_set))])

# Agora vamos filtrar a matriz para manter apenas as 7 primeiras colunas
# (assumindo que as 7 primeiras colunas correspondem aos rótulos -B)
filtered_initial_set = []

for row in initial_set:
    # Mantendo apenas as 7 primeiras colunas (a primeira coluna é '-')
    filtered_row = row[:7]  # Considerando que as primeiras 7 colunas são os rótulos -B
    filtered_initial_set.append(filtered_row)

# Exibindo a matriz resultante filtrada
for row in filtered_initial_set:
    print(row)
# Out:
# [0, 52, 158, 3, 63, 36, 74]
# [1, 23, 48, 1, 41, 2, 5]
# [2, 6, 28, 3, 12, 19, 9]
# [3, 3, 24, 4, 19, 52, 6]
# [4, 4, 17, 8, 20, 22, 23]
# [5, 0, 17, 1, 5, 3, 15]
# [6, 7, 33, 1, 11, 5, 5]
# [7, 79, 124, 62, 168, 113, 56]
# [8, 29, 35, 2, 46, 30, 37]
# [9, 13, 10, 1, 69, 22, 18]
# [10, 34, 8, 3, 16, 36, 29]
# [11, 18, 29, 1, 58, 30, 18]
# [12, 1, 10, 4, 15, 26, 32]
# [13, 11, 136, 5, 28, 7, 37]
# [14, 12, 3, 2, 17, 18, 8]
# [15, 3, 41, 46, 69, 37, 25]
# [16, 5, 12, 30, 21, 49, 24]
# [17, 19, 40, 1, 9, 14, 16]
# [18, 63, 117, 11, 232, 96, 60]
# [19, 6, 7, 1, 9, 2, 5]
# [20, 18, 8, 3, 28, 16, 20]
# [21, 8, 18, 6, 42, 38, 30]
# [22, 15, 44, 4, 35, 25, 53]
# [23, 0, 12, 4, 12, 1, 7]
# [24, 8, 11, 1, 10, 13, 10]
# [25, 58, 29, 67, 52, 26, 23]
# [26, 6, 9, 1, 24, 19, 20]
# [27, 15, 79, 1, 10, 6, 6]
# [28, 39, 30, 5, 134, 45, 12]
# [29, 2, 8, 3, 9, 7, 11]
# [30, 5, 17, 12, 68, 48, 76]
# [31, 14, 10, 1, 55, 65, 16]
# [32, 8, 18, 1, 10, 8, 5]
# [33, 17, 7, 13, 32, 33, 7]
# [34, 4, 21, 1, 5, 2, 2]
# [35, 2, 17, 2, 11, 3, 4]
# [36, 20, 25, 1, 29, 8, 16]
# [37, 3, 9, 1, 7, 8, 4]
# [38, 4, 12, 9, 14, 32, 5]
# [39, 17, 177, 144, 103, 62, 84]
# [40, 42, 28, 94, 63, 26, 29]
# [41, 41, 29, 1, 117, 31, 21]
# [42, 8, 11, 1, 12, 13, 10]
# [43, 27, 60, 1, 79, 14, 23]
# [44, 1, 42, 2, 48, 2, 26]
# [45, 17, 14, 2, 30, 37, 16]
# [46, 0, 5, 49, 6, 1, 4]
# [47, 14, 60, 1, 14, 9, 8]
# [48, 24, 48, 4, 44, 34, 13]
# [49, 67, 70, 22, 352, 84, 101]
# [50, 44, 39, 2, 30, 23, 22]
# [51, 25, 20, 4, 38, 45, 14]
# [52, 10, 25, 4, 8, 11, 3]
# [53, 2, 4, 3, 30, 13, 29]
# [54, 10, 13, 1, 14, 10, 12]
# [55, 47, 62, 7, 34, 43, 34]
# [56, 21, 22, 1, 18, 8, 21]
# [57, 0, 9, 1, 5, 12, 4]
# [58, 49, 65, 1, 143, 66, 15]
# [59, 1, 20, 1, 4, 10, 14]
# [60, 36, 105, 2, 26, 18, 23]
# [61, 1, 4, 1, 8, 4, 18]
# [62, 35, 36, 2, 33, 7, 18]
# [63, 75, 140, 27, 265, 67, 73]
# [64, 14, 13, 5, 15, 20, 22]
# [65, 105, 149, 20, 170, 148, 131]
# [66, 49, 36, 2, 43, 71, 40]
# [67, 2, 6, 1, 4, 2, 2]
# [68, 52, 33, 15, 98, 98, 45]
# [69, 26, 69, 20, 93, 57, 56]
# ['-', 1496, 2695, 767, 3462, 2068, 1760]

# %%
# list(labels_por_doc.keys())

# %%
#initial_set[-1] = initial_set[-1][:7]  # Isso mantém as 7 primeiras colunas, incluindo '-'

# Exibindo a última linha após a atualização
print(filtered_initial_set[-1])
# Out:
# ['-', 1496, 2695, 767, 3462, 2068, 1760]

# %%
len(filtered_initial_set)
# Out:
# 71

# %%
number_divisions = 10
result = [x / number_divisions for x in filtered_initial_set[-1][1:]]
print(result)
# Out:
# [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]

# %%
sub_set = [[['-'] + [x/number_divisions for x in filtered_initial_set[-1][1:]]] for i in range(number_divisions)]
sub_set
# Out:
# [[['-', 149.6, 269.5, 76.7, 346.2, 206.8, 176.0]],
#  [['-', 149.6, 269.5, 76.7, 346.2, 206.8, 176.0]],
#  [['-', 149.6, 269.5, 76.7, 346.2, 206.8, 176.0]],
#  [['-', 149.6, 269.5, 76.7, 346.2, 206.8, 176.0]],
#  [['-', 149.6, 269.5, 76.7, 346.2, 206.8, 176.0]],
#  [['-', 149.6, 269.5, 76.7, 346.2, 206.8, 176.0]],
#  [['-', 149.6, 269.5, 76.7, 346.2, 206.8, 176.0]],
#  [['-', 149.6, 269.5, 76.7, 346.2, 206.8, 176.0]],
#  [['-', 149.6, 269.5, 76.7, 346.2, 206.8, 176.0]],
#  [['-', 149.6, 269.5, 76.7, 346.2, 206.8, 176.0]]]

# %% [markdown]
# ##
# ITERATIVE STRATIFICATION
#
# - while there're still sentences in the initial_set
#     - update number of each label in the initial_set
#     - select label in initial_set that has fewest (at least 1) example
#     - then for each sentences that contains this label,
#         - find the subset that desires it more and add it to it
#         - update the desired number of each label for the subset

# %%
# initial_set_l = [x for x in initial_set[:-1] if x[2] > 0]
# len(initial_set_l)
# 12168 - 2734
# for sentence in initial_set_l:
#     initial_set.pop(initial_set.index(sentence))

# %%
# len(initial_set)
# initial_set[-1]
# initial_set[-1] = ['-'] + [ sum(x) for x in zip(*(row[1:] for row in initial_set[:-1])) ]
# initial_set[-1]

# %%
while len(filtered_initial_set) > 1:
    print(f"\nTamanho atual de filtered_initial_set: {len(filtered_initial_set)}")
    contador = 0

    try:
        # Identificar o índice da label com menor quantidade
        min_lbl_idx = filtered_initial_set[-1].index(min((i for i in filtered_initial_set[-1][1:] if i > 0)))
        print(f"Label com menor quantidade: {min_lbl_idx} (quantidade: {filtered_initial_set[-1][min_lbl_idx]})")

        # Filtrar as sentenças relevantes
        initial_set_l = [x for x in filtered_initial_set[:-1] if x[min_lbl_idx] > 0]

        # Ordenar as sentenças pela quantidade da palavra desejada (min_lbl_idx), em ordem decrescente
        initial_set_l.sort(key=lambda x: x[min_lbl_idx], reverse=True)

        print(f"\nSentenças ordenadas pela quantidade da palavra desejada (label {min_lbl_idx}):")
        for idx, item in enumerate(initial_set_l):
            print(f"  {idx + 1}: {item}")

        # Inicializar o índice das partições
        partition_order = list(range(10))  # 10 partições

        for sentence in initial_set_l:
            partition_found = False

            # Ordenar as partições pela quantidade de desejo da min_lbl_idx, em ordem decrescente
            sorted_partitions = sorted(partition_order, key=lambda idx: sub_set[idx][0][min_lbl_idx], reverse=True)

            for partition_idx in sorted_partitions:
                current_partition_desires = sub_set[partition_idx][0][1:]
                potential_desires = [
                    current - count
                    for current, count in zip(current_partition_desires, sentence[1:])
                ]

                # Verificar se algum desejo se torna negativo
                if all(potential >= 0 for potential in potential_desires):
                    # Se a partição permitir a adição sem causar desejos negativos, adicione a sentença
                    sub_set[partition_idx].append(sentence)
                    filtered_initial_set.pop(filtered_initial_set.index(sentence))

                    # Atualizar o desejo de cada label na partição
                    sub_set[partition_idx][0][1:] = [
                        current - count for current, count in zip(sub_set[partition_idx][0][1:], sentence[1:])
                    ]

                    # Atualizar os valores em filtered_initial_set
                    filtered_initial_set[-1] = ['-'] + [sum(x) for x in zip(*(row[1:] for row in filtered_initial_set[:-1]))]

                    # Imprimir status atualizado
                    total_entities_in_partition = sum(
                        sum(doc[1:]) for doc in sub_set[partition_idx][1:]
                    )
                    print(f"\nSentença adicionada: {sentence}")
                    print(f"Partição {partition_idx} agora tem {total_entities_in_partition} entidades.")

                    # Imprimir o desejo de cada partição
                    print("\nDesejo de cada partição após adicionar a sentença:")
                    for i, partition in enumerate(sub_set):
                        print(f"Partição {i}: {partition[0][1:]}")

                    partition_found = True
                    break  # Sentença adicionada, pode sair do loop

            if not partition_found:
                # Caso a sentença não tenha sido alocada sem negativos, vamos escolher a partição com o menor número de entidades negativas
                best_negative_count = float('inf')  # Maior soma de negativos
                best_negative_sum = float('inf')   # Soma dos negativos
                best_partition_idx = None

                for partition_idx in sorted_partitions:
                    current_partition_desires = sub_set[partition_idx][0][1:]
                    potential_desires = [
                        current - count
                        for current, count in zip(current_partition_desires, sentence[1:])
                    ]

                    # Contar quantos desejos se tornam negativos
                    negative_count = sum(1 for desire in potential_desires if desire < 0)

                    # Calcular a soma dos valores negativos
                    negative_sum = sum(1 for desire in potential_desires if desire < 0)

                    # Se o número de negativos for menor, ou se for igual e a soma dos negativos for maior, escolher esta partição
                    if negative_count < best_negative_count or (negative_count == best_negative_count and negative_sum > best_negative_sum):
                        best_negative_count = negative_count
                        best_negative_sum = negative_sum
                        best_partition_idx = partition_idx

                if best_partition_idx is not None:
                    # Adicionar a sentença na partição com o menor impacto negativo
                    sub_set[best_partition_idx].append(sentence)
                    sub_set[best_partition_idx][0][1:] = [
                        current - count for current, count in zip(sub_set[best_partition_idx][0][1:], sentence[1:])
                    ]
                    filtered_initial_set.pop(filtered_initial_set.index(sentence))

                    # Atualizar os valores em filtered_initial_set
                    filtered_initial_set[-1] = ['-'] + [sum(x) for x in zip(*(row[1:] for row in filtered_initial_set[:-1]))]

                    # Imprimir status atualizado
                    total_entities_in_partition = sum(
                        sum(doc[1:]) for doc in sub_set[best_partition_idx][1:]
                    )
                    print(f"\nSentença adicionada (com negativos): {sentence}")
                    print(f"Partição {best_partition_idx} agora tem {total_entities_in_partition} entidades.")

                    # Imprimir o desejo de cada partição
                    print("\nDesejo de cada partição após adicionar a sentença:")
                    for i, partition in enumerate(sub_set):
                        print(f"Partição {i}: {partition[0][1:]}")

            contador += 1

        # Recalcular a label com menor quantidade após a alocação das sentenças
        min_lbl_idx = filtered_initial_set[-1].index(min((i for i in filtered_initial_set[-1][1:] if i > 0)))

    except ValueError:
        # Caso ValueError, processar as sentenças restantes sem basear-se na label
        initial_set_l = filtered_initial_set[:-1]

        print(f"\nConteúdo de initial_set_l (ValueError handler, {len(initial_set_l)} elementos):")
        for idx, item in enumerate(initial_set_l):
            print(f"  {idx + 1}: {item}")

        for sentence in initial_set_l:
            # Verificar os tamanhos das partições
            partition_sizes = [sum(sum(doc[1:]) for doc in partition[1:]) for partition in sub_set]
            partitions_below_limit = [i for i, size in enumerate(partition_sizes) if size < 1225]

            # Escolher a partição com menor valor total
            if partitions_below_limit:
                target_partition_idx = min(partitions_below_limit, key=lambda i: partition_sizes[i])
            else:
                target_partition_idx = partition_sizes.index(min(partition_sizes))

            # Adicionar a sentença na partição escolhida
            sub_set[target_partition_idx].append(sentence)
            filtered_initial_set.pop(filtered_initial_set.index(sentence))

            # Atualizar os valores em filtered_initial_set
            filtered_initial_set[-1] = ['-'] + [sum(x) for x in zip(*(row[1:] for row in filtered_initial_set[:-1]))]

            # Imprimir status atualizado
            total_entities_in_partition = partition_sizes[target_partition_idx] + sum(sentence[1:])
            print(f"\nSentença adicionada: {sentence}")
            print(f"Partição {target_partition_idx} agora tem {total_entities_in_partition} entidades.")

    print(f"\nEstado atualizado de filtered_initial_set: {filtered_initial_set[-1]}")
    print(f"Total de sentenças processadas nesta iteração: {contador}")
# Out:
# Tamanho atual de filtered_initial_set: 71
# Label com menor quantidade: 3 (quantidade: 767)
#
# Sentenças ordenadas pela quantidade da palavra desejada (label
#   53: [26, 6, 9, 1, 24, 19, 20]
#   54: [27, 15, 79, 1, 10, 6, 6]
#   55: [31, 14, 10, 1, 55, 65, 16]
#   56: [32, 8, 18, 1, 10, 8, 5]
#   57: [34, 4, 21, 1, 5, 2, 2]
#   58: [36, 20, 25, 1, 29, 8, 16]
#   59: [37, 3, 9, 1, 7, 8, 4]
#   60: [41, 41, 29, 1, 117, 31, 21]
#   61: [42, 8, 11, 1, 12, 13, 10]
#   62: [43, 27, 60, 1, 79, 14, 23]
#   63: [47, 14, 60, 1, 14, 9, 8]
#   64: [54, 10, 13, 1, 14, 10, 12]
#   65: [56, 21, 22, 1, 18, 8, 21]
#   66: [57, 0, 9, 1, 5, 12, 4]
#   67: [58, 49, 65, 1, 143, 66, 15]
#   68: [59, 1, 20, 1, 4, 10, 14]
#   69: [61, 1, 4, 1, 8, 4, 18]
#   70: [67, 2, 6, 1, 4, 2, 2]
#
# Sentença adicionada (com negativos): [39, 17, 177, 144, 103, 62, 84]
# Partição 0 agora tem 587 entidades.
#
# Desejo de cada partição após adicionar a sentença:
# Partição 0: [132.6, 92.5, -67.3, 243.2, 144.8, 92.0]
# Partição 1: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 2: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 3: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 4: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 5: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 6: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 7: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 8: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 9: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
#
# Sentença adicionada (com negativos): [40, 42, 28, 94, 63, 26, 29]
# Partição 1 agora tem 282 entidades.
#
# Desejo de cada partição após adicionar a sentença:
# Partição 0: [132.6, 92.5, -67.3, 243.2, 144.8, 92.0]
# Partição 1: [107.6, 241.5, -17.299999999999997, 283.2, 180.8, 147.0]
# Partição 2: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 3: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 4: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 5: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 6: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 7: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 8: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 9: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
#
# Sentença adicionada: [25, 58, 29, 67, 52, 26, 23]
# Partição 2 agora tem 255 entidades.
#
# Desejo de cada partição após adicionar a sentença:
# Partição 0: [132.6, 92.5, -67.3, 243.2, 144.8, 92.0]
# Partição 1: [107.6, 241.5, -17.299999999999997, 283.2, 180.8, 147.0]
# Partição 2: [91.6, 240.5, 9.700000000000003, 294.2, 180.8, 153.0]
# Partição 3: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 4: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 5: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 6: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 7: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 8: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 9: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
#
# Sentença adicionada: [7, 79, 124, 62, 168, 113, 56]
# Partição 3 agora tem 602 entidades.
#
# Desejo de cada partição após adicionar a sentença:
# Partição 0: [132.6, 92.5, -67.3, 243.2, 144.8, 92.0]
# Partição 1: [107.6, 241.5, -17.299999999999997, 283.2, 180.8, 147.0]
# Partição 2: [91.6, 240.5, 9.700000000000003, 294.2, 180.8, 153.0]
# Partição 3: [70.6, 145.5, 14.700000000000003, 178.2, 93.80000000000001, 120.0]
# Partição 4: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 5: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 6: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 7: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 8: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 9: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
#
# Sentença adicionada: [46, 0, 5, 49, 6, 1, 4]
# Partição 4 agora tem 65 entidades.
#
# Desejo de cada partição após adicionar a sentença:
# Partição 0: [132.6, 92.5, -67.3, 243.2, 144.8, 92.0]
# Partição 1: [107.6, 241.5, -17.299999999999997, 283.2, 180.8, 147.0]
# Partição 2: [91.6, 240.5, 9.700000000000003, 294.2, 180.8, 153.0]
# Partição 3: [70.6, 145.5, 14.700000000000003, 178.2, 93.80000000000001, 120.0]
# Partição 4: [149.6, 264.5, 27.700000000000003, 340.2, 205.8, 172.0]
# Partição 5: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 6: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 7: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 8: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 9: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
#
# Sentença adicionada: [15, 3, 41, 46, 69, 37, 25]
# Partição 5 agora tem 221 entidades.
#
# Desejo de cada partição após adicionar a sentença:
# Partição 0: [132.6, 92.5, -67.3, 243.2, 144.8, 92.0]
# Partição 1: [107.6, 241.5, -17.299999999999997, 283.2, 180.8, 147.0]
# Partição 2: [91.6, 240.5, 9.700000000000003, 294.2, 180.8, 153.0]
# Partição 3: [70.6, 145.5, 14.700000000000003, 178.2, 93.80000000000001, 120.0]
# Partição 4: [149.6, 264.5, 27.700000000000003, 340.2, 205.8, 172.0]
# Partição 5: [146.6, 228.5, 30.700000000000003, 277.2, 169.8, 151.0]
# Partição 6: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 7: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 8: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 9: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
#
# Sentença adicionada: [16, 5, 12, 30, 21, 49, 24]
# Partição 6 agora tem 141 entidades.
#
# Desejo de cada partição após adicionar a sentença:
# Partição 0: [132.6, 92.5, -67.3, 243.2, 144.8, 92.0]
# Partição 1: [107.6, 241.5, -17.299999999999997, 283.2, 180.8, 147.0]
# Partição 2: [91.6, 240.5, 9.700000000000003, 294.2, 180.8, 153.0]
# Partição 3: [70.6, 145.5, 14.700000000000003, 178.2, 93.80000000000001, 120.0]
# Partição 4: [149.6, 264.5, 27.700000000000003, 340.2, 205.8, 172.0]
# Partição 5: [146.6, 228.5, 30.700000000000003, 277.2, 169.8, 151.0]
# Partição 6: [144.6, 257.5, 46.7, 325.2, 157.8, 152.0]
# Partição 7: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 8: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 9: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
#
# Sentença adicionada: [63, 75, 140, 27, 265, 67, 73]
# Partição 7 agora tem 647 entidades.
#
# Desejo de cada partição após adicionar a sentença:
# Partição 0: [132.6, 92.5, -67.3, 243.2, 144.8, 92.0]
# Partição 1: [107.6, 241.5, -17.299999999999997, 283.2, 180.8, 147.0]
# Partição 2: [91.6, 240.5, 9.700000000000003, 294.2, 180.8, 153.0]
# Partição 3: [70.6, 145.5, 14.700000000000003, 178.2, 93.80000000000001, 120.0]
# Partição 4: [149.6, 264.5, 27.700000000000003, 340.2, 205.8, 172.0]
# Partição 5: [146.6, 228.5, 30.700000000000003, 277.2, 169.8, 151.0]
# Partição 6: [144.6, 257.5, 46.7, 325.2, 157.8, 152.0]
# Partição 7: [74.6, 129.5, 49.7, 81.19999999999999, 139.8, 103.0]
# Partição 8: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
# Partição 9: [149.6, 269.5, 76.7, 346.2, 206.8, 176.0]
#
# Sentença adicionada (com negativos): [49, 67, 70, 22, 352, 84, 101]
# Partição 8 agora tem 696 entidades.
#
# Desejo de cada partição após adicionar a sentença:
# Partição 0: [132.6, 92.5, -67.3, 243.2, 144.8, 92.0]
# Partição 1: [107.6, 241.5, -17.299999999999997, 283.2, 180.8, 147.0]
# Partição 2: [91.6, 240.5, 9.700000000000003, 294.2, 180.8, 153.0]
# Partição 3: [70.6, 145.5, 14.700000000000003, 178.2, 93.80000000000001, 120.0]
# Partição 4:
# Conteúdo de initial_set_l (ValueError handler, 0 elementos):
#
# Estado atualizado de filtered_initial_set: ['-']
# Total de sentenças processadas nesta iteração: 70

# %%
filtered_initial_set
# Out:
# [['-']]

# %%
for sub in sub_set:
    print('tam: {} - lbs:{}'.format(len(sub[1:]), sub[0]))
# Out:
# tam: 6 - lbs:['-', 18.599999999999994, -58.5, -74.3, 77.19999999999999, 27.80000000000001, 4.0]
# tam: 7 - lbs:['-', -58.400000000000006, -49.5, -25.299999999999997, 24.19999999999999, 59.80000000000001, 68.0]
# tam: 10 - lbs:['-', -14.400000000000006, 10.5, -9.299999999999997, 112.19999999999999, 18.80000000000001, 5.0]
# tam: 5 - lbs:['-', -35.400000000000006, 34.5, 1.7000000000000028, -146.8, -29.19999999999999, 45.0]
# tam: 7 - lbs:['-', 27.599999999999994, 47.5, -0.29999999999999716, -10.800000000000011, 0.8000000000000114, 12.0]
# tam: 7 - lbs:['-', 57.599999999999994, 3.5, -0.29999999999999716, 99.19999999999999, -20.19999999999999, 34.0]
# tam: 7 - lbs:['-', 11.599999999999994, 0.5, 4.700000000000003, 15.199999999999989, -78.19999999999999, -35.0]
# tam: 8 - lbs:['-', 4.599999999999994, 0.5, 26.700000000000003, -79.80000000000001, 32.80000000000001, -41.0]
# tam: 5 - lbs:['-', 3.5999999999999943, -18.5, 48.7, -140.8, 33.80000000000001, -41.0]
# tam: 8 - lbs:['-', -15.400000000000006, 29.5, 27.700000000000003, 50.19999999999999, -46.19999999999999, -51.0]

# %%
for sub in sub_set:
    
    print (sub)
# Out:
# [['-', 18.599999999999994, -58.5, -74.3, 77.19999999999999, 27.80000000000001, 4.0], [39, 17, 177, 144, 103, 62, 84], [62, 35, 36, 2, 33, 7, 18], [66, 49, 36, 2, 43, 71, 40], [9, 13, 10, 1, 69, 22, 18], [37, 3, 9, 1, 7, 8, 4], [47, 14, 60, 1, 14, 9, 8]]
# [['-', -58.400000000000006, -49.5, -25.299999999999997, 24.19999999999999, 59.80000000000001, 68.0], [40, 42, 28, 94, 63, 26, 29], [50, 44, 39, 2, 30, 23, 22], [60, 36, 105, 2, 26, 18, 23], [1, 23, 48, 1, 41, 2, 5], [34, 4, 21, 1, 5, 2, 2], [54, 10, 13, 1, 14, 10, 12], [58, 49, 65, 1, 143, 66, 15]]
# [['-', -14.400000000000006, 10.5, -9.299999999999997, 112.19999999999999, 18.80000000000001, 5.0], [25, 58, 29, 67, 52, 26, 23], [12, 1, 10, 4, 15, 26, 32], [51, 25, 20, 4, 38, 45, 14], [10, 34, 8, 3, 16, 36, 29], [44, 1, 42, 2, 48, 2, 26], [45, 17, 14, 2, 30, 37, 16], [5, 0, 17, 1, 5, 3, 15], [6, 7, 33, 1, 11, 5, 5], [19, 6, 7, 1, 9, 2, 5], [27, 15, 79, 1, 10, 6, 6]]
# [['-', -35.400000000000006, 34.5, 1.7000000000000028, -146.8, -29.19999999999999, 45.0], [7, 79, 124, 62, 168, 113, 56], [28, 39, 30, 5, 134, 45, 12], [48, 24, 48, 4, 44, 34, 13], [53, 2, 4, 3, 30, 13, 29], [41, 41, 29, 1, 117, 31, 21]]
# [['-', 27.599999999999994, 47.5, -0.29999999999999716, -10.800000000000011, 0.8000000000000114, 12.0], [46, 0, 5, 49, 6, 1, 4], [18, 63, 117, 11, 232, 96, 60], [21, 8, 18, 6, 42, 38, 30], [64, 14, 13, 5, 15, 20, 22], [2, 6, 28, 3, 12, 19, 9], [8, 29, 35, 2, 46, 30, 37], [67, 2, 6, 1, 4, 2, 2]]
# [['-', 57.599999999999994, 3.5, -0.29999999999999716, 99.19999999999999, -20.19999999999999, 34.0], [15, 3, 41, 46, 69, 37, 25], [68, 52, 33, 15, 98, 98, 45], [13, 11, 136, 5, 28, 7, 37], [3, 3, 24, 4, 19, 52, 6], [52, 10, 25, 4, 8, 11, 3], [14, 12, 3, 2, 17, 18, 8], [61, 1, 4, 1, 8, 4, 18]]
# [['-', 11.599999999999994, 0.5, 4.700000000000003, 15.199999999999989, -78.19999999999999, -35.0], [16, 5, 12, 30, 21, 49, 24], [69, 26, 69, 20, 93, 57, 56], [38, 4, 12, 9, 14, 32, 5], [55, 47, 62, 7, 34, 43, 34], [22, 15, 44, 4, 35, 25, 53], [31, 14, 10, 1, 55, 65, 16], [43, 27, 60, 1, 79, 14, 23]]
# [['-', 4.599999999999994, 0.5, 26.700000000000003, -79.80000000000001, 32.80000000000001, -41.0], [63, 75, 140, 27, 265, 67, 73], [30, 5, 17, 12, 68, 48, 76], [23, 0, 12, 4, 12, 1, 7], [20, 18, 8, 3, 28, 16, 20], [17, 19, 40, 1, 9, 14, 16], [32, 8, 18, 1, 10, 8, 5], [36, 20, 25, 1, 29, 8, 16], [57, 0, 9, 1, 5, 12, 4]]
# [['-', 3.5999999999999943, -18.5, 48.7, -140.8, 33.80000000000001, -41.0], [49, 67, 70, 22, 352, 84, 101], [0, 52, 158, 3, 63, 36, 74], [11, 18, 29, 1, 58, 30, 18], [24, 8, 11, 1, 10, 13, 10], [59, 1, 20, 1, 4, 10, 14]]
# [['-', -15.400000000000006, 29.5, 27.700000000000003, 50.19999999999999, -46.19999999999999, -51.0], [65, 105, 149, 20, 170, 148, 131], [33, 17, 7, 13, 32, 33, 7], [4, 4, 17, 8, 20, 22, 23], [29, 2, 8, 3, 9, 7, 11], [35, 2, 17, 2, 11, 3, 4], [26, 6, 9, 1, 24, 19, 20], [42, 8, 11, 1, 12, 13, 10], [56, 21, 22, 1, 18, 8, 21]]

# %%
len(sub_set[-1])
# Out:
# 9

# %%
# Iterando sobre cada subconjunto em sub_set
for idx, s_set in enumerate(sub_set):
    # Abrindo o arquivo para o subconjunto
    file_path = f"{config['base_dir']}{config['save_dir']}division_{idx}"
    with open(file_path, 'w+') as fp:
        # Iterando sobre cada documento no subconjunto, excluindo a linha de contagens (assumindo que está na posição 0)
        for set_doc in s_set[1:]:
            # Obter o nome do documento usando o índice do documento
            doc_name = list(data_por_sentenca_por_doc.keys())[set_doc[0]]
            doc_sentences = data_por_sentenca_por_doc[doc_name]

            # Escrever cada sentença do documento no arquivo
            for sentence in doc_sentences:
                for tk_class in sentence:
                    # Gravar cada elemento da sentença, com separador adequado
                    fp.write(config['col_sep'].join(map(str, tk_class)) + '\n')
                # Quebra de linha entre sentenças
                fp.write('\n')
    
    print(f"Subconjunto {idx} salvo com sucesso em {file_path}")
# Out:
# Subconjunto 0 salvo com sucesso em ../Base de Dados/leNER/divisions/iterative/division_0
# Subconjunto 1 salvo com sucesso em ../Base de Dados/leNER/divisions/iterative/division_1
# Subconjunto 2 salvo com sucesso em ../Base de Dados/leNER/divisions/iterative/division_2
# Subconjunto 3 salvo com sucesso em ../Base de Dados/leNER/divisions/iterative/division_3
# Subconjunto 4 salvo com sucesso em ../Base de Dados/leNER/divisions/iterative/division_4
# Subconjunto 5 salvo com sucesso em ../Base de Dados/leNER/divisions/iterative/division_5
# Subconjunto 6 salvo com sucesso em ../Base de Dados/leNER/divisions/iterative/division_6
# Subconjunto 7 salvo com sucesso em ../Base de Dados/leNER/divisions/iterative/division_7
# Subconjunto 8 salvo com sucesso em ../Base de Dados/leNER/divisions/iterative/division_8
# Subconjunto 9 salvo com sucesso em ../Base de Dados/leNER/divisions/iterative/division_9

# %%
import os
from collections import Counter
import matplotlib.pyplot as plt
import re

# Diretório onde as partições estão salvas
base_dir = "../Base de Dados/leNER/divisions/iterative/"

number_divisions = 10

# Inicializar lista para as classes teóricas
unique_lbl_list = []

# Lista de abreviações
abbreviations = r"\b(?:Sr|S|Sra|Dr|Prof|Eng|Mme|Mestre|Vº|Vª)\.$"  # Abreviações que não devem terminar uma sentença
pattern = r"[.!?](\s|$)"  # Verifica ponto, exclamação ou interrogação seguidos de espaço ou fim da linha

# Contadores gerais
total_counts = Counter()
total_sentences_por_div = {}
total_tokens_por_div = {}

for file_name in sorted(os.listdir(base_dir)):
    if file_name.startswith("division_"):
        partition_path = os.path.join(base_dir, file_name)
        with open(partition_path, 'r', encoding='utf-8') as file:
            sentence_count = 0
            token_count = 0
            for line in file:
                line = line.strip()
                if line:
                    token_data = line.split()
                    label = token_data[-1]
                    token_count += 1  # Contando tokens
                    if label.startswith("B-"):  # Considerar apenas os rótulos com prefixo 'B-'
                        simplified_label = label.split("-")[-1]
                        unique_lbl_list.append(simplified_label)
                        total_counts[simplified_label] += 1
                    
                    # Verificar se a linha termina com ponto, exclamação ou interrogação
                    # e garantir que não seja uma abreviação
                    if re.search(pattern, line) and not re.search(abbreviations, line):
                        sentence_count += 1
            
            total_sentences_por_div[file_name] = sentence_count
            total_tokens_por_div[file_name] = token_count

# Obter classes teóricas únicas e ordenadas
classes_teoricas = sorted(set(unique_lbl_list))

# Calcular os valores teóricos dividindo as contagens totais por número de divisões
valores_teoricos = [total_counts[cls] / number_divisions for cls in classes_teoricas]

# Inicializando dicionários para armazenar contagens por partição
qtd_classes_por_div = {}
total_entidades_por_div = {}

# Iterar novamente pelas partições para calcular os valores reais
for file_name in sorted(os.listdir(base_dir)):
    if file_name.startswith("division_"):
        partition_path = os.path.join(base_dir, file_name)

        # Inicializar contador para esta partição
        labels_count = Counter()

        with open(partition_path, 'r', encoding='utf-8') as file:
            for line in file:
                line = line.strip()
                if line:
                    token_data = line.split()
                    label = token_data[-1]
                    if label.startswith("B-"):  # Considerar apenas os rótulos com prefixo 'B-'
                        simplified_label = label.split("-")[-1]
                        labels_count[simplified_label] += 1

        # Armazenar as contagens para a partição atual
        qtd_classes_por_div[file_name] = labels_count
        total_entidades_por_div[file_name] = sum(labels_count.values())

# Calculando o total geral de todas as partições
total_entidades_geral = sum(total_entidades_por_div.values())
total_sentences_geral = sum(total_sentences_por_div.values())
total_tokens_geral = sum(total_tokens_por_div.values())

# Exibindo os totais por partição e o total geral
print("Totais de entidades, sentenças e tokens por partição:")
for div_name in total_entidades_por_div:
    print(f"  {div_name}: {total_entidades_por_div[div_name]} entidades, "
          f"{total_sentences_por_div[div_name]} sentenças, "
          f"{total_tokens_por_div[div_name]} tokens")
print(f"\nTotal geral de entidades: {total_entidades_geral}")
print(f"Total geral de sentenças: {total_sentences_geral}")
print(f"Total geral de tokens: {total_tokens_geral}\n")

# Gerando os gráficos para cada partição
for div_name, labels_count in qtd_classes_por_div.items():
    # Ordenar as contagens conforme as classes teóricas
    qtd = [labels_count.get(cls, 0) for cls in classes_teoricas]

    plt.figure(figsize=(10, 6))
    bars_real = plt.barh(classes_teoricas, qtd, color="pink", label="Contagem Real")
    bars_teorico = plt.barh(classes_teoricas, valores_teoricos, color="lightblue", alpha=0.5, label="Valor Teórico")

    # Adicionando os valores nas barras
    for i, count in enumerate(qtd):
        plt.text(count, i, str(count), va="center_baseline", ha="right", fontsize=10)

    for i, teorico in enumerate(valores_teoricos):
        if teorico > 0:
            plt.text(teorico, i, f"{teorico:.1f}", va="center_baseline", ha="right", fontsize=10, color="blue")

    plt.title(f"Entities per Class in Partition: {div_name}", fontsize=15)
    plt.xlabel("Number of Entities", fontweight="bold", fontsize=12)
    plt.ylabel("Classes", fontweight="bold", fontsize=12)

    plt.legend()

    # Salvando o gráfico
    output_path = os.path.join(base_dir, f"entities_per_class_{div_name}.png")
    plt.savefig(output_path, dpi=300, format="png", bbox_inches="tight")
    print(f"Gráfico salvo: {output_path}")

print("Todos os gráficos foram gerados e salvos com sucesso!")
# Out:
# Totais de entidades, sentenças e tokens por partição:
#   division_0: 1155 entidades, 1667 sentenças, 34784 tokens
#   division_1: 1163 entidades, 1437 sentenças, 28299 tokens
#   division_2: 845 entidades, 1381 sentenças, 27791 tokens
#   division_3: 1113 entidades, 1295 sentenças, 28012 tokens
#   division_4: 992 entidades, 1332 sentenças, 26708 tokens
#   division_5: 992 entidades, 1942 sentenças, 36764 tokens
#   division_6: 983 entidades, 826 sentenças, 17582 tokens
#   division_7: 1073 entidades, 1336 sentenças, 31305 tokens
#   division_8: 1078 entidades, 1404 sentenças, 28803 tokens
#   division_9: 854 entidades, 1033 sentenças, 22505 tokens
#
# Total geral de entidades: 10248
# Total geral de sentenças: 13653
# Total geral de tokens: 282553
#
# Gráfico salvo: ../Base de Dados/leNER/divisions/iterative/entities_per_class_division_0.png
# Gráfico salvo: ../Base de Dados/leNER/divisions/iterative/entities_per_class_division_1.png
