# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# ## Funções e Configurações

# %%
# this dictionary contains the configuration necessary to divide each dataset used in the work, the script is made
# for the conll type of datasets, so if you want to add datasets to divide, make sure to add it here
gen_config = {
    'leNER':{
        'base_dir': "../Base de Dados/leNER/",
        'load_dir': "documents/allDoc/",
        'save_dir': "divisions/iterative/",
        'col_sep' : ' ',
        'file_type': '.conll',
    },
    'UlyssesNER-BR':{
        'base_dir': "../Base de Dados/UlyssesNER-BR/",
        'load_dir': "PL_Corpus_byTypes_conll/",
        'save_dir': "divisions/iterative/",
        'col_sep' : ' ',
        'file_type': '.conll',
    },
    'Harem-second':{
        'base_dir': "../Base de Dados/HAREM/",
        'load_dir': "SecondHarem/documents",
        'save_dir': "divisions/second/iterative/",
        'col_sep' : '\t',
        'file_type': '.conll',
    }
}

# %%
def get_sentencas(corpus, coll_sep):
        sentenca = []
        for line in corpus:
            if line == '\n':
                if sentenca:
                    yield sentenca
                    sentenca = []
            else:
                
                sentenca.append(line.strip('\n').split(coll_sep))
        if sentenca:
            yield sentenca

# %%
def read_dataset(filepath,coll_sep):
    data_por_sentenca = []
    with open(filepath, "r") as corpus:
        data_por_sentenca += list(get_sentencas(corpus,coll_sep))
    
    return data_por_sentenca

# %%
def get_data(config, selective = False, fileName = ""):
    load_dir = config['base_dir'] + config['load_dir']
    sep = config['col_sep']
    if selective:
        fp = load_dir + fileName
        return read_dataset(filepath=fp, coll_sep=sep)
    else:
        filepaths = []
        for file in os.listdir(load_dir):
            if file.endswith(config['file_type']):
                filepaths.append(load_dir + file)
        
        data_por_sentenca = []
        for filepath in filepaths:
            print(filepath+"\n")
            data_por_sentenca += read_dataset(filepath=filepath, coll_sep=sep)
        
        return data_por_sentenca

# %%
def split_token_label(data):
    return list(map(list,zip(*data)))

# %% [markdown]
# ## Carregando DataSet e preparando dados

# %%
# dataset = 'leNER'
# dataset = 'Paramopama'
# dataset = 'Harem-mini'
dataset = 'Harem-second'
# dataset = 'UlyssesNER-BR'

config = gen_config[dataset]

filepaths = []

files = os.listdir(config['base_dir'] + config['load_dir'])
print(files)
for file in files:
    # if file.endswith('.conll'):
    filepaths.append(config['base_dir'] + config['load_dir'] + file)

# data_por_sentenca = get_data(config=config)

# data_por_sentenca = get_data(config=config, selective=True, fileName='corpus_Paramopama.txt')
# data_por_sentenca = get_data(config=config, selective=True, fileName='haremMini-total.colnn')
# data_por_sentenca = get_data(config=config, selective=True, fileName='primeiroHAREM-total.colnn')
folder_path = '../Base de Dados/HAREM/SecondHarem/documents'
data_por_sentenca_por_doc = {}

# Listar arquivos dentro da pasta
if os.path.exists(folder_path):
    for file in os.listdir(folder_path):
        filepath = os.path.join(folder_path, file)
        
        # Verificar se é um arquivo
        if os.path.isfile(filepath):
            data_por_sentenca_por_doc[file] = read_dataset(filepath, coll_sep=config['col_sep'])
else:
    print(f"O diretório {folder_path} não existe. Verifique o caminho.")

# Exibir resultado
total_documentos = len(data_por_sentenca_por_doc)
print("Total de documentos carregados:", total_documentos)
# Out:
# ['ric-78733', 'wpt-1000772700099419796', 'dav-844651', 'hub-5080', 'hub-68694', 'ric-11625', 'ric-53646', 'Ytr433', 'aa87333', 'hub-37295', 'aa58069', 'ric-81275', 'wpt-1019468604217317242', 'hub-2701', 'hub-60382', 'hub-56266', 'ric-58766', 'hub-49343', 'aa66435', 'H2-dhy6432', 'DR-PT5', 'ric-22961', 'hub-93257', 'hub-21881', 'hub-31642', 'hub-74208', 'ric-42664', 'bob-37600', 'hub-62214', 'hub-822', 'hub-39869', 'hub-43823', 'hub-398', 'ric-92221', 'H2-Ren_2001_6414', 'H2-Ren_2003_6465', 'ric-47441', 'aa55968', 'dav-522210', 'hub-18050', 'ric-85133', 'relkj7666', 'hub-4171', 'wpt-1001819342220711712', 'hub-96408', 'ric-18999', 'dav-100932', 'hub-63156', 'hub-83020', 'exp-76321', 'wpt-101306633536471708', 'hub-28306', 'hub-19181', 'wpt-1016797200209519613', 'ric-33939', 'hub-64260', 'hub-28874', 'H2-gt654', 'hub-16632', 'hub-22322', 'dav-833351', 'ric-46546', 'aa25258', 'hub-51467', 'hub-65266', 'wpt-1005220936254463458', 'bob-14949', 'ric-30606', 'hub-77558', 'hub-60905', '2ght33', 'hub-66526', 'aa13183', 'aa64686', '2ght33-2', 'aa56088', 'gtpppp', 'ric-19806', 'ric-40040', 'hub-97297', 'H2-bbb', 'hub-15590', 'ric-76632', 'hub-71248', 'ric-39610', 'rica-474415', 'hub-55847', 'wpt-10034934164544455', 'hub-2312', 'dav-52390', 'aa40383', 'wpt-101789548982731354', 'hub-44595', 'ven-098', 'hjlll', 'hub-41899', 'hub-78051', 'hub-81551', 'ric-54609', 'hub-83689', 'hub-94570', 'hub-94890', 'hub-66746', 'hub-30518', 'hub-16268', 'hub-57257', 'cver', 'hub-67792', 'Ntyr-78', 'gtqqq', 'aa77651', 'wpt-1014517543841152414', 'ric-74122', 'hub-77889', 'H2-dftre765', 'hub-47914', 'dav-188222', 'wpt-1001951616378060469', 'aa33715', 'hub-37819', 'ric-46913', 'hub-24360', 'H2-Ert75', 'aa46996', 'aa94781', 'hub-15425', 'H2-EFin', 'ric-12366', 'wpt-1011130529557294176']
# Total de documentos carregados: 129

# %%
# data_por_sentenca_por_doc['HAREMdoc_aa64686'][0]
# len(data_por_sentenca_por_doc['HAREMdoc_aa64686'])
# data_por_sentenca_por_doc[list(data_por_sentenca_por_doc.keys())[0]]
# d = list(data_por_sentenca_por_doc.values())[0][10][-1]
# list(map(list,zip(d)))
# # d

# %%
from collections import Counter
labels_por_doc = {}

for docName, docData in data_por_sentenca_por_doc.items():
    allDocData = []
    
    for sentence in docData:
        allDocData += [i for i in sentence]
    
    docTokens, docLabels = split_token_label(allDocData)
    
    
    labels_por_doc[docName] = docLabels

    labels_count = Counter(docLabels)
    
    # Armazenar a contagem de rótulos para o documento atual
    labels_por_doc[docName] = dict(labels_count)

# Exibir as contagens de rótulos por documento
for doc, labels_count in labels_por_doc.items():
    print(f"Documento: {doc}")
    print("Contagem de rótulos:", labels_count)
    print()
# Out:
# Documento: ric-78733
# Contagem de rótulos: {'B-ACONTECIMENTO': 7, 'I-ACONTECIMENTO': 3, 'O': 454, 'B-TEMPO': 13, 'I-TEMPO': 29, 'B-OBRA': 3, 'I-OBRA': 4, 'B-LOCAL': 11, 'B-PESSOA': 25, 'I-PESSOA': 11, 'B-VALOR': 1, 'B-ORGANIZACAO': 5, 'I-ORGANIZACAO': 14, 'B-ABSTRACCAO': 6, 'B-COISA': 7}
#
# Documento: wpt-1000772700099419796
# Contagem de rótulos: {'B-PESSOA': 21, 'I-PESSOA': 24, 'O': 456, 'B-TEMPO': 7, 'I-TEMPO': 16, 'B-ACONTECIMENTO': 5, 'I-ACONTECIMENTO': 11, 'B-COISA': 13, 'I-COISA': 6, 'B-LOCAL': 2, 'I-LOCAL': 2, 'B-VALOR': 11, 'B-OUTRO': 2}
#
# Documento: dav-844651
# Contagem de rótulos: {'O': 1125, 'B-TEMPO': 19, 'I-TEMPO': 25, 'B-OBRA': 4, 'I-OBRA': 6, 'B-LOCAL': 51, 'B-PESSOA': 40, 'I-PESSOA': 41, 'B-COISA': 12, 'B-OUTRO': 3, 'I-OUTRO': 6, 'B-ABSTRACCAO': 5, 'B-ORGANIZACAO': 7, 'I-ORGANIZACAO': 5, 'I-COISA': 4, 'B-ACONTECIMENTO': 16, 'I-ACONTECIMENTO': 26, 'B-VALOR': 1, 'I-LOCAL': 19, 'I-ABSTRACCAO': 1}
#
# Documento: hub-5080
# Contagem de rótulos: {'O': 75, 'B-ACONTECIMENTO': 5, 'I-ACONTECIMENTO': 8, 'B-TEMPO': 3, 'I-TEMPO': 5, 'B-LOCAL': 4, 'B-VALOR': 2, 'I-VALOR': 2, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 1, 'B-PESSOA': 1, 'I-PESSOA': 1}
#
# Documento: hub-68694
# Contagem de rótulos: {'O': 182, 'B-COISA': 3, 'B-ORGANIZACAO': 4, 'B-ABSTRACCAO': 2, 'I-ABSTRACCAO': 2, 'B-LOCAL': 4, 'B-TEMPO': 3, 'I-TEMPO': 4, 'B-OBRA': 1, 'I-OBRA': 4, 'I-COISA': 1}
#
# Documento: ric-11625
# Contagem de rótulos: {'O': 1127, 'B-ABSTRACCAO': 48, 'B-LOCAL': 23, 'I-ABSTRACCAO': 4, 'I-LOCAL': 5, 'B-TEMPO': 10, 'I-TEMPO': 16, 'B-PESSOA': 4, 'I-PESSOA': 6, 'B-COISA': 4, 'B-OUTRO': 2, 'B-OBRA': 1, 'I-OBRA': 2}
#
# Documento: ric-53646
# Contagem de rótulos: {'B-PESSOA': 12, 'O': 484, 'B-ORGANIZACAO': 11, 'I-ORGANIZACAO': 19, 'B-TEMPO': 4, 'I-TEMPO': 9, 'B-ACONTECIMENTO': 5, 'I-ACONTECIMENTO': 7, 'B-LOCAL': 9, 'B-OBRA': 4, 'I-OBRA': 16, 'I-LOCAL': 6, 'B-COISA': 4, 'I-COISA': 2, 'B-VALOR': 2, 'I-VALOR': 2, 'I-PESSOA': 19, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 1}
#
# Documento: Ytr433
# Contagem de rótulos: {'B-PESSOA': 11, 'O': 204, 'B-TEMPO': 3, 'I-TEMPO': 3, 'B-LOCAL': 5, 'I-LOCAL': 3, 'B-ORGANIZACAO': 2, 'B-VALOR': 3, 'B-COISA': 1, 'I-COISA': 3, 'I-VALOR': 4, 'I-PESSOA': 1}
#
# Documento: aa87333
# Contagem de rótulos: {'O': 1351, 'B-LOCAL': 47, 'B-TEMPO': 50, 'I-TEMPO': 119, 'B-PESSOA': 57, 'I-PESSOA': 62, 'I-LOCAL': 44, 'B-ORGANIZACAO': 18, 'I-ORGANIZACAO': 38, 'B-VALOR': 5, 'B-ABSTRACCAO': 10, 'I-ABSTRACCAO': 22, 'I-VALOR': 2, 'B-OUTRO': 7, 'I-OUTRO': 10, 'B-COISA': 5, 'I-COISA': 2, 'B-OBRA': 12, 'I-OBRA': 20}
#
# Documento: hub-37295
# Contagem de rótulos: {'B-ACONTECIMENTO': 2, 'O': 179, 'B-LOCAL': 6, 'B-PESSOA': 4, 'I-PESSOA': 4, 'B-TEMPO': 6, 'I-TEMPO': 10, 'B-COISA': 1, 'I-COISA': 1, 'B-VALOR': 1, 'I-VALOR': 2}
#
# Documento: aa58069
# Contagem de rótulos: {'O': 711, 'B-VALOR': 13, 'I-VALOR': 14, 'B-TEMPO': 21, 'B-PESSOA': 14, 'I-PESSOA': 15, 'I-TEMPO': 32, 'B-LOCAL': 19, 'I-LOCAL': 3, 'B-COISA': 1, 'I-COISA': 4, 'B-ORGANIZACAO': 12, 'I-ORGANIZACAO': 3}
#
# Documento: ric-81275
# Contagem de rótulos: {'O': 703, 'B-COISA': 7, 'I-COISA': 2, 'B-PESSOA': 20, 'I-PESSOA': 19, 'B-TEMPO': 6, 'I-TEMPO': 15, 'B-ABSTRACCAO': 9, 'B-LOCAL': 3, 'B-OBRA': 6, 'I-OBRA': 13, 'I-LOCAL': 3, 'I-ABSTRACCAO': 7}
#
# Documento: wpt-1019468604217317242
# Contagem de rótulos: {'B-OBRA': 23, 'I-OBRA': 73, 'O': 224, 'B-TEMPO': 7, 'I-TEMPO': 29, 'B-ORGANIZACAO': 15, 'I-ORGANIZACAO': 9, 'B-OUTRO': 3, 'I-OUTRO': 9, 'B-LOCAL': 3, 'I-LOCAL': 1}
#
# Documento: hub-2701
# Contagem de rótulos: {'O': 494, 'B-OBRA': 2, 'I-OBRA': 2, 'B-TEMPO': 5, 'I-TEMPO': 8, 'B-ORGANIZACAO': 17, 'B-PESSOA': 9, 'I-PESSOA': 2, 'B-LOCAL': 1}
#
# Documento: hub-60382
# Contagem de rótulos: {'B-ACONTECIMENTO': 5, 'O': 288, 'B-PESSOA': 17, 'I-PESSOA': 4, 'B-LOCAL': 3, 'B-ORGANIZACAO': 2, 'B-TEMPO': 9, 'I-TEMPO': 14, 'B-OBRA': 2, 'I-OBRA': 2, 'B-VALOR': 2, 'I-VALOR': 2, 'B-OUTRO': 1, 'I-OUTRO': 1, 'I-LOCAL': 2}
#
# Documento: hub-56266
# Contagem de rótulos: {'O': 267, 'B-ACONTECIMENTO': 2, 'I-ACONTECIMENTO': 1, 'B-ORGANIZACAO': 6, 'B-COISA': 10, 'B-TEMPO': 8, 'I-TEMPO': 14, 'I-COISA': 3, 'B-LOCAL': 6, 'I-LOCAL': 1, 'B-PESSOA': 2, 'I-PESSOA': 2, 'B-VALOR': 7, 'I-VALOR': 11}
#
# Documento: ric-58766
# Contagem de rótulos: {'B-TEMPO': 4, 'I-TEMPO': 6, 'O': 439, 'B-LOCAL': 27, 'B-VALOR': 11, 'I-VALOR': 16, 'I-LOCAL': 30, 'B-COISA': 6, 'I-COISA': 10, 'B-ORGANIZACAO': 2, 'B-PESSOA': 1}
#
# Documento: hub-49343
# Contagem de rótulos: {'B-PESSOA': 14, 'I-PESSOA': 28, 'O': 334, 'B-TEMPO': 15, 'I-TEMPO': 26, 'B-LOCAL': 33, 'B-ORGANIZACAO': 9, 'I-ORGANIZACAO': 7, 'I-LOCAL': 17, 'B-VALOR': 1, 'I-VALOR': 1, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 4}
#
# Documento: aa66435
# Contagem de rótulos: {'O': 849, 'B-ORGANIZACAO': 16, 'B-PESSOA': 14, 'I-PESSOA': 7, 'B-LOCAL': 14, 'B-OUTRO': 2, 'I-LOCAL': 1, 'B-ACONTECIMENTO': 4, 'B-TEMPO': 11, 'I-TEMPO': 21, 'B-ABSTRACCAO': 4, 'I-ACONTECIMENTO': 1, 'B-OBRA': 1, 'I-OUTRO': 1, 'B-VALOR': 1, 'I-VALOR': 1, 'I-ORGANIZACAO': 2}
#
# Documento: H2-dhy6432
# Contagem de rótulos: {'O': 328, 'B-TEMPO': 7, 'I-TEMPO': 21, 'B-LOCAL': 9, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 1, 'B-OBRA': 1, 'I-OBRA': 2, 'B-VALOR': 1, 'I-VALOR': 2, 'B-ORGANIZACAO': 1, 'I-ORGANIZACAO': 3}
#
# Documento: DR-PT5
# Contagem de rótulos: {'B-ORGANIZACAO': 7, 'I-ORGANIZACAO': 29, 'O': 202, 'B-OBRA': 3, 'I-OBRA': 6, 'B-TEMPO': 6, 'I-TEMPO': 23, 'B-LOCAL': 7, 'B-PESSOA': 7, 'I-PESSOA': 47, 'B-VALOR': 3, 'I-VALOR': 3, 'I-LOCAL': 6}
#
# Documento: ric-22961
# Contagem de rótulos: {'O': 974, 'B-PESSOA': 3, 'I-PESSOA': 2, 'B-LOCAL': 19, 'B-TEMPO': 14, 'I-TEMPO': 35, 'B-ORGANIZACAO': 11, 'I-ORGANIZACAO': 11, 'B-ABSTRACCAO': 4, 'I-ABSTRACCAO': 13, 'I-LOCAL': 10, 'B-OUTRO': 1, 'B-VALOR': 3}
#
# Documento: hub-93257
# Contagem de rótulos: {'B-PESSOA': 23, 'I-PESSOA': 20, 'O': 398, 'B-ACONTECIMENTO': 2, 'I-ACONTECIMENTO': 4, 'B-LOCAL': 12, 'B-ORGANIZACAO': 6, 'I-ORGANIZACAO': 2, 'B-OBRA': 1, 'I-OBRA': 1, 'B-TEMPO': 6, 'I-TEMPO': 22, 'I-LOCAL': 1}
#
# Documento: hub-21881
# Contagem de rótulos: {'B-TEMPO': 5, 'O': 184, 'B-ORGANIZACAO': 17, 'B-PESSOA': 2, 'I-ORGANIZACAO': 11, 'I-TEMPO': 8, 'I-PESSOA': 1, 'B-VALOR': 1}
#
# Documento: hub-31642
# Contagem de rótulos: {'B-ACONTECIMENTO': 2, 'I-ACONTECIMENTO': 4, 'O': 165, 'B-TEMPO': 6, 'I-TEMPO': 7, 'B-PESSOA': 8, 'I-PESSOA': 9, 'B-LOCAL': 8, 'B-ORGANIZACAO': 5, 'I-LOCAL': 3}
#
# Documento: hub-74208
# Contagem de rótulos: {'O': 192, 'B-COISA': 8, 'B-TEMPO': 3, 'I-TEMPO': 7, 'B-ABSTRACCAO': 2, 'I-ABSTRACCAO': 1, 'B-LOCAL': 2, 'I-LOCAL': 3, 'B-VALOR': 7, 'I-VALOR': 7, 'B-PESSOA': 3, 'I-PESSOA': 3, 'I-COISA': 4, 'B-ORGANIZACAO': 1}
#
# Documento: ric-42664
# Contagem de rótulos: {'B-PESSOA': 19, 'O': 431, 'B-TEMPO': 9, 'I-TEMPO': 19, 'B-LOCAL': 15, 'I-PESSOA': 13, 'B-COISA': 10, 'I-COISA': 11, 'B-ABSTRACCAO': 5, 'I-ABSTRACCAO': 5, 'B-ACONTECIMENTO': 4, 'I-ACONTECIMENTO': 8, 'I-LOCAL': 5, 'B-ORGANIZACAO': 7, 'I-ORGANIZACAO': 13}
#
# Documento: bob-37600
# Contagem de rótulos: {'B-ABSTRACCAO': 19, 'I-ABSTRACCAO': 14, 'O': 684, 'B-OBRA': 26, 'B-ORGANIZACAO': 27, 'I-ORGANIZACAO': 51, 'I-OBRA': 73, 'B-LOCAL': 2, 'B-TEMPO': 2, 'B-ACONTECIMENTO': 2, 'I-ACONTECIMENTO': 12, 'B-VALOR': 1, 'B-PESSOA': 4, 'I-PESSOA': 3, 'I-TEMPO': 1}
#
# Documento: hub-62214
# Contagem de rótulos: {'B-LOCAL': 9, 'I-LOCAL': 6, 'O': 264, 'B-PESSOA': 9, 'I-PESSOA': 15, 'B-TEMPO': 6, 'I-TEMPO': 6, 'B-OBRA': 2, 'I-OBRA': 8, 'B-ABSTRACCAO': 5, 'I-ABSTRACCAO': 7}
#
# Documento: hub-822
# Contagem de rótulos: {'B-COISA': 1, 'O': 128, 'B-ORGANIZACAO': 7, 'I-ORGANIZACAO': 9, 'B-TEMPO': 7, 'I-TEMPO': 12, 'B-VALOR': 6, 'I-VALOR': 4, 'B-LOCAL': 1}
#
# Documento: hub-39869
# Contagem de rótulos: {'B-TEMPO': 5, 'I-TEMPO': 6, 'O': 185, 'B-LOCAL': 9, 'B-PESSOA': 12, 'B-ACONTECIMENTO': 2, 'I-ACONTECIMENTO': 2, 'B-ORGANIZACAO': 12, 'I-ORGANIZACAO': 4, 'I-PESSOA': 6, 'I-LOCAL': 3}
#
# Documento: hub-43823
# Contagem de rótulos: {'O': 1205, 'B-ABSTRACCAO': 3, 'B-ORGANIZACAO': 35, 'B-PESSOA': 21, 'I-ORGANIZACAO': 3, 'B-LOCAL': 5, 'I-PESSOA': 14, 'B-TEMPO': 15, 'I-TEMPO': 24, 'I-LOCAL': 4, 'B-OBRA': 1}
#
# Documento: hub-398
# Contagem de rótulos: {'O': 105, 'B-PESSOA': 8, 'B-LOCAL': 5, 'I-LOCAL': 8, 'B-ORGANIZACAO': 2, 'B-TEMPO': 7, 'B-VALOR': 4, 'I-TEMPO': 3, 'B-ACONTECIMENTO': 1}
#
# Documento: ric-92221
# Contagem de rótulos: {'O': 325, 'B-ACONTECIMENTO': 3, 'B-VALOR': 7, 'I-VALOR': 4, 'I-ACONTECIMENTO': 4, 'B-LOCAL': 11, 'B-TEMPO': 2, 'I-TEMPO': 4, 'B-PESSOA': 19, 'I-PESSOA': 11, 'I-LOCAL': 10, 'B-ABSTRACCAO': 1, 'B-OUTRO': 1}
#
# Documento: H2-Ren_2001_6414
# Contagem de rótulos: {'O': 215, 'B-ORGANIZACAO': 2, 'I-ORGANIZACAO': 2, 'B-LOCAL': 5, 'B-PESSOA': 3, 'I-PESSOA': 1, 'B-COISA': 3, 'B-TEMPO': 2, 'I-TEMPO': 2, 'B-VALOR': 2, 'I-LOCAL': 1}
#
# Documento: H2-Ren_2003_6465
# Contagem de rótulos: {'O': 220, 'B-COISA': 2, 'B-TEMPO': 7, 'I-TEMPO': 16, 'B-LOCAL': 5, 'B-VALOR': 6, 'I-VALOR': 12, 'B-ORGANIZACAO': 3, 'I-ORGANIZACAO': 2, 'I-LOCAL': 2}
#
# Documento: ric-47441
# Contagem de rótulos: {'O': 151, 'B-OUTRO': 1, 'B-ACONTECIMENTO': 1, 'I-ACONTECIMENTO': 7, 'B-LOCAL': 3, 'B-COISA': 1, 'B-ABSTRACCAO': 3, 'I-ABSTRACCAO': 1, 'B-PESSOA': 3, 'I-PESSOA': 3, 'B-VALOR': 2, 'I-VALOR': 2, 'I-LOCAL': 2, 'B-TEMPO': 1, 'I-TEMPO': 1}
#
# Documento: aa55968
# Contagem de rótulos: {'B-OBRA': 1, 'I-OBRA': 3, 'O': 306, 'B-LOCAL': 15, 'I-LOCAL': 8, 'B-TEMPO': 3, 'I-TEMPO': 4, 'B-PESSOA': 16, 'I-PESSOA': 17, 'B-ORGANIZACAO': 8, 'I-ORGANIZACAO': 9, 'B-ACONTECIMENTO': 1, 'I-ACONTECIMENTO': 1, 'B-VALOR': 2, 'I-VALOR': 7}
#
# Documento: dav-522210
# Contagem de rótulos: {'O': 1340, 'B-PESSOA': 56, 'I-PESSOA': 63, 'B-OBRA': 27, 'I-OBRA': 53, 'B-LOCAL': 60, 'I-LOCAL': 31, 'B-ORGANIZACAO': 30, 'B-TEMPO': 26, 'I-TEMPO': 40, 'B-OUTRO': 13, 'I-OUTRO': 12, 'I-ORGANIZACAO': 12, 'B-ACONTECIMENTO': 31, 'I-ACONTECIMENTO': 58, 'B-ABSTRACCAO': 9, 'B-COISA': 4, 'I-COISA': 3, 'I-ABSTRACCAO': 2}
#
# Documento: hub-18050
# Contagem de rótulos: {'B-OBRA': 5, 'I-OBRA': 16, 'O': 128, 'B-LOCAL': 11, 'B-TEMPO': 9, 'I-TEMPO': 18, 'B-ORGANIZACAO': 8, 'I-ORGANIZACAO': 32, 'B-PESSOA': 8, 'I-PESSOA': 20, 'I-LOCAL': 3}
#
# Documento: ric-85133
# Contagem de rótulos: {'O': 782, 'B-PESSOA': 33, 'I-PESSOA': 17, 'B-ABSTRACCAO': 2, 'B-TEMPO': 8, 'I-TEMPO': 7, 'B-OBRA': 12, 'I-OBRA': 30}
#
# Documento: relkj7666
# Contagem de rótulos: {'O': 1475, 'B-LOCAL': 41, 'I-LOCAL': 59, 'B-OBRA': 18, 'I-OBRA': 58, 'B-TEMPO': 35, 'I-TEMPO': 78, 'B-ACONTECIMENTO': 8, 'I-ACONTECIMENTO': 13, 'B-PESSOA': 49, 'I-PESSOA': 95, 'B-ORGANIZACAO': 46, 'I-ORGANIZACAO': 103, 'B-VALOR': 16, 'I-VALOR': 10, 'B-ABSTRACCAO': 5, 'I-ABSTRACCAO': 3, 'B-COISA': 12, 'I-COISA': 29, 'B-OUTRO': 1, 'I-OUTRO': 2}
#
# Documento: hub-4171
# Contagem de rótulos: {'O': 230, 'B-TEMPO': 8, 'I-TEMPO': 12, 'B-LOCAL': 1, 'B-ABSTRACCAO': 2, 'B-ORGANIZACAO': 4, 'I-ORGANIZACAO': 2, 'B-ACONTECIMENTO': 3, 'B-PESSOA': 2, 'I-PESSOA': 1, 'B-VALOR': 4, 'I-VALOR': 4}
#
# Documento: wpt-1001819342220711712
# Contagem de rótulos: {'O': 207, 'B-TEMPO': 6, 'B-OBRA': 2, 'I-OBRA': 8, 'B-PESSOA': 5, 'I-TEMPO': 7, 'B-VALOR': 1, 'I-PESSOA': 2}
#
# Documento: hub-96408
# Contagem de rótulos: {'B-ACONTECIMENTO': 8, 'I-ACONTECIMENTO': 7, 'O': 289, 'B-PESSOA': 24, 'B-LOCAL': 6, 'I-PESSOA': 5, 'B-ABSTRACCAO': 1, 'B-VALOR': 11, 'I-LOCAL': 3, 'B-COISA': 1, 'B-TEMPO': 1, 'I-TEMPO': 2, 'I-VALOR': 1}
#
# Documento: ric-18999
# Contagem de rótulos: {'B-LOCAL': 11, 'O': 132, 'B-PESSOA': 3, 'I-LOCAL': 9, 'B-TEMPO': 4, 'B-OBRA': 1, 'I-OBRA': 7, 'I-PESSOA': 1, 'I-TEMPO': 8, 'B-VALOR': 5, 'I-VALOR': 3, 'B-ORGANIZACAO': 2, 'I-ORGANIZACAO': 2}
#
# Documento: dav-100932
# Contagem de rótulos: {'O': 1435, 'B-LOCAL': 57, 'I-LOCAL': 23, 'B-PESSOA': 56, 'I-PESSOA': 67, 'B-ORGANIZACAO': 32, 'B-OBRA': 7, 'B-COISA': 7, 'B-TEMPO': 41, 'I-TEMPO': 106, 'B-ABSTRACCAO': 2, 'I-ORGANIZACAO': 21, 'I-OBRA': 12, 'B-ACONTECIMENTO': 8, 'I-ACONTECIMENTO': 12, 'B-OUTRO': 4, 'I-OUTRO': 2, 'B-VALOR': 7, 'I-VALOR': 4}
#
# Documento: hub-63156
# Contagem de rótulos: {'O': 241, 'B-PESSOA': 15, 'I-PESSOA': 9, 'B-ABSTRACCAO': 5, 'B-LOCAL': 6, 'I-LOCAL': 3, 'B-TEMPO': 12, 'I-TEMPO': 17, 'B-OBRA': 9, 'B-COISA': 3, 'I-COISA': 4, 'B-ORGANIZACAO': 2, 'I-ORGANIZACAO': 1, 'I-OBRA': 10, 'B-OUTRO': 1, 'I-OUTRO': 2, 'I-ABSTRACCAO': 6}
#
# Documento: hub-83020
# Contagem de rótulos: {'O': 153, 'B-VALOR': 7, 'I-VALOR': 7, 'B-ORGANIZACAO': 2, 'B-TEMPO': 10, 'B-LOCAL': 6, 'I-TEMPO': 14, 'B-PESSOA': 4, 'I-PESSOA': 5, 'B-ACONTECIMENTO': 1, 'I-ACONTECIMENTO': 2, 'I-LOCAL': 1}
#
# Documento: exp-76321
# Contagem de rótulos: {'O': 227, 'B-ORGANIZACAO': 4, 'I-ORGANIZACAO': 2, 'B-TEMPO': 3, 'B-VALOR': 1, 'I-VALOR': 1, 'I-TEMPO': 3, 'B-LOCAL': 1}
#
# Documento: wpt-101306633536471708
# Contagem de rótulos: {'O': 1532, 'B-TEMPO': 20, 'B-ORGANIZACAO': 100, 'I-ORGANIZACAO': 74, 'I-TEMPO': 51, 'B-OUTRO': 5, 'B-PESSOA': 22, 'I-PESSOA': 50, 'B-OBRA': 26, 'I-OBRA': 79, 'I-OUTRO': 5, 'B-ABSTRACCAO': 14, 'I-ABSTRACCAO': 30, 'B-LOCAL': 32, 'B-VALOR': 7, 'I-VALOR': 6, 'I-LOCAL': 39, 'B-ACONTECIMENTO': 14, 'I-ACONTECIMENTO': 34, 'B-COISA': 5, 'I-COISA': 16}
#
# Documento: hub-28306
# Contagem de rótulos: {'B-ORGANIZACAO': 4, 'O': 246, 'B-TEMPO': 3, 'I-TEMPO': 9, 'I-ORGANIZACAO': 1, 'B-OBRA': 2, 'B-COISA': 10, 'I-COISA': 5, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 2, 'B-LOCAL': 1}
#
# Documento: hub-19181
# Contagem de rótulos: {'B-ACONTECIMENTO': 5, 'I-ACONTECIMENTO': 5, 'O': 91, 'B-PESSOA': 9, 'I-PESSOA': 7, 'B-TEMPO': 2, 'I-TEMPO': 2, 'B-VALOR': 9, 'B-LOCAL': 3, 'I-LOCAL': 1}
#
# Documento: wpt-1016797200209519613
# Contagem de rótulos: {'B-ABSTRACCAO': 5, 'I-ABSTRACCAO': 3, 'O': 239, 'B-ORGANIZACAO': 10, 'I-ORGANIZACAO': 14, 'B-COISA': 7, 'I-COISA': 3, 'B-LOCAL': 2}
#
# Documento: ric-33939
# Contagem de rótulos: {'B-ORGANIZACAO': 24, 'O': 699, 'B-PESSOA': 11, 'I-PESSOA': 5, 'I-ORGANIZACAO': 16, 'B-TEMPO': 15, 'I-TEMPO': 31, 'B-ACONTECIMENTO': 1, 'I-ACONTECIMENTO': 2, 'B-LOCAL': 11, 'B-VALOR': 2, 'I-LOCAL': 7, 'B-COISA': 1, 'B-OBRA': 4, 'I-OBRA': 20, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 2}
#
# Documento: hub-64260
# Contagem de rótulos: {'B-OUTRO': 1, 'I-OUTRO': 2, 'O': 187, 'B-COISA': 2, 'I-COISA': 4, 'B-TEMPO': 2, 'I-TEMPO': 6, 'B-ACONTECIMENTO': 1, 'I-ACONTECIMENTO': 1, 'B-LOCAL': 7, 'B-OBRA': 4, 'I-OBRA': 8, 'B-ORGANIZACAO': 2, 'B-PESSOA': 1, 'I-PESSOA': 1, 'I-LOCAL': 2}
#
# Documento: hub-28874
# Contagem de rótulos: {'B-COISA': 4, 'O': 204, 'B-VALOR': 11, 'I-VALOR': 14, 'B-PESSOA': 2, 'B-TEMPO': 2, 'I-TEMPO': 2, 'B-ORGANIZACAO': 3, 'I-ORGANIZACAO': 11, 'B-LOCAL': 1}
#
# Documento: H2-gt654
# Contagem de rótulos: {'O': 878, 'B-PESSOA': 38, 'I-PESSOA': 23, 'B-LOCAL': 6, 'I-LOCAL': 10, 'B-OBRA': 3, 'I-OBRA': 7, 'B-TEMPO': 10, 'I-TEMPO': 17, 'B-ORGANIZACAO': 7, 'I-ORGANIZACAO': 4, 'B-ABSTRACCAO': 6, 'B-COISA': 1}
#
# Documento: hub-16632
# Contagem de rótulos: {'O': 83, 'B-PESSOA': 5, 'I-PESSOA': 7, 'B-LOCAL': 2}
#
# Documento: hub-22322
# Contagem de rótulos: {'B-PESSOA': 9, 'O': 125, 'B-TEMPO': 9, 'B-ORGANIZACAO': 3, 'I-PESSOA': 7, 'I-TEMPO': 16, 'B-LOCAL': 1, 'I-LOCAL': 2, 'B-OBRA': 1}
#
# Documento: dav-833351
# Contagem de rótulos: {'O': 1194, 'B-ORGANIZACAO': 19, 'I-ORGANIZACAO': 8, 'B-PESSOA': 69, 'B-TEMPO': 26, 'I-TEMPO': 42, 'I-PESSOA': 66, 'B-LOCAL': 42, 'B-OBRA': 13, 'I-OBRA': 25, 'B-ACONTECIMENTO': 20, 'I-ACONTECIMENTO': 48, 'B-ABSTRACCAO': 5, 'I-ABSTRACCAO': 4, 'B-COISA': 6, 'B-OUTRO': 3, 'I-OUTRO': 6, 'I-LOCAL': 13}
#
# Documento: ric-46546
# Contagem de rótulos: {'B-PESSOA': 173, 'I-PESSOA': 153, 'O': 3049, 'B-ORGANIZACAO': 24, 'B-OBRA': 21, 'I-OBRA': 74, 'B-TEMPO': 24, 'I-TEMPO': 35, 'B-LOCAL': 17, 'I-LOCAL': 12, 'B-VALOR': 7, 'I-VALOR': 2, 'I-ORGANIZACAO': 26, 'B-ABSTRACCAO': 15, 'I-ABSTRACCAO': 18, 'B-COISA': 1, 'I-COISA': 1, 'B-ACONTECIMENTO': 1, 'I-ACONTECIMENTO': 7}
#
# Documento: aa25258
# Contagem de rótulos: {'B-PESSOA': 18, 'O': 712, 'B-ABSTRACCAO': 1, 'B-OBRA': 4, 'I-PESSOA': 10, 'B-TEMPO': 14, 'I-TEMPO': 27, 'B-VALOR': 2, 'I-VALOR': 2, 'B-LOCAL': 8, 'B-ACONTECIMENTO': 1, 'I-ACONTECIMENTO': 2, 'B-ORGANIZACAO': 5, 'I-ORGANIZACAO': 1}
#
# Documento: hub-51467
# Contagem de rótulos: {'B-TEMPO': 24, 'O': 645, 'I-TEMPO': 47, 'B-VALOR': 36, 'B-ORGANIZACAO': 19, 'I-ORGANIZACAO': 33, 'B-LOCAL': 7, 'I-LOCAL': 1, 'I-VALOR': 23, 'B-OUTRO': 8, 'B-PESSOA': 1, 'I-PESSOA': 1, 'I-OUTRO': 8}
#
# Documento: hub-65266
# Contagem de rótulos: {'O': 340, 'B-ORGANIZACAO': 15, 'B-PESSOA': 15, 'I-PESSOA': 44, 'I-ORGANIZACAO': 26, 'B-TEMPO': 8, 'B-OBRA': 2, 'B-LOCAL': 3, 'I-LOCAL': 2, 'I-TEMPO': 16}
#
# Documento: wpt-1005220936254463458
# Contagem de rótulos: {'O': 121, 'B-LOCAL': 3, 'I-LOCAL': 3, 'B-TEMPO': 6, 'B-ACONTECIMENTO': 4, 'I-ACONTECIMENTO': 13, 'B-ORGANIZACAO': 3, 'I-ORGANIZACAO': 8, 'B-VALOR': 1, 'I-VALOR': 2, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 5, 'B-OBRA': 3, 'I-OBRA': 8, 'B-PESSOA': 4, 'I-PESSOA': 4, 'B-COISA': 1}
#
# Documento: bob-14949
# Contagem de rótulos: {'O': 408, 'B-PESSOA': 20, 'I-PESSOA': 13, 'B-LOCAL': 20, 'I-LOCAL': 21, 'B-ACONTECIMENTO': 3, 'I-ACONTECIMENTO': 9, 'B-TEMPO': 21, 'B-VALOR': 3, 'I-VALOR': 4, 'I-TEMPO': 23, 'B-ORGANIZACAO': 2, 'I-ORGANIZACAO': 2, 'B-OBRA': 3, 'I-OBRA': 8}
#
# Documento: ric-30606
# Contagem de rótulos: {'O': 867, 'B-TEMPO': 5, 'I-TEMPO': 5, 'B-LOCAL': 4, 'I-LOCAL': 3, 'B-ACONTECIMENTO': 1, 'I-ACONTECIMENTO': 2, 'B-OBRA': 10, 'I-OBRA': 18, 'B-COISA': 6, 'B-PESSOA': 12, 'I-PESSOA': 10, 'I-COISA': 3, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 2, 'B-VALOR': 4, 'I-VALOR': 3, 'B-ORGANIZACAO': 2}
#
# Documento: hub-77558
# Contagem de rótulos: {'O': 250, 'B-PESSOA': 18, 'B-LOCAL': 2, 'B-TEMPO': 12, 'I-TEMPO': 16, 'I-PESSOA': 14, 'B-OBRA': 18, 'I-OBRA': 25, 'B-ABSTRACCAO': 2, 'B-COISA': 1, 'I-COISA': 1, 'B-VALOR': 1, 'B-ORGANIZACAO': 1, 'I-ORGANIZACAO': 1}
#
# Documento: hub-60905
# Contagem de rótulos: {'O': 148, 'B-TEMPO': 8, 'I-TEMPO': 14, 'B-VALOR': 8, 'I-VALOR': 13, 'B-ORGANIZACAO': 4, 'B-COISA': 7, 'I-COISA': 1, 'I-ORGANIZACAO': 1}
#
# Documento: 2ght33
# Contagem de rótulos: {'O': 1088, 'B-PESSOA': 19, 'I-PESSOA': 6, 'B-LOCAL': 15, 'B-ORGANIZACAO': 5, 'B-TEMPO': 12, 'I-TEMPO': 25, 'I-LOCAL': 5, 'B-ABSTRACCAO': 12, 'I-ABSTRACCAO': 11, 'I-ORGANIZACAO': 1, 'B-OBRA': 2, 'I-OBRA': 9, 'B-COISA': 6}
#
# Documento: hub-66526
# Contagem de rótulos: {'B-OBRA': 1, 'I-OBRA': 3, 'O': 214, 'B-LOCAL': 14, 'I-LOCAL': 14, 'B-TEMPO': 6, 'I-TEMPO': 11, 'B-PESSOA': 18, 'I-PESSOA': 33, 'B-VALOR': 1, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 4, 'B-ORGANIZACAO': 5, 'B-OUTRO': 2, 'I-ORGANIZACAO': 5, 'I-OUTRO': 1}
#
# Documento: aa13183
# Contagem de rótulos: {'O': 519, 'B-COISA': 9, 'I-COISA': 4, 'B-TEMPO': 17, 'I-TEMPO': 23, 'B-LOCAL': 10, 'B-ACONTECIMENTO': 4, 'I-ACONTECIMENTO': 16, 'B-ORGANIZACAO': 18, 'I-ORGANIZACAO': 30, 'I-LOCAL': 18, 'B-PESSOA': 6, 'I-PESSOA': 6, 'B-OBRA': 3, 'I-OBRA': 8}
#
# Documento: aa64686
# Contagem de rótulos: {'B-ACONTECIMENTO': 3, 'O': 450, 'B-TEMPO': 9, 'I-TEMPO': 19, 'I-ACONTECIMENTO': 2, 'B-LOCAL': 14, 'B-ABSTRACCAO': 9, 'B-ORGANIZACAO': 3, 'I-LOCAL': 13, 'B-PESSOA': 9, 'I-ABSTRACCAO': 8, 'I-ORGANIZACAO': 1, 'I-PESSOA': 8, 'B-OBRA': 3, 'I-OBRA': 11, 'B-VALOR': 1, 'I-VALOR': 1}
#
# Documento: 2ght33-2
# Contagem de rótulos: {'O': 945, 'B-ABSTRACCAO': 5, 'B-TEMPO': 15, 'I-TEMPO': 34, 'B-LOCAL': 9, 'B-PESSOA': 17, 'B-COISA': 3, 'I-COISA': 1, 'I-PESSOA': 5}
#
# Documento: aa56088
# Contagem de rótulos: {'O': 925, 'B-PESSOA': 39, 'B-OBRA': 21, 'I-OBRA': 41, 'B-ORGANIZACAO': 40, 'I-PESSOA': 36, 'I-ORGANIZACAO': 7, 'B-TEMPO': 9, 'I-TEMPO': 20, 'B-LOCAL': 7, 'I-LOCAL': 1, 'B-VALOR': 3, 'I-VALOR': 2, 'B-ABSTRACCAO': 2, 'I-ABSTRACCAO': 2, 'B-ACONTECIMENTO': 4, 'I-ACONTECIMENTO': 7}
#
# Documento: gtpppp
# Contagem de rótulos: {'O': 326, 'B-PESSOA': 26, 'B-TEMPO': 8, 'I-TEMPO': 12, 'B-LOCAL': 15, 'B-VALOR': 3, 'B-ACONTECIMENTO': 13, 'I-ACONTECIMENTO': 38, 'I-LOCAL': 4, 'I-PESSOA': 15, 'B-ORGANIZACAO': 2, 'I-ORGANIZACAO': 2, 'B-COISA': 1, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 2}
#
# Documento: ric-19806
# Contagem de rótulos: {'B-ABSTRACCAO': 4, 'I-ABSTRACCAO': 8, 'O': 962, 'B-PESSOA': 6, 'I-PESSOA': 10, 'B-TEMPO': 12, 'I-TEMPO': 14, 'B-LOCAL': 73, 'I-LOCAL': 35, 'B-COISA': 40, 'B-VALOR': 4, 'I-COISA': 33}
#
# Documento: ric-40040
# Contagem de rótulos: {'O': 714, 'B-PESSOA': 39, 'B-LOCAL': 8, 'I-LOCAL': 7, 'I-PESSOA': 20, 'B-ACONTECIMENTO': 7, 'I-ACONTECIMENTO': 13, 'B-TEMPO': 8, 'I-TEMPO': 16, 'B-OBRA': 7, 'I-OBRA': 5, 'B-ABSTRACCAO': 5, 'I-ABSTRACCAO': 3}
#
# Documento: hub-97297
# Contagem de rótulos: {'B-PESSOA': 10, 'I-PESSOA': 6, 'O': 237, 'B-LOCAL': 9, 'I-LOCAL': 1, 'B-ORGANIZACAO': 4, 'B-TEMPO': 2, 'B-ACONTECIMENTO': 11, 'B-OBRA': 1, 'I-OBRA': 2, 'I-TEMPO': 1}
#
# Documento: H2-bbb
# Contagem de rótulos: {'B-PESSOA': 9, 'O': 188, 'B-TEMPO': 3, 'B-OBRA': 2, 'I-OBRA': 10, 'I-PESSOA': 2, 'B-ABSTRACCAO': 2, 'I-TEMPO': 6, 'B-LOCAL': 1, 'I-LOCAL': 1}
#
# Documento: hub-15590
# Contagem de rótulos: {'B-PESSOA': 40, 'I-PESSOA': 60, 'O': 299, 'B-LOCAL': 16, 'I-LOCAL': 5, 'B-TEMPO': 9, 'I-TEMPO': 19, 'B-ACONTECIMENTO': 4, 'I-ACONTECIMENTO': 4, 'B-ORGANIZACAO': 1, 'B-VALOR': 2}
#
# Documento: ric-76632
# Contagem de rótulos: {'O': 892, 'B-PESSOA': 20, 'I-PESSOA': 10, 'B-LOCAL': 9, 'I-LOCAL': 11, 'B-TEMPO': 14, 'B-VALOR': 2, 'I-TEMPO': 20, 'B-ACONTECIMENTO': 8, 'I-ACONTECIMENTO': 22, 'B-ORGANIZACAO': 6, 'I-ORGANIZACAO': 12, 'I-VALOR': 1, 'B-OBRA': 2, 'I-OBRA': 4}
#
# Documento: hub-71248
# Contagem de rótulos: {'O': 105, 'B-TEMPO': 8, 'I-TEMPO': 16, 'B-LOCAL': 8, 'I-LOCAL': 9, 'B-PESSOA': 5, 'B-VALOR': 4, 'I-VALOR': 4, 'B-ABSTRACCAO': 1}
#
# Documento: ric-39610
# Contagem de rótulos: {'B-ORGANIZACAO': 2, 'I-ORGANIZACAO': 4, 'O': 332, 'B-OBRA': 10, 'B-TEMPO': 7, 'B-VALOR': 2, 'I-OBRA': 18, 'I-TEMPO': 7, 'B-PESSOA': 6, 'I-PESSOA': 2, 'B-ABSTRACCAO': 1, 'B-LOCAL': 1, 'I-LOCAL': 1, 'B-ACONTECIMENTO': 1}
#
# Documento: rica-474415
# Contagem de rótulos: {'B-LOCAL': 11, 'O': 616, 'B-PESSOA': 20, 'I-PESSOA': 11, 'B-TEMPO': 13, 'B-VALOR': 1, 'B-ORGANIZACAO': 18, 'B-OBRA': 3, 'I-OBRA': 5, 'I-TEMPO': 17, 'I-ORGANIZACAO': 7, 'B-ABSTRACCAO': 1, 'B-ACONTECIMENTO': 1, 'I-ACONTECIMENTO': 2, 'I-LOCAL': 4}
#
# Documento: hub-55847
# Contagem de rótulos: {'B-PESSOA': 42, 'I-PESSOA': 64, 'O': 268, 'B-LOCAL': 15, 'B-TEMPO': 6, 'I-TEMPO': 9, 'B-VALOR': 2, 'I-VALOR': 4, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 1, 'B-ACONTECIMENTO': 1, 'B-OBRA': 1}
#
# Documento: wpt-10034934164544455
# Contagem de rótulos: {'O': 134, 'B-LOCAL': 3, 'I-LOCAL': 1, 'B-TEMPO': 3, 'I-TEMPO': 5, 'B-VALOR': 1, 'B-PESSOA': 2, 'B-ORGANIZACAO': 4, 'I-PESSOA': 2, 'I-ORGANIZACAO': 12}
#
# Documento: hub-2312
# Contagem de rótulos: {'B-COISA': 13, 'I-COISA': 6, 'O': 242, 'B-ABSTRACCAO': 2, 'I-ABSTRACCAO': 2, 'B-TEMPO': 1, 'I-TEMPO': 1, 'B-LOCAL': 3, 'B-ORGANIZACAO': 4, 'I-ORGANIZACAO': 9, 'I-LOCAL': 4}
#
# Documento: dav-52390
# Contagem de rótulos: {'O': 1327, 'B-PESSOA': 63, 'I-PESSOA': 63, 'B-ORGANIZACAO': 20, 'B-OBRA': 17, 'I-OBRA': 41, 'B-ACONTECIMENTO': 32, 'I-ACONTECIMENTO': 76, 'B-COISA': 16, 'I-COISA': 14, 'B-TEMPO': 35, 'I-TEMPO': 85, 'B-OUTRO': 5, 'I-OUTRO': 6, 'B-ABSTRACCAO': 4, 'I-ABSTRACCAO': 2, 'I-ORGANIZACAO': 14, 'B-LOCAL': 42, 'I-LOCAL': 26}
#
# Documento: aa40383
# Contagem de rótulos: {'O': 1090, 'B-TEMPO': 18, 'I-TEMPO': 30, 'B-PESSOA': 43, 'I-PESSOA': 32, 'B-ORGANIZACAO': 7, 'B-OUTRO': 1, 'I-OUTRO': 2, 'B-ACONTECIMENTO': 5, 'B-LOCAL': 6, 'B-OBRA': 1, 'I-OBRA': 1, 'I-ORGANIZACAO': 5, 'B-VALOR': 1}
#
# Documento: wpt-101789548982731354
# Contagem de rótulos: {'O': 131, 'B-LOCAL': 1, 'B-TEMPO': 1, 'B-ORGANIZACAO': 11, 'I-ORGANIZACAO': 6, 'B-OUTRO': 1}
#
# Documento: hub-44595
# Contagem de rótulos: {'B-ACONTECIMENTO': 8, 'O': 220, 'B-PESSOA': 18, 'B-TEMPO': 5, 'I-TEMPO': 6, 'I-PESSOA': 10, 'I-ACONTECIMENTO': 13, 'B-LOCAL': 6, 'B-OUTRO': 4, 'B-VALOR': 1, 'I-VALOR': 3}
#
# Documento: ven-098
# Contagem de rótulos: {'O': 355, 'B-PESSOA': 14, 'I-PESSOA': 18, 'B-LOCAL': 7, 'B-ORGANIZACAO': 8, 'B-ABSTRACCAO': 3, 'I-ABSTRACCAO': 2, 'B-VALOR': 2, 'I-ORGANIZACAO': 8, 'B-TEMPO': 4, 'I-TEMPO': 8, 'B-COISA': 1, 'I-COISA': 2, 'I-LOCAL': 2}
#
# Documento: hjlll
# Contagem de rótulos: {'B-ORGANIZACAO': 26, 'I-ORGANIZACAO': 20, 'O': 367, 'B-LOCAL': 7, 'B-TEMPO': 7, 'I-TEMPO': 10, 'B-VALOR': 3, 'I-VALOR': 5, 'B-ACONTECIMENTO': 5, 'I-ACONTECIMENTO': 10, 'B-COISA': 1, 'I-COISA': 1, 'B-PESSOA': 5, 'I-PESSOA': 4, 'B-ABSTRACCAO': 4, 'I-ABSTRACCAO': 9, 'I-LOCAL': 4}
#
# Documento: hub-41899
# Contagem de rótulos: {'B-PESSOA': 23, 'I-PESSOA': 25, 'O': 299, 'B-LOCAL': 7, 'B-ACONTECIMENTO': 1, 'B-TEMPO': 8, 'I-TEMPO': 10, 'I-LOCAL': 2, 'B-OBRA': 3, 'I-OBRA': 5, 'B-VALOR': 1, 'I-VALOR': 1, 'B-COISA': 2, 'B-ORGANIZACAO': 2, 'B-ABSTRACCAO': 2, 'I-ABSTRACCAO': 2}
#
# Documento: hub-78051
# Contagem de rótulos: {'B-PESSOA': 7, 'O': 163, 'B-ACONTECIMENTO': 2, 'B-LOCAL': 8, 'I-LOCAL': 3, 'I-PESSOA': 3, 'B-TEMPO': 2, 'I-TEMPO': 5, 'B-ABSTRACCAO': 1}
#
# Documento: hub-81551
# Contagem de rótulos: {'B-ACONTECIMENTO': 3, 'I-ACONTECIMENTO': 4, 'O': 434, 'B-TEMPO': 12, 'I-TEMPO': 28, 'B-VALOR': 8, 'I-VALOR': 18, 'B-LOCAL': 22, 'I-LOCAL': 9, 'B-OBRA': 9, 'I-OBRA': 16, 'B-PESSOA': 6, 'I-PESSOA': 5}
#
# Documento: ric-54609
# Contagem de rótulos: {'O': 265, 'B-LOCAL': 4, 'B-PESSOA': 10, 'I-PESSOA': 4, 'I-LOCAL': 5, 'B-TEMPO': 2, 'I-TEMPO': 6, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 1, 'B-ORGANIZACAO': 3, 'I-ORGANIZACAO': 8, 'B-OBRA': 3, 'I-OBRA': 4}
#
# Documento: hub-83689
# Contagem de rótulos: {'B-PESSOA': 18, 'I-PESSOA': 24, 'O': 293, 'B-TEMPO': 7, 'I-TEMPO': 16, 'B-ABSTRACCAO': 2, 'I-ABSTRACCAO': 4, 'B-LOCAL': 17, 'I-LOCAL': 6, 'B-VALOR': 3, 'I-VALOR': 1, 'B-ORGANIZACAO': 1, 'B-OBRA': 1, 'I-OBRA': 2}
#
# Documento: hub-94570
# Contagem de rótulos: {'O': 270, 'B-TEMPO': 4, 'I-TEMPO': 4, 'B-PESSOA': 5, 'I-PESSOA': 6, 'B-LOCAL': 6, 'I-LOCAL': 4, 'B-OUTRO': 1, 'I-OUTRO': 4, 'B-COISA': 2, 'B-ABSTRACCAO': 2, 'B-VALOR': 2, 'I-VALOR': 4}
#
# Documento: hub-94890
# Contagem de rótulos: {'B-ACONTECIMENTO': 5, 'O': 266, 'B-TEMPO': 15, 'I-TEMPO': 20, 'B-VALOR': 4, 'I-VALOR': 9, 'B-LOCAL': 14, 'B-PESSOA': 5, 'I-PESSOA': 6, 'I-LOCAL': 6, 'B-OBRA': 1, 'I-OBRA': 3}
#
# Documento: hub-66746
# Contagem de rótulos: {'B-PESSOA': 11, 'I-PESSOA': 14, 'O': 213, 'B-TEMPO': 7, 'I-TEMPO': 13, 'B-ORGANIZACAO': 15, 'I-ORGANIZACAO': 6, 'B-VALOR': 1, 'B-OBRA': 2, 'I-OBRA': 4, 'B-LOCAL': 1}
#
# Documento: hub-30518
# Contagem de rótulos: {'O': 325, 'B-COISA': 9, 'B-ACONTECIMENTO': 1, 'I-ACONTECIMENTO': 2, 'B-TEMPO': 3, 'I-TEMPO': 8, 'B-PESSOA': 2, 'I-PESSOA': 3, 'I-COISA': 4, 'B-ABSTRACCAO': 1, 'B-LOCAL': 3, 'I-LOCAL': 1}
#
# Documento: hub-16268
# Contagem de rótulos: {'B-ORGANIZACAO': 16, 'O': 238, 'I-ORGANIZACAO': 13, 'B-TEMPO': 4, 'B-COISA': 4, 'B-LOCAL': 27, 'I-LOCAL': 17, 'B-PESSOA': 1, 'I-PESSOA': 1, 'I-TEMPO': 5, 'B-OBRA': 1, 'B-VALOR': 1, 'I-VALOR': 2}
#
# Documento: hub-57257
# Contagem de rótulos: {'O': 242, 'B-OBRA': 8, 'I-OBRA': 8, 'B-TEMPO': 5, 'B-VALOR': 2, 'B-PESSOA': 17, 'I-PESSOA': 19, 'I-TEMPO': 7, 'B-ORGANIZACAO': 3, 'I-ORGANIZACAO': 2, 'B-LOCAL': 2, 'I-VALOR': 1}
#
# Documento: cver
# Contagem de rótulos: {'O': 782, 'B-PESSOA': 18, 'I-PESSOA': 9, 'B-ACONTECIMENTO': 3, 'I-ACONTECIMENTO': 2, 'B-LOCAL': 21, 'B-ORGANIZACAO': 37, 'B-TEMPO': 5, 'I-TEMPO': 11, 'I-LOCAL': 2, 'I-ORGANIZACAO': 5, 'B-ABSTRACCAO': 1}
#
# Documento: hub-67792
# Contagem de rótulos: {'B-PESSOA': 10, 'I-PESSOA': 12, 'O': 307, 'B-ABSTRACCAO': 3, 'B-ORGANIZACAO': 6, 'I-ORGANIZACAO': 13, 'B-LOCAL': 22, 'B-TEMPO': 13, 'I-TEMPO': 16, 'I-LOCAL': 9, 'B-OBRA': 1, 'I-OBRA': 5, 'B-ACONTECIMENTO': 3, 'I-ACONTECIMENTO': 3, 'B-VALOR': 2, 'I-VALOR': 1}
#
# Documento: Ntyr-78
# Contagem de rótulos: {'B-ACONTECIMENTO': 7, 'I-ACONTECIMENTO': 15, 'O': 566, 'B-LOCAL': 20, 'I-LOCAL': 11, 'B-TEMPO': 22, 'I-TEMPO': 53, 'B-ORGANIZACAO': 5, 'B-PESSOA': 43, 'I-PESSOA': 51, 'B-VALOR': 16, 'I-VALOR': 24, 'I-ORGANIZACAO': 1, 'B-OBRA': 5, 'I-OBRA': 13}
#
# Documento: gtqqq
# Contagem de rótulos: {'O': 1457, 'B-PESSOA': 27, 'I-PESSOA': 20, 'B-LOCAL': 12, 'B-TEMPO': 12, 'I-TEMPO': 22, 'B-ACONTECIMENTO': 2, 'I-ACONTECIMENTO': 4, 'B-ABSTRACCAO': 30, 'I-ABSTRACCAO': 27, 'I-LOCAL': 1, 'B-ORGANIZACAO': 1, 'B-OBRA': 3, 'I-OBRA': 10, 'B-COISA': 1}
#
# Documento: aa77651
# Contagem de rótulos: {'B-ORGANIZACAO': 10, 'I-ORGANIZACAO': 20, 'B-PESSOA': 24, 'I-PESSOA': 64, 'O': 121, 'B-LOCAL': 11, 'B-TEMPO': 3, 'I-TEMPO': 13, 'I-LOCAL': 5, 'B-VALOR': 1}
#
# Documento: wpt-1014517543841152414
# Contagem de rótulos: {'O': 217, 'B-COISA': 3, 'I-COISA': 2, 'B-ORGANIZACAO': 1, 'B-VALOR': 6, 'B-LOCAL': 3, 'I-VALOR': 4, 'B-TEMPO': 2, 'I-TEMPO': 5}
#
# Documento: ric-74122
# Contagem de rótulos: {'O': 1468, 'B-PESSOA': 80, 'I-PESSOA': 63, 'B-TEMPO': 12, 'I-TEMPO': 22, 'B-ORGANIZACAO': 6, 'I-ORGANIZACAO': 4, 'B-OBRA': 23, 'I-OBRA': 41, 'B-COISA': 20, 'I-COISA': 10, 'B-ABSTRACCAO': 8, 'I-ABSTRACCAO': 11, 'B-ACONTECIMENTO': 1, 'I-ACONTECIMENTO': 4, 'B-LOCAL': 5, 'I-LOCAL': 2, 'B-OUTRO': 2}
#
# Documento: hub-77889
# Contagem de rótulos: {'B-ORGANIZACAO': 9, 'O': 154, 'B-TEMPO': 5, 'I-TEMPO': 4, 'I-ORGANIZACAO': 6, 'B-COISA': 5, 'B-ACONTECIMENTO': 2, 'I-ACONTECIMENTO': 4, 'B-PESSOA': 3, 'I-PESSOA': 5, 'I-COISA': 1}
#
# Documento: H2-dftre765
# Contagem de rótulos: {'O': 927, 'B-ABSTRACCAO': 25, 'I-ABSTRACCAO': 17, 'B-OUTRO': 1, 'I-OUTRO': 1, 'B-LOCAL': 16, 'B-ACONTECIMENTO': 8, 'I-ACONTECIMENTO': 5, 'B-TEMPO': 15, 'I-TEMPO': 20, 'B-PESSOA': 39, 'I-PESSOA': 27, 'B-OBRA': 11, 'I-OBRA': 31, 'B-ORGANIZACAO': 17, 'I-ORGANIZACAO': 7}
#
# Documento: hub-47914
# Contagem de rótulos: {'O': 446, 'B-OBRA': 6, 'B-PESSOA': 4, 'B-TEMPO': 1, 'I-TEMPO': 3, 'B-ORGANIZACAO': 3, 'I-ORGANIZACAO': 2, 'B-COISA': 2, 'B-ABSTRACCAO': 1, 'I-OBRA': 3, 'B-LOCAL': 2, 'I-LOCAL': 2, 'B-OUTRO': 1}
#
# Documento: dav-188222
# Contagem de rótulos: {'O': 1425, 'B-TEMPO': 27, 'I-TEMPO': 48, 'B-LOCAL': 37, 'B-PESSOA': 51, 'I-PESSOA': 40, 'I-LOCAL': 22, 'B-ABSTRACCAO': 2, 'I-ABSTRACCAO': 4, 'B-ORGANIZACAO': 13, 'I-ORGANIZACAO': 4, 'B-COISA': 12, 'B-ACONTECIMENTO': 4, 'I-ACONTECIMENTO': 7, 'B-OBRA': 8, 'I-OBRA': 18, 'B-VALOR': 2, 'I-VALOR': 9, 'I-COISA': 1, 'B-OUTRO': 1, 'I-OUTRO': 3}
#
# Documento: wpt-1001951616378060469
# Contagem de rótulos: {'O': 145, 'B-ORGANIZACAO': 1, 'I-ORGANIZACAO': 7, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 3}
#
# Documento: aa33715
# Contagem de rótulos: {'O': 260, 'B-PESSOA': 15, 'I-PESSOA': 20, 'B-ORGANIZACAO': 13, 'B-ABSTRACCAO': 3, 'I-ABSTRACCAO': 3, 'B-TEMPO': 3, 'I-TEMPO': 5, 'I-ORGANIZACAO': 6, 'B-VALOR': 2, 'I-VALOR': 4, 'B-COISA': 1}
#
# Documento: hub-37819
# Contagem de rótulos: {'B-PESSOA': 22, 'O': 229, 'I-PESSOA': 9, 'B-TEMPO': 9, 'I-TEMPO': 15, 'B-VALOR': 11, 'B-LOCAL': 5, 'I-LOCAL': 1, 'B-ACONTECIMENTO': 3, 'I-ACONTECIMENTO': 4, 'I-VALOR': 1}
#
# Documento: ric-46913
# Contagem de rótulos: {'O': 538, 'B-ABSTRACCAO': 16, 'I-ABSTRACCAO': 6, 'B-TEMPO': 6, 'I-TEMPO': 10, 'B-LOCAL': 4, 'I-LOCAL': 2, 'B-PESSOA': 3, 'B-COISA': 1, 'I-PESSOA': 3, 'B-OUTRO': 1, 'I-OUTRO': 1}
#
# Documento: hub-24360
# Contagem de rótulos: {'O': 337, 'B-ORGANIZACAO': 10, 'B-OUTRO': 1, 'I-OUTRO': 5, 'B-TEMPO': 3, 'I-TEMPO': 6, 'B-PESSOA': 5, 'I-PESSOA': 6, 'I-ORGANIZACAO': 4, 'B-LOCAL': 1, 'B-ABSTRACCAO': 4}
#
# Documento: H2-Ert75
# Contagem de rótulos: {'O': 503, 'B-PESSOA': 6, 'I-PESSOA': 9, 'B-LOCAL': 18, 'I-LOCAL': 12, 'B-TEMPO': 5, 'B-ORGANIZACAO': 1, 'I-TEMPO': 3, 'B-VALOR': 2, 'I-VALOR': 1}
#
# Documento: aa46996
# Contagem de rótulos: {'O': 1060, 'B-TEMPO': 17, 'I-TEMPO': 37, 'B-ORGANIZACAO': 45, 'I-ORGANIZACAO': 23, 'B-OBRA': 35, 'I-OBRA': 107, 'B-ACONTECIMENTO': 3, 'I-ACONTECIMENTO': 3, 'B-LOCAL': 17, 'I-LOCAL': 5, 'B-ABSTRACCAO': 5, 'I-ABSTRACCAO': 9, 'B-VALOR': 2, 'I-VALOR': 4, 'B-PESSOA': 7, 'I-PESSOA': 25}
#
# Documento: aa94781
# Contagem de rótulos: {'O': 387, 'B-PESSOA': 17, 'I-PESSOA': 16, 'B-TEMPO': 13, 'I-TEMPO': 23, 'B-OBRA': 2, 'I-OBRA': 3, 'B-OUTRO': 1, 'I-OUTRO': 1, 'B-LOCAL': 13, 'I-LOCAL': 2, 'B-ORGANIZACAO': 3, 'I-ORGANIZACAO': 4, 'B-COISA': 1, 'B-ACONTECIMENTO': 2, 'I-ACONTECIMENTO': 2}
#
# Documento: hub-15425
# Contagem de rótulos: {'B-OBRA': 10, 'I-OBRA': 15, 'O': 191, 'B-TEMPO': 13, 'B-ORGANIZACAO': 10, 'I-ORGANIZACAO': 10, 'B-LOCAL': 3, 'I-TEMPO': 38, 'B-ABSTRACCAO': 3, 'B-PESSOA': 4, 'I-PESSOA': 24, 'B-VALOR': 1, 'I-ABSTRACCAO': 5, 'B-ACONTECIMENTO': 1, 'I-LOCAL': 2}
#
# Documento: H2-EFin
# Contagem de rótulos: {'O': 358, 'B-TEMPO': 9, 'I-TEMPO': 10, 'B-LOCAL': 14, 'B-PESSOA': 4, 'I-PESSOA': 9, 'I-LOCAL': 10, 'B-COISA': 3}
#
# Documento: ric-12366
# Contagem de rótulos: {'O': 828, 'B-PESSOA': 17, 'I-PESSOA': 7, 'B-LOCAL': 20, 'I-LOCAL': 15, 'B-COISA': 11, 'B-TEMPO': 9, 'I-TEMPO': 10, 'B-ORGANIZACAO': 3, 'I-ORGANIZACAO': 9, 'B-VALOR': 3, 'I-VALOR': 3}
#
# Documento: wpt-1011130529557294176
# Contagem de rótulos: {'O': 301, 'B-LOCAL': 3, 'I-LOCAL': 2, 'B-ABSTRACCAO': 5, 'B-TEMPO': 3, 'I-TEMPO': 10, 'B-OBRA': 2, 'I-OBRA': 17, 'B-PESSOA': 3, 'I-PESSOA': 6, 'B-ORGANIZACAO': 8, 'I-ORGANIZACAO': 19}

# %%
# labels_por_doc['HAREMdoc_aa64686'][-12]
# len(labels_por_doc['HAREMdoc_aa64686'])

# %%
from collections import Counter

# Inicializar um dicionário para armazenar contagens de rótulos por documento
# antes e depois de simplificar.
labels_por_doc = {}
labels_por_doc_simplificado = {}

for docName, docData in data_por_sentenca_por_doc.items():
    allDocData = []
    
    # Concatenar todas as sentenças de um documento em uma lista
    for sentence in docData:
        allDocData += [i for i in sentence]
    
    # Separar tokens e rótulos
    docTokens, docLabels = split_token_label(allDocData)
    
    # Contagem de rótulos com os prefixos (original)
    labels_count_original = Counter(docLabels)
    labels_por_doc[docName] = dict(labels_count_original)
    
    # Extração da última parte do rótulo (ex. 'B-PER' vira 'PER')
    labels_simplificados = [lbl.split('-')[-1] for lbl in docLabels]
    labels_count_simplificado = Counter(labels_simplificados)
    labels_por_doc_simplificado[docName] = dict(labels_count_simplificado)

# Exibir a contagem original e simplificada para comparação
for doc in labels_por_doc.keys():
    print(f"Documento: {doc}")
    print("Contagem de rótulos (original):", labels_por_doc[doc])
    print("Contagem de rótulos (simplificado):", labels_por_doc_simplificado[doc])
    print()

# Exibir o total de documentos
print("Total de documentos:", len(labels_por_doc))
# Out:
# Documento: ric-78733
# Contagem de rótulos (original): {'B-ACONTECIMENTO': 7, 'I-ACONTECIMENTO': 3, 'O': 454, 'B-TEMPO': 13, 'I-TEMPO': 29, 'B-OBRA': 3, 'I-OBRA': 4, 'B-LOCAL': 11, 'B-PESSOA': 25, 'I-PESSOA': 11, 'B-VALOR': 1, 'B-ORGANIZACAO': 5, 'I-ORGANIZACAO': 14, 'B-ABSTRACCAO': 6, 'B-COISA': 7}
# Contagem de rótulos (simplificado): {'ACONTECIMENTO': 10, 'O': 454, 'TEMPO': 42, 'OBRA': 7, 'LOCAL': 11, 'PESSOA': 36, 'VALOR': 1, 'ORGANIZACAO': 19, 'ABSTRACCAO': 6, 'COISA': 7}
#
# Documento: wpt-1000772700099419796
# Contagem de rótulos (original): {'B-PESSOA': 21, 'I-PESSOA': 24, 'O': 456, 'B-TEMPO': 7, 'I-TEMPO': 16, 'B-ACONTECIMENTO': 5, 'I-ACONTECIMENTO': 11, 'B-COISA': 13, 'I-COISA': 6, 'B-LOCAL': 2, 'I-LOCAL': 2, 'B-VALOR': 11, 'B-OUTRO': 2}
# Contagem de rótulos (simplificado): {'PESSOA': 45, 'O': 456, 'TEMPO': 23, 'ACONTECIMENTO': 16, 'COISA': 19, 'LOCAL': 4, 'VALOR': 11, 'OUTRO': 2}
#
# Documento: dav-844651
# Contagem de rótulos (original): {'O': 1125, 'B-TEMPO': 19, 'I-TEMPO': 25, 'B-OBRA': 4, 'I-OBRA': 6, 'B-LOCAL': 51, 'B-PESSOA': 40, 'I-PESSOA': 41, 'B-COISA': 12, 'B-OUTRO': 3, 'I-OUTRO': 6, 'B-ABSTRACCAO': 5, 'B-ORGANIZACAO': 7, 'I-ORGANIZACAO': 5, 'I-COISA': 4, 'B-ACONTECIMENTO': 16, 'I-ACONTECIMENTO': 26, 'B-VALOR': 1, 'I-LOCAL': 19, 'I-ABSTRACCAO': 1}
# Contagem de rótulos (simplificado): {'O': 1125, 'TEMPO': 44, 'OBRA': 10, 'LOCAL': 70, 'PESSOA': 81, 'COISA': 16, 'OUTRO': 9, 'ABSTRACCAO': 6, 'ORGANIZACAO': 12, 'ACONTECIMENTO': 42, 'VALOR': 1}
#
# Documento: hub-5080
# Contagem de rótulos (original): {'O': 75, 'B-ACONTECIMENTO': 5, 'I-ACONTECIMENTO': 8, 'B-TEMPO': 3, 'I-TEMPO': 5, 'B-LOCAL': 4, 'B-VALOR': 2, 'I-VALOR': 2, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 1, 'B-PESSOA': 1, 'I-PESSOA': 1}
# Contagem de rótulos (simplificado): {'O': 75, 'ACONTECIMENTO': 13, 'TEMPO': 8, 'LOCAL': 4, 'VALOR': 4, 'ABSTRACCAO': 2, 'PESSOA': 2}
#
# Documento: hub-68694
# Contagem de rótulos (original): {'O': 182, 'B-COISA': 3, 'B-ORGANIZACAO': 4, 'B-ABSTRACCAO': 2, 'I-ABSTRACCAO': 2, 'B-LOCAL': 4, 'B-TEMPO': 3, 'I-TEMPO': 4, 'B-OBRA': 1, 'I-OBRA': 4, 'I-COISA': 1}
# Contagem de rótulos (simplificado): {'O': 182, 'COISA': 4, 'ORGANIZACAO': 4, 'ABSTRACCAO': 4, 'LOCAL': 4, 'TEMPO': 7, 'OBRA': 5}
#
# Documento: ric-11625
# Contagem de rótulos (original): {'O': 1127, 'B-ABSTRACCAO': 48, 'B-LOCAL': 23, 'I-ABSTRACCAO': 4, 'I-LOCAL': 5, 'B-TEMPO': 10, 'I-TEMPO': 16, 'B-PESSOA': 4, 'I-PESSOA': 6, 'B-COISA': 4, 'B-OUTRO': 2, 'B-OBRA': 1, 'I-OBRA': 2}
# Contagem de rótulos (simplificado): {'O': 1127, 'ABSTRACCAO': 52, 'LOCAL': 28, 'TEMPO': 26, 'PESSOA': 10, 'COISA': 4, 'OUTRO': 2, 'OBRA': 3}
#
# Documento: ric-53646
# Contagem de rótulos (original): {'B-PESSOA': 12, 'O': 484, 'B-ORGANIZACAO': 11, 'I-ORGANIZACAO': 19, 'B-TEMPO': 4, 'I-TEMPO': 9, 'B-ACONTECIMENTO': 5, 'I-ACONTECIMENTO': 7, 'B-LOCAL': 9, 'B-OBRA': 4, 'I-OBRA': 16, 'I-LOCAL': 6, 'B-COISA': 4, 'I-COISA': 2, 'B-VALOR': 2, 'I-VALOR': 2, 'I-PESSOA': 19, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 1}
# Contagem de rótulos (simplificado): {'PESSOA': 31, 'O': 484, 'ORGANIZACAO': 30, 'TEMPO': 13, 'ACONTECIMENTO': 12, 'LOCAL': 15, 'OBRA': 20, 'COISA': 6, 'VALOR': 4, 'ABSTRACCAO': 2}
#
# Documento: Ytr433
# Contagem de rótulos (original): {'B-PESSOA': 11, 'O': 204, 'B-TEMPO': 3, 'I-TEMPO': 3, 'B-LOCAL': 5, 'I-LOCAL': 3, 'B-ORGANIZACAO': 2, 'B-VALOR': 3, 'B-COISA': 1, 'I-COISA': 3, 'I-VALOR': 4, 'I-PESSOA': 1}
# Contagem de rótulos (simplificado): {'PESSOA': 12, 'O': 204, 'TEMPO': 6, 'LOCAL': 8, 'ORGANIZACAO': 2, 'VALOR': 7, 'COISA': 4}
#
# Documento: aa87333
# Contagem de rótulos (original): {'O': 1351, 'B-LOCAL': 47, 'B-TEMPO': 50, 'I-TEMPO': 119, 'B-PESSOA': 57, 'I-PESSOA': 62, 'I-LOCAL': 44, 'B-ORGANIZACAO': 18, 'I-ORGANIZACAO': 38, 'B-VALOR': 5, 'B-ABSTRACCAO': 10, 'I-ABSTRACCAO': 22, 'I-VALOR': 2, 'B-OUTRO': 7, 'I-OUTRO': 10, 'B-COISA': 5, 'I-COISA': 2, 'B-OBRA': 12, 'I-OBRA': 20}
# Contagem de rótulos (simplificado): {'O': 1351, 'LOCAL': 91, 'TEMPO': 169, 'PESSOA': 119, 'ORGANIZACAO': 56, 'VALOR': 7, 'ABSTRACCAO': 32, 'OUTRO': 17, 'COISA': 7, 'OBRA': 32}
#
# Documento: hub-37295
# Contagem de rótulos (original): {'B-ACONTECIMENTO': 2, 'O': 179, 'B-LOCAL': 6, 'B-PESSOA': 4, 'I-PESSOA': 4, 'B-TEMPO': 6, 'I-TEMPO': 10, 'B-COISA': 1, 'I-COISA': 1, 'B-VALOR': 1, 'I-VALOR': 2}
# Contagem de rótulos (simplificado): {'ACONTECIMENTO': 2, 'O': 179, 'LOCAL': 6, 'PESSOA': 8, 'TEMPO': 16, 'COISA': 2, 'VALOR': 3}
#
# Documento: aa58069
# Contagem de rótulos (original): {'O': 711, 'B-VALOR': 13, 'I-VALOR': 14, 'B-TEMPO': 21, 'B-PESSOA': 14, 'I-PESSOA': 15, 'I-TEMPO': 32, 'B-LOCAL': 19, 'I-LOCAL': 3, 'B-COISA': 1, 'I-COISA': 4, 'B-ORGANIZACAO': 12, 'I-ORGANIZACAO': 3}
# Contagem de rótulos (simplificado): {'O': 711, 'VALOR': 27, 'TEMPO': 53, 'PESSOA': 29, 'LOCAL': 22, 'COISA': 5, 'ORGANIZACAO': 15}
#
# Documento: ric-81275
# Contagem de rótulos (original): {'O': 703, 'B-COISA': 7, 'I-COISA': 2, 'B-PESSOA': 20, 'I-PESSOA': 19, 'B-TEMPO': 6, 'I-TEMPO': 15, 'B-ABSTRACCAO': 9, 'B-LOCAL': 3, 'B-OBRA': 6, 'I-OBRA': 13, 'I-LOCAL': 3, 'I-ABSTRACCAO': 7}
# Contagem de rótulos (simplificado): {'O': 703, 'COISA': 9, 'PESSOA': 39, 'TEMPO': 21, 'ABSTRACCAO': 16, 'LOCAL': 6, 'OBRA': 19}
#
# Documento: wpt-1019468604217317242
# Contagem de rótulos (original): {'B-OBRA': 23, 'I-OBRA': 73, 'O': 224, 'B-TEMPO': 7, 'I-TEMPO': 29, 'B-ORGANIZACAO': 15, 'I-ORGANIZACAO': 9, 'B-OUTRO': 3, 'I-OUTRO': 9, 'B-LOCAL': 3, 'I-LOCAL': 1}
# Contagem de rótulos (simplificado): {'OBRA': 96, 'O': 224, 'TEMPO': 36, 'ORGANIZACAO': 24, 'OUTRO': 12, 'LOCAL': 4}
#
# Documento: hub-2701
# Contagem de rótulos (original): {'O': 494, 'B-OBRA': 2, 'I-OBRA': 2, 'B-TEMPO': 5, 'I-TEMPO': 8, 'B-ORGANIZACAO': 17, 'B-PESSOA': 9, 'I-PESSOA': 2, 'B-LOCAL': 1}
# Contagem de rótulos (simplificado): {'O': 494, 'OBRA': 4, 'TEMPO': 13, 'ORGANIZACAO': 17, 'PESSOA': 11, 'LOCAL': 1}
#
# Documento: hub-60382
# Contagem de rótulos (original): {'B-ACONTECIMENTO': 5, 'O': 288, 'B-PESSOA': 17, 'I-PESSOA': 4, 'B-LOCAL': 3, 'B-ORGANIZACAO': 2, 'B-TEMPO': 9, 'I-TEMPO': 14, 'B-OBRA': 2, 'I-OBRA': 2, 'B-VALOR': 2, 'I-VALOR': 2, 'B-OUTRO': 1, 'I-OUTRO': 1, 'I-LOCAL': 2}
# Contagem de rótulos (simplificado): {'ACONTECIMENTO': 5, 'O': 288, 'PESSOA': 21, 'LOCAL': 5, 'ORGANIZACAO': 2, 'TEMPO': 23, 'OBRA': 4, 'VALOR': 4, 'OUTRO': 2}
#
# Documento: hub-56266
# Contagem de rótulos (original): {'O': 267, 'B-ACONTECIMENTO': 2, 'I-ACONTECIMENTO': 1, 'B-ORGANIZACAO': 6, 'B-COISA': 10, 'B-TEMPO': 8, 'I-TEMPO': 14, 'I-COISA': 3, 'B-LOCAL': 6, 'I-LOCAL': 1, 'B-PESSOA': 2, 'I-PESSOA': 2, 'B-VALOR': 7, 'I-VALOR': 11}
# Contagem de rótulos (simplificado): {'O': 267, 'ACONTECIMENTO': 3, 'ORGANIZACAO': 6, 'COISA': 13, 'TEMPO': 22, 'LOCAL': 7, 'PESSOA': 4, 'VALOR': 18}
#
# Documento: ric-58766
# Contagem de rótulos (original): {'B-TEMPO': 4, 'I-TEMPO': 6, 'O': 439, 'B-LOCAL': 27, 'B-VALOR': 11, 'I-VALOR': 16, 'I-LOCAL': 30, 'B-COISA': 6, 'I-COISA': 10, 'B-ORGANIZACAO': 2, 'B-PESSOA': 1}
# Contagem de rótulos (simplificado): {'TEMPO': 10, 'O': 439, 'LOCAL': 57, 'VALOR': 27, 'COISA': 16, 'ORGANIZACAO': 2, 'PESSOA': 1}
#
# Documento: hub-49343
# Contagem de rótulos (original): {'B-PESSOA': 14, 'I-PESSOA': 28, 'O': 334, 'B-TEMPO': 15, 'I-TEMPO': 26, 'B-LOCAL': 33, 'B-ORGANIZACAO': 9, 'I-ORGANIZACAO': 7, 'I-LOCAL': 17, 'B-VALOR': 1, 'I-VALOR': 1, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 4}
# Contagem de rótulos (simplificado): {'PESSOA': 42, 'O': 334, 'TEMPO': 41, 'LOCAL': 50, 'ORGANIZACAO': 16, 'VALOR': 2, 'ABSTRACCAO': 5}
#
# Documento: aa66435
# Contagem de rótulos (original): {'O': 849, 'B-ORGANIZACAO': 16, 'B-PESSOA': 14, 'I-PESSOA': 7, 'B-LOCAL': 14, 'B-OUTRO': 2, 'I-LOCAL': 1, 'B-ACONTECIMENTO': 4, 'B-TEMPO': 11, 'I-TEMPO': 21, 'B-ABSTRACCAO': 4, 'I-ACONTECIMENTO': 1, 'B-OBRA': 1, 'I-OUTRO': 1, 'B-VALOR': 1, 'I-VALOR': 1, 'I-ORGANIZACAO': 2}
# Contagem de rótulos (simplificado): {'O': 849, 'ORGANIZACAO': 18, 'PESSOA': 21, 'LOCAL': 15, 'OUTRO': 3, 'ACONTECIMENTO': 5, 'TEMPO': 32, 'ABSTRACCAO': 4, 'OBRA': 1, 'VALOR': 2}
#
# Documento: H2-dhy6432
# Contagem de rótulos (original): {'O': 328, 'B-TEMPO': 7, 'I-TEMPO': 21, 'B-LOCAL': 9, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 1, 'B-OBRA': 1, 'I-OBRA': 2, 'B-VALOR': 1, 'I-VALOR': 2, 'B-ORGANIZACAO': 1, 'I-ORGANIZACAO': 3}
# Contagem de rótulos (simplificado): {'O': 328, 'TEMPO': 28, 'LOCAL': 9, 'ABSTRACCAO': 2, 'OBRA': 3, 'VALOR': 3, 'ORGANIZACAO': 4}
#
# Documento: DR-PT5
# Contagem de rótulos (original): {'B-ORGANIZACAO': 7, 'I-ORGANIZACAO': 29, 'O': 202, 'B-OBRA': 3, 'I-OBRA': 6, 'B-TEMPO': 6, 'I-TEMPO': 23, 'B-LOCAL': 7, 'B-PESSOA': 7, 'I-PESSOA': 47, 'B-VALOR': 3, 'I-VALOR': 3, 'I-LOCAL': 6}
# Contagem de rótulos (simplificado): {'ORGANIZACAO': 36, 'O': 202, 'OBRA': 9, 'TEMPO': 29, 'LOCAL': 13, 'PESSOA': 54, 'VALOR': 6}
#
# Documento: ric-22961
# Contagem de rótulos (original): {'O': 974, 'B-PESSOA': 3, 'I-PESSOA': 2, 'B-LOCAL': 19, 'B-TEMPO': 14, 'I-TEMPO': 35, 'B-ORGANIZACAO': 11, 'I-ORGANIZACAO': 11, 'B-ABSTRACCAO': 4, 'I-ABSTRACCAO': 13, 'I-LOCAL': 10, 'B-OUTRO': 1, 'B-VALOR': 3}
# Contagem de rótulos (simplificado): {'O': 974, 'PESSOA': 5, 'LOCAL': 29, 'TEMPO': 49, 'ORGANIZACAO': 22, 'ABSTRACCAO': 17, 'OUTRO': 1, 'VALOR': 3}
#
# Documento: hub-93257
# Contagem de rótulos (original): {'B-PESSOA': 23, 'I-PESSOA': 20, 'O': 398, 'B-ACONTECIMENTO': 2, 'I-ACONTECIMENTO': 4, 'B-LOCAL': 12, 'B-ORGANIZACAO': 6, 'I-ORGANIZACAO': 2, 'B-OBRA': 1, 'I-OBRA': 1, 'B-TEMPO': 6, 'I-TEMPO': 22, 'I-LOCAL': 1}
# Contagem de rótulos (simplificado): {'PESSOA': 43, 'O': 398, 'ACONTECIMENTO': 6, 'LOCAL': 13, 'ORGANIZACAO': 8, 'OBRA': 2, 'TEMPO': 28}
#
# Documento: hub-21881
# Contagem de rótulos (original): {'B-TEMPO': 5, 'O': 184, 'B-ORGANIZACAO': 17, 'B-PESSOA': 2, 'I-ORGANIZACAO': 11, 'I-TEMPO': 8, 'I-PESSOA': 1, 'B-VALOR': 1}
# Contagem de rótulos (simplificado): {'TEMPO': 13, 'O': 184, 'ORGANIZACAO': 28, 'PESSOA': 3, 'VALOR': 1}
#
# Documento: hub-31642
# Contagem de rótulos (original): {'B-ACONTECIMENTO': 2, 'I-ACONTECIMENTO': 4, 'O': 165, 'B-TEMPO': 6, 'I-TEMPO': 7, 'B-PESSOA': 8, 'I-PESSOA': 9, 'B-LOCAL': 8, 'B-ORGANIZACAO': 5, 'I-LOCAL': 3}
# Contagem de rótulos (simplificado): {'ACONTECIMENTO': 6, 'O': 165, 'TEMPO': 13, 'PESSOA': 17, 'LOCAL': 11, 'ORGANIZACAO': 5}
#
# Documento: hub-74208
# Contagem de rótulos (original): {'O': 192, 'B-COISA': 8, 'B-TEMPO': 3, 'I-TEMPO': 7, 'B-ABSTRACCAO': 2, 'I-ABSTRACCAO': 1, 'B-LOCAL': 2, 'I-LOCAL': 3, 'B-VALOR': 7, 'I-VALOR': 7, 'B-PESSOA': 3, 'I-PESSOA': 3, 'I-COISA': 4, 'B-ORGANIZACAO': 1}
# Contagem de rótulos (simplificado): {'O': 192, 'COISA': 12, 'TEMPO': 10, 'ABSTRACCAO': 3, 'LOCAL': 5, 'VALOR': 14, 'PESSOA': 6, 'ORGANIZACAO': 1}
#
# Documento: ric-42664
# Contagem de rótulos (original): {'B-PESSOA': 19, 'O': 431, 'B-TEMPO': 9, 'I-TEMPO': 19, 'B-LOCAL': 15, 'I-PESSOA': 13, 'B-COISA': 10, 'I-COISA': 11, 'B-ABSTRACCAO': 5, 'I-ABSTRACCAO': 5, 'B-ACONTECIMENTO': 4, 'I-ACONTECIMENTO': 8, 'I-LOCAL': 5, 'B-ORGANIZACAO': 7, 'I-ORGANIZACAO': 13}
# Contagem de rótulos (simplificado): {'PESSOA': 32, 'O': 431, 'TEMPO': 28, 'LOCAL': 20, 'COISA': 21, 'ABSTRACCAO': 10, 'ACONTECIMENTO': 12, 'ORGANIZACAO': 20}
#
# Documento: bob-37600
# Contagem de rótulos (original): {'B-ABSTRACCAO': 19, 'I-ABSTRACCAO': 14, 'O': 684, 'B-OBRA': 26, 'B-ORGANIZACAO': 27, 'I-ORGANIZACAO': 51, 'I-OBRA': 73, 'B-LOCAL': 2, 'B-TEMPO': 2, 'B-ACONTECIMENTO': 2, 'I-ACONTECIMENTO': 12, 'B-VALOR': 1, 'B-PESSOA': 4, 'I-PESSOA': 3, 'I-TEMPO': 1}
# Contagem de rótulos (simplificado): {'ABSTRACCAO': 33, 'O': 684, 'OBRA': 99, 'ORGANIZACAO': 78, 'LOCAL': 2, 'TEMPO': 3, 'ACONTECIMENTO': 14, 'VALOR': 1, 'PESSOA': 7}
#
# Documento: hub-62214
# Contagem de rótulos (original): {'B-LOCAL': 9, 'I-LOCAL': 6, 'O': 264, 'B-PESSOA': 9, 'I-PESSOA': 15, 'B-TEMPO': 6, 'I-TEMPO': 6, 'B-OBRA': 2, 'I-OBRA': 8, 'B-ABSTRACCAO': 5, 'I-ABSTRACCAO': 7}
# Contagem de rótulos (simplificado): {'LOCAL': 15, 'O': 264, 'PESSOA': 24, 'TEMPO': 12, 'OBRA': 10, 'ABSTRACCAO': 12}
#
# Documento: hub-822
# Contagem de rótulos (original): {'B-COISA': 1, 'O': 128, 'B-ORGANIZACAO': 7, 'I-ORGANIZACAO': 9, 'B-TEMPO': 7, 'I-TEMPO': 12, 'B-VALOR': 6, 'I-VALOR': 4, 'B-LOCAL': 1}
# Contagem de rótulos (simplificado): {'COISA': 1, 'O': 128, 'ORGANIZACAO': 16, 'TEMPO': 19, 'VALOR': 10, 'LOCAL': 1}
#
# Documento: hub-39869
# Contagem de rótulos (original): {'B-TEMPO': 5, 'I-TEMPO': 6, 'O': 185, 'B-LOCAL': 9, 'B-PESSOA': 12, 'B-ACONTECIMENTO': 2, 'I-ACONTECIMENTO': 2, 'B-ORGANIZACAO': 12, 'I-ORGANIZACAO': 4, 'I-PESSOA': 6, 'I-LOCAL': 3}
# Contagem de rótulos (simplificado): {'TEMPO': 11, 'O': 185, 'LOCAL': 12, 'PESSOA': 18, 'ACONTECIMENTO': 4, 'ORGANIZACAO': 16}
#
# Documento: hub-43823
# Contagem de rótulos (original): {'O': 1205, 'B-ABSTRACCAO': 3, 'B-ORGANIZACAO': 35, 'B-PESSOA': 21, 'I-ORGANIZACAO': 3, 'B-LOCAL': 5, 'I-PESSOA': 14, 'B-TEMPO': 15, 'I-TEMPO': 24, 'I-LOCAL': 4, 'B-OBRA': 1}
# Contagem de rótulos (simplificado): {'O': 1205, 'ABSTRACCAO': 3, 'ORGANIZACAO': 38, 'PESSOA': 35, 'LOCAL': 9, 'TEMPO': 39, 'OBRA': 1}
#
# Documento: hub-398
# Contagem de rótulos (original): {'O': 105, 'B-PESSOA': 8, 'B-LOCAL': 5, 'I-LOCAL': 8, 'B-ORGANIZACAO': 2, 'B-TEMPO': 7, 'B-VALOR': 4, 'I-TEMPO': 3, 'B-ACONTECIMENTO': 1}
# Contagem de rótulos (simplificado): {'O': 105, 'PESSOA': 8, 'LOCAL': 13, 'ORGANIZACAO': 2, 'TEMPO': 10, 'VALOR': 4, 'ACONTECIMENTO': 1}
#
# Documento: ric-92221
# Contagem de rótulos (original): {'O': 325, 'B-ACONTECIMENTO': 3, 'B-VALOR': 7, 'I-VALOR': 4, 'I-ACONTECIMENTO': 4, 'B-LOCAL': 11, 'B-TEMPO': 2, 'I-TEMPO': 4, 'B-PESSOA': 19, 'I-PESSOA': 11, 'I-LOCAL': 10, 'B-ABSTRACCAO': 1, 'B-OUTRO': 1}
# Contagem de rótulos (simplificado): {'O': 325, 'ACONTECIMENTO': 7, 'VALOR': 11, 'LOCAL': 21, 'TEMPO': 6, 'PESSOA': 30, 'ABSTRACCAO': 1, 'OUTRO': 1}
#
# Documento: H2-Ren_2001_6414
# Contagem de rótulos (original): {'O': 215, 'B-ORGANIZACAO': 2, 'I-ORGANIZACAO': 2, 'B-LOCAL': 5, 'B-PESSOA': 3, 'I-PESSOA': 1, 'B-COISA': 3, 'B-TEMPO': 2, 'I-TEMPO': 2, 'B-VALOR': 2, 'I-LOCAL': 1}
# Contagem de rótulos (simplificado): {'O': 215, 'ORGANIZACAO': 4, 'LOCAL': 6, 'PESSOA': 4, 'COISA': 3, 'TEMPO': 4, 'VALOR': 2}
#
# Documento: H2-Ren_2003_6465
# Contagem de rótulos (original): {'O': 220, 'B-COISA': 2, 'B-TEMPO': 7, 'I-TEMPO': 16, 'B-LOCAL': 5, 'B-VALOR': 6, 'I-VALOR': 12, 'B-ORGANIZACAO': 3, 'I-ORGANIZACAO': 2, 'I-LOCAL': 2}
# Contagem de rótulos (simplificado): {'O': 220, 'COISA': 2, 'TEMPO': 23, 'LOCAL': 7, 'VALOR': 18, 'ORGANIZACAO': 5}
#
# Documento: ric-47441
# Contagem de rótulos (original): {'O': 151, 'B-OUTRO': 1, 'B-ACONTECIMENTO': 1, 'I-ACONTECIMENTO': 7, 'B-LOCAL': 3, 'B-COISA': 1, 'B-ABSTRACCAO': 3, 'I-ABSTRACCAO': 1, 'B-PESSOA': 3, 'I-PESSOA': 3, 'B-VALOR': 2, 'I-VALOR': 2, 'I-LOCAL': 2, 'B-TEMPO': 1, 'I-TEMPO': 1}
# Contagem de rótulos (simplificado): {'O': 151, 'OUTRO': 1, 'ACONTECIMENTO': 8, 'LOCAL': 5, 'COISA': 1, 'ABSTRACCAO': 4, 'PESSOA': 6, 'VALOR': 4, 'TEMPO': 2}
#
# Documento: aa55968
# Contagem de rótulos (original): {'B-OBRA': 1, 'I-OBRA': 3, 'O': 306, 'B-LOCAL': 15, 'I-LOCAL': 8, 'B-TEMPO': 3, 'I-TEMPO': 4, 'B-PESSOA': 16, 'I-PESSOA': 17, 'B-ORGANIZACAO': 8, 'I-ORGANIZACAO': 9, 'B-ACONTECIMENTO': 1, 'I-ACONTECIMENTO': 1, 'B-VALOR': 2, 'I-VALOR': 7}
# Contagem de rótulos (simplificado): {'OBRA': 4, 'O': 306, 'LOCAL': 23, 'TEMPO': 7, 'PESSOA': 33, 'ORGANIZACAO': 17, 'ACONTECIMENTO': 2, 'VALOR': 9}
#
# Documento: dav-522210
# Contagem de rótulos (original): {'O': 1340, 'B-PESSOA': 56, 'I-PESSOA': 63, 'B-OBRA': 27, 'I-OBRA': 53, 'B-LOCAL': 60, 'I-LOCAL': 31, 'B-ORGANIZACAO': 30, 'B-TEMPO': 26, 'I-TEMPO': 40, 'B-OUTRO': 13, 'I-OUTRO': 12, 'I-ORGANIZACAO': 12, 'B-ACONTECIMENTO': 31, 'I-ACONTECIMENTO': 58, 'B-ABSTRACCAO': 9, 'B-COISA': 4, 'I-COISA': 3, 'I-ABSTRACCAO': 2}
# Contagem de rótulos (simplificado): {'O': 1340, 'PESSOA': 119, 'OBRA': 80, 'LOCAL': 91, 'ORGANIZACAO': 42, 'TEMPO': 66, 'OUTRO': 25, 'ACONTECIMENTO': 89, 'ABSTRACCAO': 11, 'COISA': 7}
#
# Documento: hub-18050
# Contagem de rótulos (original): {'B-OBRA': 5, 'I-OBRA': 16, 'O': 128, 'B-LOCAL': 11, 'B-TEMPO': 9, 'I-TEMPO': 18, 'B-ORGANIZACAO': 8, 'I-ORGANIZACAO': 32, 'B-PESSOA': 8, 'I-PESSOA': 20, 'I-LOCAL': 3}
# Contagem de rótulos (simplificado): {'OBRA': 21, 'O': 128, 'LOCAL': 14, 'TEMPO': 27, 'ORGANIZACAO': 40, 'PESSOA': 28}
#
# Documento: ric-85133
# Contagem de rótulos (original): {'O': 782, 'B-PESSOA': 33, 'I-PESSOA': 17, 'B-ABSTRACCAO': 2, 'B-TEMPO': 8, 'I-TEMPO': 7, 'B-OBRA': 12, 'I-OBRA': 30}
# Contagem de rótulos (simplificado): {'O': 782, 'PESSOA': 50, 'ABSTRACCAO': 2, 'TEMPO': 15, 'OBRA': 42}
#
# Documento: relkj7666
# Contagem de rótulos (original): {'O': 1475, 'B-LOCAL': 41, 'I-LOCAL': 59, 'B-OBRA': 18, 'I-OBRA': 58, 'B-TEMPO': 35, 'I-TEMPO': 78, 'B-ACONTECIMENTO': 8, 'I-ACONTECIMENTO': 13, 'B-PESSOA': 49, 'I-PESSOA': 95, 'B-ORGANIZACAO': 46, 'I-ORGANIZACAO': 103, 'B-VALOR': 16, 'I-VALOR': 10, 'B-ABSTRACCAO': 5, 'I-ABSTRACCAO': 3, 'B-COISA': 12, 'I-COISA': 29, 'B-OUTRO': 1, 'I-OUTRO': 2}
# Contagem de rótulos (simplificado): {'O': 1475, 'LOCAL': 100, 'OBRA': 76, 'TEMPO': 113, 'ACONTECIMENTO': 21, 'PESSOA': 144, 'ORGANIZACAO': 149, 'VALOR': 26, 'ABSTRACCAO': 8, 'COISA': 41, 'OUTRO': 3}
#
# Documento: hub-4171
# Contagem de rótulos (original): {'O': 230, 'B-TEMPO': 8, 'I-TEMPO': 12, 'B-LOCAL': 1, 'B-ABSTRACCAO': 2, 'B-ORGANIZACAO': 4, 'I-ORGANIZACAO': 2, 'B-ACONTECIMENTO': 3, 'B-PESSOA': 2, 'I-PESSOA': 1, 'B-VALOR': 4, 'I-VALOR': 4}
# Contagem de rótulos (simplificado): {'O': 230, 'TEMPO': 20, 'LOCAL': 1, 'ABSTRACCAO': 2, 'ORGANIZACAO': 6, 'ACONTECIMENTO': 3, 'PESSOA': 3, 'VALOR': 8}
#
# Documento: wpt-1001819342220711712
# Contagem de rótulos (original): {'O': 207, 'B-TEMPO': 6, 'B-OBRA': 2, 'I-OBRA': 8, 'B-PESSOA': 5, 'I-TEMPO': 7, 'B-VALOR': 1, 'I-PESSOA': 2}
# Contagem de rótulos (simplificado): {'O': 207, 'TEMPO': 13, 'OBRA': 10, 'PESSOA': 7, 'VALOR': 1}
#
# Documento: hub-96408
# Contagem de rótulos (original): {'B-ACONTECIMENTO': 8, 'I-ACONTECIMENTO': 7, 'O': 289, 'B-PESSOA': 24, 'B-LOCAL': 6, 'I-PESSOA': 5, 'B-ABSTRACCAO': 1, 'B-VALOR': 11, 'I-LOCAL': 3, 'B-COISA': 1, 'B-TEMPO': 1, 'I-TEMPO': 2, 'I-VALOR': 1}
# Contagem de rótulos (simplificado): {'ACONTECIMENTO': 15, 'O': 289, 'PESSOA': 29, 'LOCAL': 9, 'ABSTRACCAO': 1, 'VALOR': 12, 'COISA': 1, 'TEMPO': 3}
#
# Documento: ric-18999
# Contagem de rótulos (original): {'B-LOCAL': 11, 'O': 132, 'B-PESSOA': 3, 'I-LOCAL': 9, 'B-TEMPO': 4, 'B-OBRA': 1, 'I-OBRA': 7, 'I-PESSOA': 1, 'I-TEMPO': 8, 'B-VALOR': 5, 'I-VALOR': 3, 'B-ORGANIZACAO': 2, 'I-ORGANIZACAO': 2}
# Contagem de rótulos (simplificado): {'LOCAL': 20, 'O': 132, 'PESSOA': 4, 'TEMPO': 12, 'OBRA': 8, 'VALOR': 8, 'ORGANIZACAO': 4}
#
# Documento: dav-100932
# Contagem de rótulos (original): {'O': 1435, 'B-LOCAL': 57, 'I-LOCAL': 23, 'B-PESSOA': 56, 'I-PESSOA': 67, 'B-ORGANIZACAO': 32, 'B-OBRA': 7, 'B-COISA': 7, 'B-TEMPO': 41, 'I-TEMPO': 106, 'B-ABSTRACCAO': 2, 'I-ORGANIZACAO': 21, 'I-OBRA': 12, 'B-ACONTECIMENTO': 8, 'I-ACONTECIMENTO': 12, 'B-OUTRO': 4, 'I-OUTRO': 2, 'B-VALOR': 7, 'I-VALOR': 4}
# Contagem de rótulos (simplificado): {'O': 1435, 'LOCAL': 80, 'PESSOA': 123, 'ORGANIZACAO': 53, 'OBRA': 19, 'COISA': 7, 'TEMPO': 147, 'ABSTRACCAO': 2, 'ACONTECIMENTO': 20, 'OUTRO': 6, 'VALOR': 11}
#
# Documento: hub-63156
# Contagem de rótulos (original): {'O': 241, 'B-PESSOA': 15, 'I-PESSOA': 9, 'B-ABSTRACCAO': 5, 'B-LOCAL': 6, 'I-LOCAL': 3, 'B-TEMPO': 12, 'I-TEMPO': 17, 'B-OBRA': 9, 'B-COISA': 3, 'I-COISA': 4, 'B-ORGANIZACAO': 2, 'I-ORGANIZACAO': 1, 'I-OBRA': 10, 'B-OUTRO': 1, 'I-OUTRO': 2, 'I-ABSTRACCAO': 6}
# Contagem de rótulos (simplificado): {'O': 241, 'PESSOA': 24, 'ABSTRACCAO': 11, 'LOCAL': 9, 'TEMPO': 29, 'OBRA': 19, 'COISA': 7, 'ORGANIZACAO': 3, 'OUTRO': 3}
#
# Documento: hub-83020
# Contagem de rótulos (original): {'O': 153, 'B-VALOR': 7, 'I-VALOR': 7, 'B-ORGANIZACAO': 2, 'B-TEMPO': 10, 'B-LOCAL': 6, 'I-TEMPO': 14, 'B-PESSOA': 4, 'I-PESSOA': 5, 'B-ACONTECIMENTO': 1, 'I-ACONTECIMENTO': 2, 'I-LOCAL': 1}
# Contagem de rótulos (simplificado): {'O': 153, 'VALOR': 14, 'ORGANIZACAO': 2, 'TEMPO': 24, 'LOCAL': 7, 'PESSOA': 9, 'ACONTECIMENTO': 3}
#
# Documento: exp-76321
# Contagem de rótulos (original): {'O': 227, 'B-ORGANIZACAO': 4, 'I-ORGANIZACAO': 2, 'B-TEMPO': 3, 'B-VALOR': 1, 'I-VALOR': 1, 'I-TEMPO': 3, 'B-LOCAL': 1}
# Contagem de rótulos (simplificado): {'O': 227, 'ORGANIZACAO': 6, 'TEMPO': 6, 'VALOR': 2, 'LOCAL': 1}
#
# Documento: wpt-101306633536471708
# Contagem de rótulos (original): {'O': 1532, 'B-TEMPO': 20, 'B-ORGANIZACAO': 100, 'I-ORGANIZACAO': 74, 'I-TEMPO': 51, 'B-OUTRO': 5, 'B-PESSOA': 22, 'I-PESSOA': 50, 'B-OBRA': 26, 'I-OBRA': 79, 'I-OUTRO': 5, 'B-ABSTRACCAO': 14, 'I-ABSTRACCAO': 30, 'B-LOCAL': 32, 'B-VALOR': 7, 'I-VALOR': 6, 'I-LOCAL': 39, 'B-ACONTECIMENTO': 14, 'I-ACONTECIMENTO': 34, 'B-COISA': 5, 'I-COISA': 16}
# Contagem de rótulos (simplificado): {'O': 1532, 'TEMPO': 71, 'ORGANIZACAO': 174, 'OUTRO': 10, 'PESSOA': 72, 'OBRA': 105, 'ABSTRACCAO': 44, 'LOCAL': 71, 'VALOR': 13, 'ACONTECIMENTO': 48, 'COISA': 21}
#
# Documento: hub-28306
# Contagem de rótulos (original): {'B-ORGANIZACAO': 4, 'O': 246, 'B-TEMPO': 3, 'I-TEMPO': 9, 'I-ORGANIZACAO': 1, 'B-OBRA': 2, 'B-COISA': 10, 'I-COISA': 5, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 2, 'B-LOCAL': 1}
# Contagem de rótulos (simplificado): {'ORGANIZACAO': 5, 'O': 246, 'TEMPO': 12, 'OBRA': 2, 'COISA': 15, 'ABSTRACCAO': 3, 'LOCAL': 1}
#
# Documento: hub-19181
# Contagem de rótulos (original): {'B-ACONTECIMENTO': 5, 'I-ACONTECIMENTO': 5, 'O': 91, 'B-PESSOA': 9, 'I-PESSOA': 7, 'B-TEMPO': 2, 'I-TEMPO': 2, 'B-VALOR': 9, 'B-LOCAL': 3, 'I-LOCAL': 1}
# Contagem de rótulos (simplificado): {'ACONTECIMENTO': 10, 'O': 91, 'PESSOA': 16, 'TEMPO': 4, 'VALOR': 9, 'LOCAL': 4}
#
# Documento: wpt-1016797200209519613
# Contagem de rótulos (original): {'B-ABSTRACCAO': 5, 'I-ABSTRACCAO': 3, 'O': 239, 'B-ORGANIZACAO': 10, 'I-ORGANIZACAO': 14, 'B-COISA': 7, 'I-COISA': 3, 'B-LOCAL': 2}
# Contagem de rótulos (simplificado): {'ABSTRACCAO': 8, 'O': 239, 'ORGANIZACAO': 24, 'COISA': 10, 'LOCAL': 2}
#
# Documento: ric-33939
# Contagem de rótulos (original): {'B-ORGANIZACAO': 24, 'O': 699, 'B-PESSOA': 11, 'I-PESSOA': 5, 'I-ORGANIZACAO': 16, 'B-TEMPO': 15, 'I-TEMPO': 31, 'B-ACONTECIMENTO': 1, 'I-ACONTECIMENTO': 2, 'B-LOCAL': 11, 'B-VALOR': 2, 'I-LOCAL': 7, 'B-COISA': 1, 'B-OBRA': 4, 'I-OBRA': 20, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 2}
# Contagem de rótulos (simplificado): {'ORGANIZACAO': 40, 'O': 699, 'PESSOA': 16, 'TEMPO': 46, 'ACONTECIMENTO': 3, 'LOCAL': 18, 'VALOR': 2, 'COISA': 1, 'OBRA': 24, 'ABSTRACCAO': 3}
#
# Documento: hub-64260
# Contagem de rótulos (original): {'B-OUTRO': 1, 'I-OUTRO': 2, 'O': 187, 'B-COISA': 2, 'I-COISA': 4, 'B-TEMPO': 2, 'I-TEMPO': 6, 'B-ACONTECIMENTO': 1, 'I-ACONTECIMENTO': 1, 'B-LOCAL': 7, 'B-OBRA': 4, 'I-OBRA': 8, 'B-ORGANIZACAO': 2, 'B-PESSOA': 1, 'I-PESSOA': 1, 'I-LOCAL': 2}
# Contagem de rótulos (simplificado): {'OUTRO': 3, 'O': 187, 'COISA': 6, 'TEMPO': 8, 'ACONTECIMENTO': 2, 'LOCAL': 9, 'OBRA': 12, 'ORGANIZACAO': 2, 'PESSOA': 2}
#
# Documento: hub-28874
# Contagem de rótulos (original): {'B-COISA': 4, 'O': 204, 'B-VALOR': 11, 'I-VALOR': 14, 'B-PESSOA': 2, 'B-TEMPO': 2, 'I-TEMPO': 2, 'B-ORGANIZACAO': 3, 'I-ORGANIZACAO': 11, 'B-LOCAL': 1}
# Contagem de rótulos (simplificado): {'COISA': 4, 'O': 204, 'VALOR': 25, 'PESSOA': 2, 'TEMPO': 4, 'ORGANIZACAO': 14, 'LOCAL': 1}
#
# Documento: H2-gt654
# Contagem de rótulos (original): {'O': 878, 'B-PESSOA': 38, 'I-PESSOA': 23, 'B-LOCAL': 6, 'I-LOCAL': 10, 'B-OBRA': 3, 'I-OBRA': 7, 'B-TEMPO': 10, 'I-TEMPO': 17, 'B-ORGANIZACAO': 7, 'I-ORGANIZACAO': 4, 'B-ABSTRACCAO': 6, 'B-COISA': 1}
# Contagem de rótulos (simplificado): {'O': 878, 'PESSOA': 61, 'LOCAL': 16, 'OBRA': 10, 'TEMPO': 27, 'ORGANIZACAO': 11, 'ABSTRACCAO': 6, 'COISA': 1}
#
# Documento: hub-16632
# Contagem de rótulos (original): {'O': 83, 'B-PESSOA': 5, 'I-PESSOA': 7, 'B-LOCAL': 2}
# Contagem de rótulos (simplificado): {'O': 83, 'PESSOA': 12, 'LOCAL': 2}
#
# Documento: hub-22322
# Contagem de rótulos (original): {'B-PESSOA': 9, 'O': 125, 'B-TEMPO': 9, 'B-ORGANIZACAO': 3, 'I-PESSOA': 7, 'I-TEMPO': 16, 'B-LOCAL': 1, 'I-LOCAL': 2, 'B-OBRA': 1}
# Contagem de rótulos (simplificado): {'PESSOA': 16, 'O': 125, 'TEMPO': 25, 'ORGANIZACAO': 3, 'LOCAL': 3, 'OBRA': 1}
#
# Documento: dav-833351
# Contagem de rótulos (original): {'O': 1194, 'B-ORGANIZACAO': 19, 'I-ORGANIZACAO': 8, 'B-PESSOA': 69, 'B-TEMPO': 26, 'I-TEMPO': 42, 'I-PESSOA': 66, 'B-LOCAL': 42, 'B-OBRA': 13, 'I-OBRA': 25, 'B-ACONTECIMENTO': 20, 'I-ACONTECIMENTO': 48, 'B-ABSTRACCAO': 5, 'I-ABSTRACCAO': 4, 'B-COISA': 6, 'B-OUTRO': 3, 'I-OUTRO': 6, 'I-LOCAL': 13}
# Contagem de rótulos (simplificado): {'O': 1194, 'ORGANIZACAO': 27, 'PESSOA': 135, 'TEMPO': 68, 'LOCAL': 55, 'OBRA': 38, 'ACONTECIMENTO': 68, 'ABSTRACCAO': 9, 'COISA': 6, 'OUTRO': 9}
#
# Documento: ric-46546
# Contagem de rótulos (original): {'B-PESSOA': 173, 'I-PESSOA': 153, 'O': 3049, 'B-ORGANIZACAO': 24, 'B-OBRA': 21, 'I-OBRA': 74, 'B-TEMPO': 24, 'I-TEMPO': 35, 'B-LOCAL': 17, 'I-LOCAL': 12, 'B-VALOR': 7, 'I-VALOR': 2, 'I-ORGANIZACAO': 26, 'B-ABSTRACCAO': 15, 'I-ABSTRACCAO': 18, 'B-COISA': 1, 'I-COISA': 1, 'B-ACONTECIMENTO': 1, 'I-ACONTECIMENTO': 7}
# Contagem de rótulos (simplificado): {'PESSOA': 326, 'O': 3049, 'ORGANIZACAO': 50, 'OBRA': 95, 'TEMPO': 59, 'LOCAL': 29, 'VALOR': 9, 'ABSTRACCAO': 33, 'COISA': 2, 'ACONTECIMENTO': 8}
#
# Documento: aa25258
# Contagem de rótulos (original): {'B-PESSOA': 18, 'O': 712, 'B-ABSTRACCAO': 1, 'B-OBRA': 4, 'I-PESSOA': 10, 'B-TEMPO': 14, 'I-TEMPO': 27, 'B-VALOR': 2, 'I-VALOR': 2, 'B-LOCAL': 8, 'B-ACONTECIMENTO': 1, 'I-ACONTECIMENTO': 2, 'B-ORGANIZACAO': 5, 'I-ORGANIZACAO': 1}
# Contagem de rótulos (simplificado): {'PESSOA': 28, 'O': 712, 'ABSTRACCAO': 1, 'OBRA': 4, 'TEMPO': 41, 'VALOR': 4, 'LOCAL': 8, 'ACONTECIMENTO': 3, 'ORGANIZACAO': 6}
#
# Documento: hub-51467
# Contagem de rótulos (original): {'B-TEMPO': 24, 'O': 645, 'I-TEMPO': 47, 'B-VALOR': 36, 'B-ORGANIZACAO': 19, 'I-ORGANIZACAO': 33, 'B-LOCAL': 7, 'I-LOCAL': 1, 'I-VALOR': 23, 'B-OUTRO': 8, 'B-PESSOA': 1, 'I-PESSOA': 1, 'I-OUTRO': 8}
# Contagem de rótulos (simplificado): {'TEMPO': 71, 'O': 645, 'VALOR': 59, 'ORGANIZACAO': 52, 'LOCAL': 8, 'OUTRO': 16, 'PESSOA': 2}
#
# Documento: hub-65266
# Contagem de rótulos (original): {'O': 340, 'B-ORGANIZACAO': 15, 'B-PESSOA': 15, 'I-PESSOA': 44, 'I-ORGANIZACAO': 26, 'B-TEMPO': 8, 'B-OBRA': 2, 'B-LOCAL': 3, 'I-LOCAL': 2, 'I-TEMPO': 16}
# Contagem de rótulos (simplificado): {'O': 340, 'ORGANIZACAO': 41, 'PESSOA': 59, 'TEMPO': 24, 'OBRA': 2, 'LOCAL': 5}
#
# Documento: wpt-1005220936254463458
# Contagem de rótulos (original): {'O': 121, 'B-LOCAL': 3, 'I-LOCAL': 3, 'B-TEMPO': 6, 'B-ACONTECIMENTO': 4, 'I-ACONTECIMENTO': 13, 'B-ORGANIZACAO': 3, 'I-ORGANIZACAO': 8, 'B-VALOR': 1, 'I-VALOR': 2, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 5, 'B-OBRA': 3, 'I-OBRA': 8, 'B-PESSOA': 4, 'I-PESSOA': 4, 'B-COISA': 1}
# Contagem de rótulos (simplificado): {'O': 121, 'LOCAL': 6, 'TEMPO': 6, 'ACONTECIMENTO': 17, 'ORGANIZACAO': 11, 'VALOR': 3, 'ABSTRACCAO': 6, 'OBRA': 11, 'PESSOA': 8, 'COISA': 1}
#
# Documento: bob-14949
# Contagem de rótulos (original): {'O': 408, 'B-PESSOA': 20, 'I-PESSOA': 13, 'B-LOCAL': 20, 'I-LOCAL': 21, 'B-ACONTECIMENTO': 3, 'I-ACONTECIMENTO': 9, 'B-TEMPO': 21, 'B-VALOR': 3, 'I-VALOR': 4, 'I-TEMPO': 23, 'B-ORGANIZACAO': 2, 'I-ORGANIZACAO': 2, 'B-OBRA': 3, 'I-OBRA': 8}
# Contagem de rótulos (simplificado): {'O': 408, 'PESSOA': 33, 'LOCAL': 41, 'ACONTECIMENTO': 12, 'TEMPO': 44, 'VALOR': 7, 'ORGANIZACAO': 4, 'OBRA': 11}
#
# Documento: ric-30606
# Contagem de rótulos (original): {'O': 867, 'B-TEMPO': 5, 'I-TEMPO': 5, 'B-LOCAL': 4, 'I-LOCAL': 3, 'B-ACONTECIMENTO': 1, 'I-ACONTECIMENTO': 2, 'B-OBRA': 10, 'I-OBRA': 18, 'B-COISA': 6, 'B-PESSOA': 12, 'I-PESSOA': 10, 'I-COISA': 3, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 2, 'B-VALOR': 4, 'I-VALOR': 3, 'B-ORGANIZACAO': 2}
# Contagem de rótulos (simplificado): {'O': 867, 'TEMPO': 10, 'LOCAL': 7, 'ACONTECIMENTO': 3, 'OBRA': 28, 'COISA': 9, 'PESSOA': 22, 'ABSTRACCAO': 3, 'VALOR': 7, 'ORGANIZACAO': 2}
#
# Documento: hub-77558
# Contagem de rótulos (original): {'O': 250, 'B-PESSOA': 18, 'B-LOCAL': 2, 'B-TEMPO': 12, 'I-TEMPO': 16, 'I-PESSOA': 14, 'B-OBRA': 18, 'I-OBRA': 25, 'B-ABSTRACCAO': 2, 'B-COISA': 1, 'I-COISA': 1, 'B-VALOR': 1, 'B-ORGANIZACAO': 1, 'I-ORGANIZACAO': 1}
# Contagem de rótulos (simplificado): {'O': 250, 'PESSOA': 32, 'LOCAL': 2, 'TEMPO': 28, 'OBRA': 43, 'ABSTRACCAO': 2, 'COISA': 2, 'VALOR': 1, 'ORGANIZACAO': 2}
#
# Documento: hub-60905
# Contagem de rótulos (original): {'O': 148, 'B-TEMPO': 8, 'I-TEMPO': 14, 'B-VALOR': 8, 'I-VALOR': 13, 'B-ORGANIZACAO': 4, 'B-COISA': 7, 'I-COISA': 1, 'I-ORGANIZACAO': 1}
# Contagem de rótulos (simplificado): {'O': 148, 'TEMPO': 22, 'VALOR': 21, 'ORGANIZACAO': 5, 'COISA': 8}
#
# Documento: 2ght33
# Contagem de rótulos (original): {'O': 1088, 'B-PESSOA': 19, 'I-PESSOA': 6, 'B-LOCAL': 15, 'B-ORGANIZACAO': 5, 'B-TEMPO': 12, 'I-TEMPO': 25, 'I-LOCAL': 5, 'B-ABSTRACCAO': 12, 'I-ABSTRACCAO': 11, 'I-ORGANIZACAO': 1, 'B-OBRA': 2, 'I-OBRA': 9, 'B-COISA': 6}
# Contagem de rótulos (simplificado): {'O': 1088, 'PESSOA': 25, 'LOCAL': 20, 'ORGANIZACAO': 6, 'TEMPO': 37, 'ABSTRACCAO': 23, 'OBRA': 11, 'COISA': 6}
#
# Documento: hub-66526
# Contagem de rótulos (original): {'B-OBRA': 1, 'I-OBRA': 3, 'O': 214, 'B-LOCAL': 14, 'I-LOCAL': 14, 'B-TEMPO': 6, 'I-TEMPO': 11, 'B-PESSOA': 18, 'I-PESSOA': 33, 'B-VALOR': 1, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 4, 'B-ORGANIZACAO': 5, 'B-OUTRO': 2, 'I-ORGANIZACAO': 5, 'I-OUTRO': 1}
# Contagem de rótulos (simplificado): {'OBRA': 4, 'O': 214, 'LOCAL': 28, 'TEMPO': 17, 'PESSOA': 51, 'VALOR': 1, 'ABSTRACCAO': 5, 'ORGANIZACAO': 10, 'OUTRO': 3}
#
# Documento: aa13183
# Contagem de rótulos (original): {'O': 519, 'B-COISA': 9, 'I-COISA': 4, 'B-TEMPO': 17, 'I-TEMPO': 23, 'B-LOCAL': 10, 'B-ACONTECIMENTO': 4, 'I-ACONTECIMENTO': 16, 'B-ORGANIZACAO': 18, 'I-ORGANIZACAO': 30, 'I-LOCAL': 18, 'B-PESSOA': 6, 'I-PESSOA': 6, 'B-OBRA': 3, 'I-OBRA': 8}
# Contagem de rótulos (simplificado): {'O': 519, 'COISA': 13, 'TEMPO': 40, 'LOCAL': 28, 'ACONTECIMENTO': 20, 'ORGANIZACAO': 48, 'PESSOA': 12, 'OBRA': 11}
#
# Documento: aa64686
# Contagem de rótulos (original): {'B-ACONTECIMENTO': 3, 'O': 450, 'B-TEMPO': 9, 'I-TEMPO': 19, 'I-ACONTECIMENTO': 2, 'B-LOCAL': 14, 'B-ABSTRACCAO': 9, 'B-ORGANIZACAO': 3, 'I-LOCAL': 13, 'B-PESSOA': 9, 'I-ABSTRACCAO': 8, 'I-ORGANIZACAO': 1, 'I-PESSOA': 8, 'B-OBRA': 3, 'I-OBRA': 11, 'B-VALOR': 1, 'I-VALOR': 1}
# Contagem de rótulos (simplificado): {'ACONTECIMENTO': 5, 'O': 450, 'TEMPO': 28, 'LOCAL': 27, 'ABSTRACCAO': 17, 'ORGANIZACAO': 4, 'PESSOA': 17, 'OBRA': 14, 'VALOR': 2}
#
# Documento: 2ght33-2
# Contagem de rótulos (original): {'O': 945, 'B-ABSTRACCAO': 5, 'B-TEMPO': 15, 'I-TEMPO': 34, 'B-LOCAL': 9, 'B-PESSOA': 17, 'B-COISA': 3, 'I-COISA': 1, 'I-PESSOA': 5}
# Contagem de rótulos (simplificado): {'O': 945, 'ABSTRACCAO': 5, 'TEMPO': 49, 'LOCAL': 9, 'PESSOA': 22, 'COISA': 4}
#
# Documento: aa56088
# Contagem de rótulos (original): {'O': 925, 'B-PESSOA': 39, 'B-OBRA': 21, 'I-OBRA': 41, 'B-ORGANIZACAO': 40, 'I-PESSOA': 36, 'I-ORGANIZACAO': 7, 'B-TEMPO': 9, 'I-TEMPO': 20, 'B-LOCAL': 7, 'I-LOCAL': 1, 'B-VALOR': 3, 'I-VALOR': 2, 'B-ABSTRACCAO': 2, 'I-ABSTRACCAO': 2, 'B-ACONTECIMENTO': 4, 'I-ACONTECIMENTO': 7}
# Contagem de rótulos (simplificado): {'O': 925, 'PESSOA': 75, 'OBRA': 62, 'ORGANIZACAO': 47, 'TEMPO': 29, 'LOCAL': 8, 'VALOR': 5, 'ABSTRACCAO': 4, 'ACONTECIMENTO': 11}
#
# Documento: gtpppp
# Contagem de rótulos (original): {'O': 326, 'B-PESSOA': 26, 'B-TEMPO': 8, 'I-TEMPO': 12, 'B-LOCAL': 15, 'B-VALOR': 3, 'B-ACONTECIMENTO': 13, 'I-ACONTECIMENTO': 38, 'I-LOCAL': 4, 'I-PESSOA': 15, 'B-ORGANIZACAO': 2, 'I-ORGANIZACAO': 2, 'B-COISA': 1, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 2}
# Contagem de rótulos (simplificado): {'O': 326, 'PESSOA': 41, 'TEMPO': 20, 'LOCAL': 19, 'VALOR': 3, 'ACONTECIMENTO': 51, 'ORGANIZACAO': 4, 'COISA': 1, 'ABSTRACCAO': 3}
#
# Documento: ric-19806
# Contagem de rótulos (original): {'B-ABSTRACCAO': 4, 'I-ABSTRACCAO': 8, 'O': 962, 'B-PESSOA': 6, 'I-PESSOA': 10, 'B-TEMPO': 12, 'I-TEMPO': 14, 'B-LOCAL': 73, 'I-LOCAL': 35, 'B-COISA': 40, 'B-VALOR': 4, 'I-COISA': 33}
# Contagem de rótulos (simplificado): {'ABSTRACCAO': 12, 'O': 962, 'PESSOA': 16, 'TEMPO': 26, 'LOCAL': 108, 'COISA': 73, 'VALOR': 4}
#
# Documento: ric-40040
# Contagem de rótulos (original): {'O': 714, 'B-PESSOA': 39, 'B-LOCAL': 8, 'I-LOCAL': 7, 'I-PESSOA': 20, 'B-ACONTECIMENTO': 7, 'I-ACONTECIMENTO': 13, 'B-TEMPO': 8, 'I-TEMPO': 16, 'B-OBRA': 7, 'I-OBRA': 5, 'B-ABSTRACCAO': 5, 'I-ABSTRACCAO': 3}
# Contagem de rótulos (simplificado): {'O': 714, 'PESSOA': 59, 'LOCAL': 15, 'ACONTECIMENTO': 20, 'TEMPO': 24, 'OBRA': 12, 'ABSTRACCAO': 8}
#
# Documento: hub-97297
# Contagem de rótulos (original): {'B-PESSOA': 10, 'I-PESSOA': 6, 'O': 237, 'B-LOCAL': 9, 'I-LOCAL': 1, 'B-ORGANIZACAO': 4, 'B-TEMPO': 2, 'B-ACONTECIMENTO': 11, 'B-OBRA': 1, 'I-OBRA': 2, 'I-TEMPO': 1}
# Contagem de rótulos (simplificado): {'PESSOA': 16, 'O': 237, 'LOCAL': 10, 'ORGANIZACAO': 4, 'TEMPO': 3, 'ACONTECIMENTO': 11, 'OBRA': 3}
#
# Documento: H2-bbb
# Contagem de rótulos (original): {'B-PESSOA': 9, 'O': 188, 'B-TEMPO': 3, 'B-OBRA': 2, 'I-OBRA': 10, 'I-PESSOA': 2, 'B-ABSTRACCAO': 2, 'I-TEMPO': 6, 'B-LOCAL': 1, 'I-LOCAL': 1}
# Contagem de rótulos (simplificado): {'PESSOA': 11, 'O': 188, 'TEMPO': 9, 'OBRA': 12, 'ABSTRACCAO': 2, 'LOCAL': 2}
#
# Documento: hub-15590
# Contagem de rótulos (original): {'B-PESSOA': 40, 'I-PESSOA': 60, 'O': 299, 'B-LOCAL': 16, 'I-LOCAL': 5, 'B-TEMPO': 9, 'I-TEMPO': 19, 'B-ACONTECIMENTO': 4, 'I-ACONTECIMENTO': 4, 'B-ORGANIZACAO': 1, 'B-VALOR': 2}
# Contagem de rótulos (simplificado): {'PESSOA': 100, 'O': 299, 'LOCAL': 21, 'TEMPO': 28, 'ACONTECIMENTO': 8, 'ORGANIZACAO': 1, 'VALOR': 2}
#
# Documento: ric-76632
# Contagem de rótulos (original): {'O': 892, 'B-PESSOA': 20, 'I-PESSOA': 10, 'B-LOCAL': 9, 'I-LOCAL': 11, 'B-TEMPO': 14, 'B-VALOR': 2, 'I-TEMPO': 20, 'B-ACONTECIMENTO': 8, 'I-ACONTECIMENTO': 22, 'B-ORGANIZACAO': 6, 'I-ORGANIZACAO': 12, 'I-VALOR': 1, 'B-OBRA': 2, 'I-OBRA': 4}
# Contagem de rótulos (simplificado): {'O': 892, 'PESSOA': 30, 'LOCAL': 20, 'TEMPO': 34, 'VALOR': 3, 'ACONTECIMENTO': 30, 'ORGANIZACAO': 18, 'OBRA': 6}
#
# Documento: hub-71248
# Contagem de rótulos (original): {'O': 105, 'B-TEMPO': 8, 'I-TEMPO': 16, 'B-LOCAL': 8, 'I-LOCAL': 9, 'B-PESSOA': 5, 'B-VALOR': 4, 'I-VALOR': 4, 'B-ABSTRACCAO': 1}
# Contagem de rótulos (simplificado): {'O': 105, 'TEMPO': 24, 'LOCAL': 17, 'PESSOA': 5, 'VALOR': 8, 'ABSTRACCAO': 1}
#
# Documento: ric-39610
# Contagem de rótulos (original): {'B-ORGANIZACAO': 2, 'I-ORGANIZACAO': 4, 'O': 332, 'B-OBRA': 10, 'B-TEMPO': 7, 'B-VALOR': 2, 'I-OBRA': 18, 'I-TEMPO': 7, 'B-PESSOA': 6, 'I-PESSOA': 2, 'B-ABSTRACCAO': 1, 'B-LOCAL': 1, 'I-LOCAL': 1, 'B-ACONTECIMENTO': 1}
# Contagem de rótulos (simplificado): {'ORGANIZACAO': 6, 'O': 332, 'OBRA': 28, 'TEMPO': 14, 'VALOR': 2, 'PESSOA': 8, 'ABSTRACCAO': 1, 'LOCAL': 2, 'ACONTECIMENTO': 1}
#
# Documento: rica-474415
# Contagem de rótulos (original): {'B-LOCAL': 11, 'O': 616, 'B-PESSOA': 20, 'I-PESSOA': 11, 'B-TEMPO': 13, 'B-VALOR': 1, 'B-ORGANIZACAO': 18, 'B-OBRA': 3, 'I-OBRA': 5, 'I-TEMPO': 17, 'I-ORGANIZACAO': 7, 'B-ABSTRACCAO': 1, 'B-ACONTECIMENTO': 1, 'I-ACONTECIMENTO': 2, 'I-LOCAL': 4}
# Contagem de rótulos (simplificado): {'LOCAL': 15, 'O': 616, 'PESSOA': 31, 'TEMPO': 30, 'VALOR': 1, 'ORGANIZACAO': 25, 'OBRA': 8, 'ABSTRACCAO': 1, 'ACONTECIMENTO': 3}
#
# Documento: hub-55847
# Contagem de rótulos (original): {'B-PESSOA': 42, 'I-PESSOA': 64, 'O': 268, 'B-LOCAL': 15, 'B-TEMPO': 6, 'I-TEMPO': 9, 'B-VALOR': 2, 'I-VALOR': 4, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 1, 'B-ACONTECIMENTO': 1, 'B-OBRA': 1}
# Contagem de rótulos (simplificado): {'PESSOA': 106, 'O': 268, 'LOCAL': 15, 'TEMPO': 15, 'VALOR': 6, 'ABSTRACCAO': 2, 'ACONTECIMENTO': 1, 'OBRA': 1}
#
# Documento: wpt-10034934164544455
# Contagem de rótulos (original): {'O': 134, 'B-LOCAL': 3, 'I-LOCAL': 1, 'B-TEMPO': 3, 'I-TEMPO': 5, 'B-VALOR': 1, 'B-PESSOA': 2, 'B-ORGANIZACAO': 4, 'I-PESSOA': 2, 'I-ORGANIZACAO': 12}
# Contagem de rótulos (simplificado): {'O': 134, 'LOCAL': 4, 'TEMPO': 8, 'VALOR': 1, 'PESSOA': 4, 'ORGANIZACAO': 16}
#
# Documento: hub-2312
# Contagem de rótulos (original): {'B-COISA': 13, 'I-COISA': 6, 'O': 242, 'B-ABSTRACCAO': 2, 'I-ABSTRACCAO': 2, 'B-TEMPO': 1, 'I-TEMPO': 1, 'B-LOCAL': 3, 'B-ORGANIZACAO': 4, 'I-ORGANIZACAO': 9, 'I-LOCAL': 4}
# Contagem de rótulos (simplificado): {'COISA': 19, 'O': 242, 'ABSTRACCAO': 4, 'TEMPO': 2, 'LOCAL': 7, 'ORGANIZACAO': 13}
#
# Documento: dav-52390
# Contagem de rótulos (original): {'O': 1327, 'B-PESSOA': 63, 'I-PESSOA': 63, 'B-ORGANIZACAO': 20, 'B-OBRA': 17, 'I-OBRA': 41, 'B-ACONTECIMENTO': 32, 'I-ACONTECIMENTO': 76, 'B-COISA': 16, 'I-COISA': 14, 'B-TEMPO': 35, 'I-TEMPO': 85, 'B-OUTRO': 5, 'I-OUTRO': 6, 'B-ABSTRACCAO': 4, 'I-ABSTRACCAO': 2, 'I-ORGANIZACAO': 14, 'B-LOCAL': 42, 'I-LOCAL': 26}
# Contagem de rótulos (simplificado): {'O': 1327, 'PESSOA': 126, 'ORGANIZACAO': 34, 'OBRA': 58, 'ACONTECIMENTO': 108, 'COISA': 30, 'TEMPO': 120, 'OUTRO': 11, 'ABSTRACCAO': 6, 'LOCAL': 68}
#
# Documento: aa40383
# Contagem de rótulos (original): {'O': 1090, 'B-TEMPO': 18, 'I-TEMPO': 30, 'B-PESSOA': 43, 'I-PESSOA': 32, 'B-ORGANIZACAO': 7, 'B-OUTRO': 1, 'I-OUTRO': 2, 'B-ACONTECIMENTO': 5, 'B-LOCAL': 6, 'B-OBRA': 1, 'I-OBRA': 1, 'I-ORGANIZACAO': 5, 'B-VALOR': 1}
# Contagem de rótulos (simplificado): {'O': 1090, 'TEMPO': 48, 'PESSOA': 75, 'ORGANIZACAO': 12, 'OUTRO': 3, 'ACONTECIMENTO': 5, 'LOCAL': 6, 'OBRA': 2, 'VALOR': 1}
#
# Documento: wpt-101789548982731354
# Contagem de rótulos (original): {'O': 131, 'B-LOCAL': 1, 'B-TEMPO': 1, 'B-ORGANIZACAO': 11, 'I-ORGANIZACAO': 6, 'B-OUTRO': 1}
# Contagem de rótulos (simplificado): {'O': 131, 'LOCAL': 1, 'TEMPO': 1, 'ORGANIZACAO': 17, 'OUTRO': 1}
#
# Documento: hub-44595
# Contagem de rótulos (original): {'B-ACONTECIMENTO': 8, 'O': 220, 'B-PESSOA': 18, 'B-TEMPO': 5, 'I-TEMPO': 6, 'I-PESSOA': 10, 'I-ACONTECIMENTO': 13, 'B-LOCAL': 6, 'B-OUTRO': 4, 'B-VALOR': 1, 'I-VALOR': 3}
# Contagem de rótulos (simplificado): {'ACONTECIMENTO': 21, 'O': 220, 'PESSOA': 28, 'TEMPO': 11, 'LOCAL': 6, 'OUTRO': 4, 'VALOR': 4}
#
# Documento: ven-098
# Contagem de rótulos (original): {'O': 355, 'B-PESSOA': 14, 'I-PESSOA': 18, 'B-LOCAL': 7, 'B-ORGANIZACAO': 8, 'B-ABSTRACCAO': 3, 'I-ABSTRACCAO': 2, 'B-VALOR': 2, 'I-ORGANIZACAO': 8, 'B-TEMPO': 4, 'I-TEMPO': 8, 'B-COISA': 1, 'I-COISA': 2, 'I-LOCAL': 2}
# Contagem de rótulos (simplificado): {'O': 355, 'PESSOA': 32, 'LOCAL': 9, 'ORGANIZACAO': 16, 'ABSTRACCAO': 5, 'VALOR': 2, 'TEMPO': 12, 'COISA': 3}
#
# Documento: hjlll
# Contagem de rótulos (original): {'B-ORGANIZACAO': 26, 'I-ORGANIZACAO': 20, 'O': 367, 'B-LOCAL': 7, 'B-TEMPO': 7, 'I-TEMPO': 10, 'B-VALOR': 3, 'I-VALOR': 5, 'B-ACONTECIMENTO': 5, 'I-ACONTECIMENTO': 10, 'B-COISA': 1, 'I-COISA': 1, 'B-PESSOA': 5, 'I-PESSOA': 4, 'B-ABSTRACCAO': 4, 'I-ABSTRACCAO': 9, 'I-LOCAL': 4}
# Contagem de rótulos (simplificado): {'ORGANIZACAO': 46, 'O': 367, 'LOCAL': 11, 'TEMPO': 17, 'VALOR': 8, 'ACONTECIMENTO': 15, 'COISA': 2, 'PESSOA': 9, 'ABSTRACCAO': 13}
#
# Documento: hub-41899
# Contagem de rótulos (original): {'B-PESSOA': 23, 'I-PESSOA': 25, 'O': 299, 'B-LOCAL': 7, 'B-ACONTECIMENTO': 1, 'B-TEMPO': 8, 'I-TEMPO': 10, 'I-LOCAL': 2, 'B-OBRA': 3, 'I-OBRA': 5, 'B-VALOR': 1, 'I-VALOR': 1, 'B-COISA': 2, 'B-ORGANIZACAO': 2, 'B-ABSTRACCAO': 2, 'I-ABSTRACCAO': 2}
# Contagem de rótulos (simplificado): {'PESSOA': 48, 'O': 299, 'LOCAL': 9, 'ACONTECIMENTO': 1, 'TEMPO': 18, 'OBRA': 8, 'VALOR': 2, 'COISA': 2, 'ORGANIZACAO': 2, 'ABSTRACCAO': 4}
#
# Documento: hub-78051
# Contagem de rótulos (original): {'B-PESSOA': 7, 'O': 163, 'B-ACONTECIMENTO': 2, 'B-LOCAL': 8, 'I-LOCAL': 3, 'I-PESSOA': 3, 'B-TEMPO': 2, 'I-TEMPO': 5, 'B-ABSTRACCAO': 1}
# Contagem de rótulos (simplificado): {'PESSOA': 10, 'O': 163, 'ACONTECIMENTO': 2, 'LOCAL': 11, 'TEMPO': 7, 'ABSTRACCAO': 1}
#
# Documento: hub-81551
# Contagem de rótulos (original): {'B-ACONTECIMENTO': 3, 'I-ACONTECIMENTO': 4, 'O': 434, 'B-TEMPO': 12, 'I-TEMPO': 28, 'B-VALOR': 8, 'I-VALOR': 18, 'B-LOCAL': 22, 'I-LOCAL': 9, 'B-OBRA': 9, 'I-OBRA': 16, 'B-PESSOA': 6, 'I-PESSOA': 5}
# Contagem de rótulos (simplificado): {'ACONTECIMENTO': 7, 'O': 434, 'TEMPO': 40, 'VALOR': 26, 'LOCAL': 31, 'OBRA': 25, 'PESSOA': 11}
#
# Documento: ric-54609
# Contagem de rótulos (original): {'O': 265, 'B-LOCAL': 4, 'B-PESSOA': 10, 'I-PESSOA': 4, 'I-LOCAL': 5, 'B-TEMPO': 2, 'I-TEMPO': 6, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 1, 'B-ORGANIZACAO': 3, 'I-ORGANIZACAO': 8, 'B-OBRA': 3, 'I-OBRA': 4}
# Contagem de rótulos (simplificado): {'O': 265, 'LOCAL': 9, 'PESSOA': 14, 'TEMPO': 8, 'ABSTRACCAO': 2, 'ORGANIZACAO': 11, 'OBRA': 7}
#
# Documento: hub-83689
# Contagem de rótulos (original): {'B-PESSOA': 18, 'I-PESSOA': 24, 'O': 293, 'B-TEMPO': 7, 'I-TEMPO': 16, 'B-ABSTRACCAO': 2, 'I-ABSTRACCAO': 4, 'B-LOCAL': 17, 'I-LOCAL': 6, 'B-VALOR': 3, 'I-VALOR': 1, 'B-ORGANIZACAO': 1, 'B-OBRA': 1, 'I-OBRA': 2}
# Contagem de rótulos (simplificado): {'PESSOA': 42, 'O': 293, 'TEMPO': 23, 'ABSTRACCAO': 6, 'LOCAL': 23, 'VALOR': 4, 'ORGANIZACAO': 1, 'OBRA': 3}
#
# Documento: hub-94570
# Contagem de rótulos (original): {'O': 270, 'B-TEMPO': 4, 'I-TEMPO': 4, 'B-PESSOA': 5, 'I-PESSOA': 6, 'B-LOCAL': 6, 'I-LOCAL': 4, 'B-OUTRO': 1, 'I-OUTRO': 4, 'B-COISA': 2, 'B-ABSTRACCAO': 2, 'B-VALOR': 2, 'I-VALOR': 4}
# Contagem de rótulos (simplificado): {'O': 270, 'TEMPO': 8, 'PESSOA': 11, 'LOCAL': 10, 'OUTRO': 5, 'COISA': 2, 'ABSTRACCAO': 2, 'VALOR': 6}
#
# Documento: hub-94890
# Contagem de rótulos (original): {'B-ACONTECIMENTO': 5, 'O': 266, 'B-TEMPO': 15, 'I-TEMPO': 20, 'B-VALOR': 4, 'I-VALOR': 9, 'B-LOCAL': 14, 'B-PESSOA': 5, 'I-PESSOA': 6, 'I-LOCAL': 6, 'B-OBRA': 1, 'I-OBRA': 3}
# Contagem de rótulos (simplificado): {'ACONTECIMENTO': 5, 'O': 266, 'TEMPO': 35, 'VALOR': 13, 'LOCAL': 20, 'PESSOA': 11, 'OBRA': 4}
#
# Documento: hub-66746
# Contagem de rótulos (original): {'B-PESSOA': 11, 'I-PESSOA': 14, 'O': 213, 'B-TEMPO': 7, 'I-TEMPO': 13, 'B-ORGANIZACAO': 15, 'I-ORGANIZACAO': 6, 'B-VALOR': 1, 'B-OBRA': 2, 'I-OBRA': 4, 'B-LOCAL': 1}
# Contagem de rótulos (simplificado): {'PESSOA': 25, 'O': 213, 'TEMPO': 20, 'ORGANIZACAO': 21, 'VALOR': 1, 'OBRA': 6, 'LOCAL': 1}
#
# Documento: hub-30518
# Contagem de rótulos (original): {'O': 325, 'B-COISA': 9, 'B-ACONTECIMENTO': 1, 'I-ACONTECIMENTO': 2, 'B-TEMPO': 3, 'I-TEMPO': 8, 'B-PESSOA': 2, 'I-PESSOA': 3, 'I-COISA': 4, 'B-ABSTRACCAO': 1, 'B-LOCAL': 3, 'I-LOCAL': 1}
# Contagem de rótulos (simplificado): {'O': 325, 'COISA': 13, 'ACONTECIMENTO': 3, 'TEMPO': 11, 'PESSOA': 5, 'ABSTRACCAO': 1, 'LOCAL': 4}
#
# Documento: hub-16268
# Contagem de rótulos (original): {'B-ORGANIZACAO': 16, 'O': 238, 'I-ORGANIZACAO': 13, 'B-TEMPO': 4, 'B-COISA': 4, 'B-LOCAL': 27, 'I-LOCAL': 17, 'B-PESSOA': 1, 'I-PESSOA': 1, 'I-TEMPO': 5, 'B-OBRA': 1, 'B-VALOR': 1, 'I-VALOR': 2}
# Contagem de rótulos (simplificado): {'ORGANIZACAO': 29, 'O': 238, 'TEMPO': 9, 'COISA': 4, 'LOCAL': 44, 'PESSOA': 2, 'OBRA': 1, 'VALOR': 3}
#
# Documento: hub-57257
# Contagem de rótulos (original): {'O': 242, 'B-OBRA': 8, 'I-OBRA': 8, 'B-TEMPO': 5, 'B-VALOR': 2, 'B-PESSOA': 17, 'I-PESSOA': 19, 'I-TEMPO': 7, 'B-ORGANIZACAO': 3, 'I-ORGANIZACAO': 2, 'B-LOCAL': 2, 'I-VALOR': 1}
# Contagem de rótulos (simplificado): {'O': 242, 'OBRA': 16, 'TEMPO': 12, 'VALOR': 3, 'PESSOA': 36, 'ORGANIZACAO': 5, 'LOCAL': 2}
#
# Documento: cver
# Contagem de rótulos (original): {'O': 782, 'B-PESSOA': 18, 'I-PESSOA': 9, 'B-ACONTECIMENTO': 3, 'I-ACONTECIMENTO': 2, 'B-LOCAL': 21, 'B-ORGANIZACAO': 37, 'B-TEMPO': 5, 'I-TEMPO': 11, 'I-LOCAL': 2, 'I-ORGANIZACAO': 5, 'B-ABSTRACCAO': 1}
# Contagem de rótulos (simplificado): {'O': 782, 'PESSOA': 27, 'ACONTECIMENTO': 5, 'LOCAL': 23, 'ORGANIZACAO': 42, 'TEMPO': 16, 'ABSTRACCAO': 1}
#
# Documento: hub-67792
# Contagem de rótulos (original): {'B-PESSOA': 10, 'I-PESSOA': 12, 'O': 307, 'B-ABSTRACCAO': 3, 'B-ORGANIZACAO': 6, 'I-ORGANIZACAO': 13, 'B-LOCAL': 22, 'B-TEMPO': 13, 'I-TEMPO': 16, 'I-LOCAL': 9, 'B-OBRA': 1, 'I-OBRA': 5, 'B-ACONTECIMENTO': 3, 'I-ACONTECIMENTO': 3, 'B-VALOR': 2, 'I-VALOR': 1}
# Contagem de rótulos (simplificado): {'PESSOA': 22, 'O': 307, 'ABSTRACCAO': 3, 'ORGANIZACAO': 19, 'LOCAL': 31, 'TEMPO': 29, 'OBRA': 6, 'ACONTECIMENTO': 6, 'VALOR': 3}
#
# Documento: Ntyr-78
# Contagem de rótulos (original): {'B-ACONTECIMENTO': 7, 'I-ACONTECIMENTO': 15, 'O': 566, 'B-LOCAL': 20, 'I-LOCAL': 11, 'B-TEMPO': 22, 'I-TEMPO': 53, 'B-ORGANIZACAO': 5, 'B-PESSOA': 43, 'I-PESSOA': 51, 'B-VALOR': 16, 'I-VALOR': 24, 'I-ORGANIZACAO': 1, 'B-OBRA': 5, 'I-OBRA': 13}
# Contagem de rótulos (simplificado): {'ACONTECIMENTO': 22, 'O': 566, 'LOCAL': 31, 'TEMPO': 75, 'ORGANIZACAO': 6, 'PESSOA': 94, 'VALOR': 40, 'OBRA': 18}
#
# Documento: gtqqq
# Contagem de rótulos (original): {'O': 1457, 'B-PESSOA': 27, 'I-PESSOA': 20, 'B-LOCAL': 12, 'B-TEMPO': 12, 'I-TEMPO': 22, 'B-ACONTECIMENTO': 2, 'I-ACONTECIMENTO': 4, 'B-ABSTRACCAO': 30, 'I-ABSTRACCAO': 27, 'I-LOCAL': 1, 'B-ORGANIZACAO': 1, 'B-OBRA': 3, 'I-OBRA': 10, 'B-COISA': 1}
# Contagem de rótulos (simplificado): {'O': 1457, 'PESSOA': 47, 'LOCAL': 13, 'TEMPO': 34, 'ACONTECIMENTO': 6, 'ABSTRACCAO': 57, 'ORGANIZACAO': 1, 'OBRA': 13, 'COISA': 1}
#
# Documento: aa77651
# Contagem de rótulos (original): {'B-ORGANIZACAO': 10, 'I-ORGANIZACAO': 20, 'B-PESSOA': 24, 'I-PESSOA': 64, 'O': 121, 'B-LOCAL': 11, 'B-TEMPO': 3, 'I-TEMPO': 13, 'I-LOCAL': 5, 'B-VALOR': 1}
# Contagem de rótulos (simplificado): {'ORGANIZACAO': 30, 'PESSOA': 88, 'O': 121, 'LOCAL': 16, 'TEMPO': 16, 'VALOR': 1}
#
# Documento: wpt-1014517543841152414
# Contagem de rótulos (original): {'O': 217, 'B-COISA': 3, 'I-COISA': 2, 'B-ORGANIZACAO': 1, 'B-VALOR': 6, 'B-LOCAL': 3, 'I-VALOR': 4, 'B-TEMPO': 2, 'I-TEMPO': 5}
# Contagem de rótulos (simplificado): {'O': 217, 'COISA': 5, 'ORGANIZACAO': 1, 'VALOR': 10, 'LOCAL': 3, 'TEMPO': 7}
#
# Documento: ric-74122
# Contagem de rótulos (original): {'O': 1468, 'B-PESSOA': 80, 'I-PESSOA': 63, 'B-TEMPO': 12, 'I-TEMPO': 22, 'B-ORGANIZACAO': 6, 'I-ORGANIZACAO': 4, 'B-OBRA': 23, 'I-OBRA': 41, 'B-COISA': 20, 'I-COISA': 10, 'B-ABSTRACCAO': 8, 'I-ABSTRACCAO': 11, 'B-ACONTECIMENTO': 1, 'I-ACONTECIMENTO': 4, 'B-LOCAL': 5, 'I-LOCAL': 2, 'B-OUTRO': 2}
# Contagem de rótulos (simplificado): {'O': 1468, 'PESSOA': 143, 'TEMPO': 34, 'ORGANIZACAO': 10, 'OBRA': 64, 'COISA': 30, 'ABSTRACCAO': 19, 'ACONTECIMENTO': 5, 'LOCAL': 7, 'OUTRO': 2}
#
# Documento: hub-77889
# Contagem de rótulos (original): {'B-ORGANIZACAO': 9, 'O': 154, 'B-TEMPO': 5, 'I-TEMPO': 4, 'I-ORGANIZACAO': 6, 'B-COISA': 5, 'B-ACONTECIMENTO': 2, 'I-ACONTECIMENTO': 4, 'B-PESSOA': 3, 'I-PESSOA': 5, 'I-COISA': 1}
# Contagem de rótulos (simplificado): {'ORGANIZACAO': 15, 'O': 154, 'TEMPO': 9, 'COISA': 6, 'ACONTECIMENTO': 6, 'PESSOA': 8}
#
# Documento: H2-dftre765
# Contagem de rótulos (original): {'O': 927, 'B-ABSTRACCAO': 25, 'I-ABSTRACCAO': 17, 'B-OUTRO': 1, 'I-OUTRO': 1, 'B-LOCAL': 16, 'B-ACONTECIMENTO': 8, 'I-ACONTECIMENTO': 5, 'B-TEMPO': 15, 'I-TEMPO': 20, 'B-PESSOA': 39, 'I-PESSOA': 27, 'B-OBRA': 11, 'I-OBRA': 31, 'B-ORGANIZACAO': 17, 'I-ORGANIZACAO': 7}
# Contagem de rótulos (simplificado): {'O': 927, 'ABSTRACCAO': 42, 'OUTRO': 2, 'LOCAL': 16, 'ACONTECIMENTO': 13, 'TEMPO': 35, 'PESSOA': 66, 'OBRA': 42, 'ORGANIZACAO': 24}
#
# Documento: hub-47914
# Contagem de rótulos (original): {'O': 446, 'B-OBRA': 6, 'B-PESSOA': 4, 'B-TEMPO': 1, 'I-TEMPO': 3, 'B-ORGANIZACAO': 3, 'I-ORGANIZACAO': 2, 'B-COISA': 2, 'B-ABSTRACCAO': 1, 'I-OBRA': 3, 'B-LOCAL': 2, 'I-LOCAL': 2, 'B-OUTRO': 1}
# Contagem de rótulos (simplificado): {'O': 446, 'OBRA': 9, 'PESSOA': 4, 'TEMPO': 4, 'ORGANIZACAO': 5, 'COISA': 2, 'ABSTRACCAO': 1, 'LOCAL': 4, 'OUTRO': 1}
#
# Documento: dav-188222
# Contagem de rótulos (original): {'O': 1425, 'B-TEMPO': 27, 'I-TEMPO': 48, 'B-LOCAL': 37, 'B-PESSOA': 51, 'I-PESSOA': 40, 'I-LOCAL': 22, 'B-ABSTRACCAO': 2, 'I-ABSTRACCAO': 4, 'B-ORGANIZACAO': 13, 'I-ORGANIZACAO': 4, 'B-COISA': 12, 'B-ACONTECIMENTO': 4, 'I-ACONTECIMENTO': 7, 'B-OBRA': 8, 'I-OBRA': 18, 'B-VALOR': 2, 'I-VALOR': 9, 'I-COISA': 1, 'B-OUTRO': 1, 'I-OUTRO': 3}
# Contagem de rótulos (simplificado): {'O': 1425, 'TEMPO': 75, 'LOCAL': 59, 'PESSOA': 91, 'ABSTRACCAO': 6, 'ORGANIZACAO': 17, 'COISA': 13, 'ACONTECIMENTO': 11, 'OBRA': 26, 'VALOR': 11, 'OUTRO': 4}
#
# Documento: wpt-1001951616378060469
# Contagem de rótulos (original): {'O': 145, 'B-ORGANIZACAO': 1, 'I-ORGANIZACAO': 7, 'B-ABSTRACCAO': 1, 'I-ABSTRACCAO': 3}
# Contagem de rótulos (simplificado): {'O': 145, 'ORGANIZACAO': 8, 'ABSTRACCAO': 4}
#
# Documento: aa33715
# Contagem de rótulos (original): {'O': 260, 'B-PESSOA': 15, 'I-PESSOA': 20, 'B-ORGANIZACAO': 13, 'B-ABSTRACCAO': 3, 'I-ABSTRACCAO': 3, 'B-TEMPO': 3, 'I-TEMPO': 5, 'I-ORGANIZACAO': 6, 'B-VALOR': 2, 'I-VALOR': 4, 'B-COISA': 1}
# Contagem de rótulos (simplificado): {'O': 260, 'PESSOA': 35, 'ORGANIZACAO': 19, 'ABSTRACCAO': 6, 'TEMPO': 8, 'VALOR': 6, 'COISA': 1}
#
# Documento: hub-37819
# Contagem de rótulos (original): {'B-PESSOA': 22, 'O': 229, 'I-PESSOA': 9, 'B-TEMPO': 9, 'I-TEMPO': 15, 'B-VALOR': 11, 'B-LOCAL': 5, 'I-LOCAL': 1, 'B-ACONTECIMENTO': 3, 'I-ACONTECIMENTO': 4, 'I-VALOR': 1}
# Contagem de rótulos (simplificado): {'PESSOA': 31, 'O': 229, 'TEMPO': 24, 'VALOR': 12, 'LOCAL': 6, 'ACONTECIMENTO': 7}
#
# Documento: ric-46913
# Contagem de rótulos (original): {'O': 538, 'B-ABSTRACCAO': 16, 'I-ABSTRACCAO': 6, 'B-TEMPO': 6, 'I-TEMPO': 10, 'B-LOCAL': 4, 'I-LOCAL': 2, 'B-PESSOA': 3, 'B-COISA': 1, 'I-PESSOA': 3, 'B-OUTRO': 1, 'I-OUTRO': 1}
# Contagem de rótulos (simplificado): {'O': 538, 'ABSTRACCAO': 22, 'TEMPO': 16, 'LOCAL': 6, 'PESSOA': 6, 'COISA': 1, 'OUTRO': 2}
#
# Documento: hub-24360
# Contagem de rótulos (original): {'O': 337, 'B-ORGANIZACAO': 10, 'B-OUTRO': 1, 'I-OUTRO': 5, 'B-TEMPO': 3, 'I-TEMPO': 6, 'B-PESSOA': 5, 'I-PESSOA': 6, 'I-ORGANIZACAO': 4, 'B-LOCAL': 1, 'B-ABSTRACCAO': 4}
# Contagem de rótulos (simplificado): {'O': 337, 'ORGANIZACAO': 14, 'OUTRO': 6, 'TEMPO': 9, 'PESSOA': 11, 'LOCAL': 1, 'ABSTRACCAO': 4}
#
# Documento: H2-Ert75
# Contagem de rótulos (original): {'O': 503, 'B-PESSOA': 6, 'I-PESSOA': 9, 'B-LOCAL': 18, 'I-LOCAL': 12, 'B-TEMPO': 5, 'B-ORGANIZACAO': 1, 'I-TEMPO': 3, 'B-VALOR': 2, 'I-VALOR': 1}
# Contagem de rótulos (simplificado): {'O': 503, 'PESSOA': 15, 'LOCAL': 30, 'TEMPO': 8, 'ORGANIZACAO': 1, 'VALOR': 3}
#
# Documento: aa46996
# Contagem de rótulos (original): {'O': 1060, 'B-TEMPO': 17, 'I-TEMPO': 37, 'B-ORGANIZACAO': 45, 'I-ORGANIZACAO': 23, 'B-OBRA': 35, 'I-OBRA': 107, 'B-ACONTECIMENTO': 3, 'I-ACONTECIMENTO': 3, 'B-LOCAL': 17, 'I-LOCAL': 5, 'B-ABSTRACCAO': 5, 'I-ABSTRACCAO': 9, 'B-VALOR': 2, 'I-VALOR': 4, 'B-PESSOA': 7, 'I-PESSOA': 25}
# Contagem de rótulos (simplificado): {'O': 1060, 'TEMPO': 54, 'ORGANIZACAO': 68, 'OBRA': 142, 'ACONTECIMENTO': 6, 'LOCAL': 22, 'ABSTRACCAO': 14, 'VALOR': 6, 'PESSOA': 32}
#
# Documento: aa94781
# Contagem de rótulos (original): {'O': 387, 'B-PESSOA': 17, 'I-PESSOA': 16, 'B-TEMPO': 13, 'I-TEMPO': 23, 'B-OBRA': 2, 'I-OBRA': 3, 'B-OUTRO': 1, 'I-OUTRO': 1, 'B-LOCAL': 13, 'I-LOCAL': 2, 'B-ORGANIZACAO': 3, 'I-ORGANIZACAO': 4, 'B-COISA': 1, 'B-ACONTECIMENTO': 2, 'I-ACONTECIMENTO': 2}
# Contagem de rótulos (simplificado): {'O': 387, 'PESSOA': 33, 'TEMPO': 36, 'OBRA': 5, 'OUTRO': 2, 'LOCAL': 15, 'ORGANIZACAO': 7, 'COISA': 1, 'ACONTECIMENTO': 4}
#
# Documento: hub-15425
# Contagem de rótulos (original): {'B-OBRA': 10, 'I-OBRA': 15, 'O': 191, 'B-TEMPO': 13, 'B-ORGANIZACAO': 10, 'I-ORGANIZACAO': 10, 'B-LOCAL': 3, 'I-TEMPO': 38, 'B-ABSTRACCAO': 3, 'B-PESSOA': 4, 'I-PESSOA': 24, 'B-VALOR': 1, 'I-ABSTRACCAO': 5, 'B-ACONTECIMENTO': 1, 'I-LOCAL': 2}
# Contagem de rótulos (simplificado): {'OBRA': 25, 'O': 191, 'TEMPO': 51, 'ORGANIZACAO': 20, 'LOCAL': 5, 'ABSTRACCAO': 8, 'PESSOA': 28, 'VALOR': 1, 'ACONTECIMENTO': 1}
#
# Documento: H2-EFin
# Contagem de rótulos (original): {'O': 358, 'B-TEMPO': 9, 'I-TEMPO': 10, 'B-LOCAL': 14, 'B-PESSOA': 4, 'I-PESSOA': 9, 'I-LOCAL': 10, 'B-COISA': 3}
# Contagem de rótulos (simplificado): {'O': 358, 'TEMPO': 19, 'LOCAL': 24, 'PESSOA': 13, 'COISA': 3}
#
# Documento: ric-12366
# Contagem de rótulos (original): {'O': 828, 'B-PESSOA': 17, 'I-PESSOA': 7, 'B-LOCAL': 20, 'I-LOCAL': 15, 'B-COISA': 11, 'B-TEMPO': 9, 'I-TEMPO': 10, 'B-ORGANIZACAO': 3, 'I-ORGANIZACAO': 9, 'B-VALOR': 3, 'I-VALOR': 3}
# Contagem de rótulos (simplificado): {'O': 828, 'PESSOA': 24, 'LOCAL': 35, 'COISA': 11, 'TEMPO': 19, 'ORGANIZACAO': 12, 'VALOR': 6}
#
# Documento: wpt-1011130529557294176
# Contagem de rótulos (original): {'O': 301, 'B-LOCAL': 3, 'I-LOCAL': 2, 'B-ABSTRACCAO': 5, 'B-TEMPO': 3, 'I-TEMPO': 10, 'B-OBRA': 2, 'I-OBRA': 17, 'B-PESSOA': 3, 'I-PESSOA': 6, 'B-ORGANIZACAO': 8, 'I-ORGANIZACAO': 19}
# Contagem de rótulos (simplificado): {'O': 301, 'LOCAL': 5, 'ABSTRACCAO': 5, 'TEMPO': 13, 'OBRA': 19, 'PESSOA': 9, 'ORGANIZACAO': 27}
#
# Total de documentos: 129

# %%
# labels_por_doc['HAREMdoc_aa64686'][-12]
# len(labels_por_doc['HAREMdoc_aa64686'])

# %%
lbl_list = []
for lbl in labels_por_doc.values():
    lbl_list.extend(lbl)  # Adiciona os rótulos de cada documento à lista

# Filtrando 'B-OUTRO' e 'I-OUTRO'
lbl_list = [label for label in lbl_list if label not in ['B-OUTRO', 'I-OUTRO']]

# Obtendo os rótulos únicos
unique_lbl_list = list(set(lbl_list))

# Exibindo a lista de rótulos únicos
print(unique_lbl_list)
# Out:
# ['B-PESSOA', 'B-ORGANIZACAO', 'I-TEMPO', 'I-ACONTECIMENTO', 'I-COISA', 'I-VALOR', 'B-COISA', 'O', 'B-ACONTECIMENTO', 'B-ABSTRACCAO', 'I-LOCAL', 'B-TEMPO', 'I-PESSOA', 'B-LOCAL', 'I-ORGANIZACAO', 'I-ABSTRACCAO', 'B-VALOR', 'I-OBRA', 'B-OBRA']

# %%
unique_lbl_list.pop(unique_lbl_list.index('O'))
unique_lbl_list
# Out:
# ['B-PESSOA',
#  'B-ORGANIZACAO',
#  'I-TEMPO',
#  'I-ACONTECIMENTO',
#  'I-COISA',
#  'I-VALOR',
#  'B-COISA',
#  'B-ACONTECIMENTO',
#  'B-ABSTRACCAO',
#  'I-LOCAL',
#  'B-TEMPO',
#  'I-PESSOA',
#  'B-LOCAL',
#  'I-ORGANIZACAO',
#  'I-ABSTRACCAO',
#  'B-VALOR',
#  'I-OBRA',
#  'B-OBRA']

# %%
unique_lbl_list = sorted(unique_lbl_list)
unique_lbl_list
# Out:
# ['B-ABSTRACCAO',
#  'B-ACONTECIMENTO',
#  'B-COISA',
#  'B-LOCAL',
#  'B-OBRA',
#  'B-ORGANIZACAO',
#  'B-PESSOA',
#  'B-TEMPO',
#  'B-VALOR',
#  'I-ABSTRACCAO',
#  'I-ACONTECIMENTO',
#  'I-COISA',
#  'I-LOCAL',
#  'I-OBRA',
#  'I-ORGANIZACAO',
#  'I-PESSOA',
#  'I-TEMPO',
#  'I-VALOR']

# %%
#test_l = ['LOCAL', 'ORGANIZACAO', 'PESSOA', 'TEMPO', 'LOCAL', 'ORGANIZACAO', 'PESSOA', 'TEMPO', 'LOCAL', 'ORGANIZACAO', 'PESSOA', 'TEMPO', 'TEMPO', 'TEMPO']
#[test_l.count(x) for x in unique_lbl_list]

# %%
from collections import Counter

initial_set = []
for s_idx, s_labels in enumerate(list(labels_por_doc.values())):
    # Contagem eficiente dos rótulos usando Counter
    label_count = Counter(s_labels)
    
    # Adicionando o índice do documento e as contagens para cada rótulo em unique_lbl_list
    initial_set.append([s_idx] + [label_count.get(x, 0) for x in unique_lbl_list])

# Verificando o tamanho de initial_set (número de documentos)
print(len(initial_set))
# Out:
# 129

# %%
# initial_set[:, 1:]

# %%
# Adicionando a linha final com os totais de cada label (soma dos rótulos)
initial_set.append(['-'] + [sum(x) for x in zip(*(row[1:] for row in initial_set))])

# Agora vamos filtrar a matriz para manter apenas as 7 primeiras colunas
# (assumindo que as 7 primeiras colunas correspondem aos rótulos -B)
filtered_initial_set = []

for row in initial_set:
    # Mantendo apenas as 7 primeiras colunas (a primeira coluna é '-')
    filtered_row = row[:10]  # Considerando que as primeiras 7 colunas são os rótulos -B
    filtered_initial_set.append(filtered_row)

# Exibindo a matriz resultante filtrada
for row in filtered_initial_set:
    print(row)
# Out:
# [0, 6, 7, 7, 11, 3, 5, 25, 13, 1]
# [1, 0, 5, 13, 2, 0, 0, 21, 7, 11]
# [2, 5, 16, 12, 51, 4, 7, 40, 19, 1]
# [3, 1, 5, 0, 4, 0, 0, 1, 3, 2]
# [4, 2, 0, 3, 4, 1, 4, 0, 3, 0]
# [5, 48, 0, 4, 23, 1, 0, 4, 10, 0]
# [6, 1, 5, 4, 9, 4, 11, 12, 4, 2]
# [7, 0, 0, 1, 5, 0, 2, 11, 3, 3]
# [8, 10, 0, 5, 47, 12, 18, 57, 50, 5]
# [9, 0, 2, 1, 6, 0, 0, 4, 6, 1]
# [10, 0, 0, 1, 19, 0, 12, 14, 21, 13]
# [11, 9, 0, 7, 3, 6, 0, 20, 6, 0]
# [12, 0, 0, 0, 3, 23, 15, 0, 7, 0]
# [13, 0, 0, 0, 1, 2, 17, 9, 5, 0]
# [14, 0, 5, 0, 3, 2, 2, 17, 9, 2]
# [15, 0, 2, 10, 6, 0, 6, 2, 8, 7]
# [16, 0, 0, 6, 27, 0, 2, 1, 4, 11]
# [17, 1, 0, 0, 33, 0, 9, 14, 15, 1]
# [18, 4, 4, 0, 14, 1, 16, 14, 11, 1]
# [19, 1, 0, 0, 9, 1, 1, 0, 7, 1]
# [20, 0, 0, 0, 7, 3, 7, 7, 6, 3]
# [21, 4, 0, 0, 19, 0, 11, 3, 14, 3]
# [22, 0, 2, 0, 12, 1, 6, 23, 6, 0]
# [23, 0, 0, 0, 0, 0, 17, 2, 5, 1]
# [24, 0, 2, 0, 8, 0, 5, 8, 6, 0]
# [25, 2, 0, 8, 2, 0, 1, 3, 3, 7]
# [26, 5, 4, 10, 15, 0, 7, 19, 9, 0]
# [27, 19, 2, 0, 2, 26, 27, 4, 2, 1]
# [28, 5, 0, 0, 9, 2, 0, 9, 6, 0]
# [29, 0, 0, 1, 1, 0, 7, 0, 7, 6]
# [30, 0, 2, 0, 9, 0, 12, 12, 5, 0]
# [31, 3, 0, 0, 5, 1, 35, 21, 15, 0]
# [32, 0, 1, 0, 5, 0, 2, 8, 7, 4]
# [33, 1, 3, 0, 11, 0, 0, 19, 2, 7]
# [34, 0, 0, 3, 5, 0, 2, 3, 2, 2]
# [35, 0, 0, 2, 5, 0, 3, 0, 7, 6]
# [36, 3, 1, 1, 3, 0, 0, 3, 1, 2]
# [37, 0, 1, 0, 15, 1, 8, 16, 3, 2]
# [38, 9, 31, 4, 60, 27, 30, 56, 26, 0]
# [39, 0, 0, 0, 11, 5, 8, 8, 9, 0]
# [40, 2, 0, 0, 0, 12, 0, 33, 8, 0]
# [41, 5, 8, 12, 41, 18, 46, 49, 35, 16]
# [42, 2, 3, 0, 1, 0, 4, 2, 8, 4]
# [43, 0, 0, 0, 0, 2, 0, 5, 6, 1]
# [44, 1, 8, 1, 6, 0, 0, 24, 1, 11]
# [45, 0, 0, 0, 11, 1, 2, 3, 4, 5]
# [46, 2, 8, 7, 57, 7, 32, 56, 41, 7]
# [47, 5, 0, 3, 6, 9, 2, 15, 12, 0]
# [48, 0, 1, 0, 6, 0, 2, 4, 10, 7]
# [49, 0, 0, 0, 1, 0, 4, 0, 3, 1]
# [50, 14, 14, 5, 32, 26, 100, 22, 20, 7]
# [51, 1, 0, 10, 1, 2, 4, 0, 3, 0]
# [52, 0, 5, 0, 3, 0, 0, 9, 2, 9]
# [53, 5, 0, 7, 2, 0, 10, 0, 0, 0]
# [54, 1, 1, 1, 11, 4, 24, 11, 15, 2]
# [55, 0, 1, 2, 7, 4, 2, 1, 2, 0]
# [56, 0, 0, 4, 1, 0, 3, 2, 2, 11]
# [57, 6, 0, 1, 6, 3, 7, 38, 10, 0]
# [58, 0, 0, 0, 2, 0, 0, 5, 0, 0]
# [59, 0, 0, 0, 1, 1, 3, 9, 9, 0]
# [60, 5, 20, 6, 42, 13, 19, 69, 26, 0]
# [61, 15, 1, 1, 17, 21, 24, 173, 24, 7]
# [62, 1, 1, 0, 8, 4, 5, 18, 14, 2]
# [63, 0, 0, 0, 7, 0, 19, 1, 24, 36]
# [64, 0, 0, 0, 3, 2, 15, 15, 8, 0]
# [65, 1, 4, 1, 3, 3, 3, 4, 6, 1]
# [66, 0, 3, 0, 20, 3, 2, 20, 21, 3]
# [67, 1, 1, 6, 4, 10, 2, 12, 5, 4]
# [68, 2, 0, 1, 2, 18, 1, 18, 12, 1]
# [69, 0, 0, 7, 0, 0, 4, 0, 8, 8]
# [70, 12, 0, 6, 15, 2, 5, 19, 12, 0]
# [71, 1, 0, 0, 14, 1, 5, 18, 6, 1]
# [72, 0, 4, 9, 10, 3, 18, 6, 17, 0]
# [73, 9, 3, 0, 14, 3, 3, 9, 9, 1]
# [74, 5, 0, 3, 9, 0, 0, 17, 15, 0]
# [75, 2, 4, 0, 7, 21, 40, 39, 9, 3]
# [76, 1, 13, 1, 15, 0, 2, 26, 8, 3]
# [77, 4, 0, 40, 73, 0, 0, 6, 12, 4]
# [78, 5, 7, 0, 8, 7, 0, 39, 8, 0]
# [79, 0, 11, 0, 9, 1, 4, 10, 2, 0]
# [80, 2, 0, 0, 1, 2, 0, 9, 3, 0]
# [81, 0, 4, 0, 16, 0, 1, 40, 9, 2]
# [82, 0, 8, 0, 9, 2, 6, 20, 14, 2]
# [83, 1, 0, 0, 8, 0, 0, 5, 8, 4]
# [84, 1, 1, 0, 1, 10, 2, 6, 7, 2]
# [85, 1, 1, 0, 11, 3, 18, 20, 13, 1]
# [86, 1, 1, 0, 15, 1, 0, 42, 6, 2]
# [87, 0, 0, 0, 3, 0, 4, 2, 3, 1]
# [88, 2, 0, 13, 3, 0, 4, 0, 1, 0]
# [89, 4, 32, 16, 42, 17, 20, 63, 35, 0]
# [90, 0, 5, 0, 6, 1, 7, 43, 18, 1]
# [91, 0, 0, 0, 1, 0, 11, 0, 1, 0]
# [92, 0, 8, 0, 6, 0, 0, 18, 5, 1]
# [93, 3, 0, 1, 7, 0, 8, 14, 4, 2]
# [94, 4, 5, 1, 7, 0, 26, 5, 7, 3]
# [95, 2, 1, 2, 7, 3, 2, 23, 8, 1]
# [96, 1, 2, 0, 8, 0, 0, 7, 2, 0]
# [97, 0, 3, 0, 22, 9, 0, 6, 12, 8]
# [98, 1, 0, 0, 4, 3, 3, 10, 2, 0]
# [99, 2, 0, 0, 17, 1, 1, 18, 7, 3]
# [100, 2, 0, 2, 6, 0, 0, 5, 4, 2]
# [101, 0, 5, 0, 14, 1, 0, 5, 15, 4]
# [102, 0, 0, 0, 1, 2, 15, 11, 7, 1]
# [103, 1, 1, 9, 3, 0, 0, 2, 3, 0]
# [104, 0, 0, 4, 27, 1, 16, 1, 4, 1]
# [105, 0, 0, 0, 2, 8, 3, 17, 5, 2]
# [106, 1, 3, 0, 21, 0, 37, 18, 5, 0]
# [107, 3, 3, 0, 22, 1, 6, 10, 13, 2]
# [108, 0, 7, 0, 20, 5, 5, 43, 22, 16]
# [109, 30, 2, 1, 12, 3, 1, 27, 12, 0]
# [110, 0, 0, 0, 11, 0, 10, 24, 3, 1]
# [111, 0, 0, 3, 3, 0, 1, 0, 2, 6]
# [112, 8, 1, 20, 5, 23, 6, 80, 12, 0]
# [113, 0, 2, 5, 0, 0, 9, 3, 5, 0]
# [114, 25, 8, 0, 16, 11, 17, 39, 15, 0]
# [115, 1, 0, 2, 2, 6, 3, 4, 1, 0]
# [116, 2, 4, 12, 37, 8, 13, 51, 27, 2]
# [117, 1, 0, 0, 0, 0, 1, 0, 0, 0]
# [118, 3, 0, 1, 0, 0, 13, 15, 3, 2]
# [119, 0, 3, 0, 5, 0, 0, 22, 9, 11]
# [120, 16, 0, 1, 4, 0, 0, 3, 6, 0]
# [121, 4, 0, 0, 1, 0, 10, 5, 3, 0]
# [122, 0, 0, 0, 18, 0, 1, 6, 5, 2]
# [123, 5, 3, 0, 17, 35, 45, 7, 17, 2]
# [124, 0, 2, 1, 13, 2, 3, 17, 13, 0]
# [125, 3, 1, 0, 3, 10, 10, 4, 13, 1]
# [126, 0, 0, 3, 14, 0, 0, 4, 9, 0]
# [127, 0, 0, 11, 20, 0, 3, 17, 9, 3]
# [128, 5, 0, 0, 3, 2, 8, 3, 3, 0]
# ['-', 382, 337, 345, 1453, 497, 1080, 2091, 1199, 352]

# %%
# list(labels_por_doc.keys())

# %%
#initial_set[-1] = initial_set[-1][:7]  # Isso mantém as 7 primeiras colunas, incluindo '-'

# Exibindo a última linha após a atualização
print(filtered_initial_set[-1])
# Out:
# ['-', 382, 337, 345, 1453, 497, 1080, 2091, 1199, 352]

# %%
len(filtered_initial_set)
# Out:
# 130

# %%
number_divisions = 10
result = [x / number_divisions for x in filtered_initial_set[-1][1:]]
print(result)
# Out:
# [38.2, 33.7, 34.5, 145.3, 49.7, 108.0, 209.1, 119.9, 35.2]

# %%
sub_set = [[['-'] + [x/number_divisions for x in filtered_initial_set[-1][1:]]] for i in range(number_divisions)]
sub_set
# Out:
# [[['-', 38.2, 33.7, 34.5, 145.3, 49.7, 108.0, 209.1, 119.9, 35.2]],
#  [['-', 38.2, 33.7, 34.5, 145.3, 49.7, 108.0, 209.1, 119.9, 35.2]],
#  [['-', 38.2, 33.7, 34.5, 145.3, 49.7, 108.0, 209.1, 119.9, 35.2]],
#  [['-', 38.2, 33.7, 34.5, 145.3, 49.7, 108.0, 209.1, 119.9, 35.2]],
#  [['-', 38.2, 33.7, 34.5, 145.3, 49.7, 108.0, 209.1, 119.9, 35.2]],
#  [['-', 38.2, 33.7, 34.5, 145.3, 49.7, 108.0, 209.1, 119.9, 35.2]],
#  [['-', 38.2, 33.7, 34.5, 145.3, 49.7, 108.0, 209.1, 119.9, 35.2]],
#  [['-', 38.2, 33.7, 34.5, 145.3, 49.7, 108.0, 209.1, 119.9, 35.2]],
#  [['-', 38.2, 33.7, 34.5, 145.3, 49.7, 108.0, 209.1, 119.9, 35.2]],
#  [['-', 38.2, 33.7, 34.5, 145.3, 49.7, 108.0, 209.1, 119.9, 35.2]]]

# %% [markdown]
# ##
# ITERATIVE STRATIFICATION
#
# - while there're still sentences in the initial_set
#     - update number of each label in the initial_set
#     - select label in initial_set that has fewest (at least 1) example
#     - then for each sentences that contains this label,
#         - find the subset that desires it more and add it to it
#         - update the desired number of each label for the subset

# %%
# initial_set_l = [x for x in initial_set[:-1] if x[2] > 0]
# len(initial_set_l)
# 12168 - 2734
# for sentence in initial_set_l:
#     initial_set.pop(initial_set.index(sentence))

# %%
# len(initial_set)
# initial_set[-1]
# initial_set[-1] = ['-'] + [ sum(x) for x in zip(*(row[1:] for row in initial_set[:-1])) ]
# initial_set[-1]

# %%
while len(filtered_initial_set) > 1:
    print(f"\nTamanho atual de filtered_initial_set: {len(filtered_initial_set)}")
    contador = 0

    try:
        # Identificar o índice da label com menor quantidade
        min_lbl_idx = filtered_initial_set[-1].index(min((i for i in filtered_initial_set[-1][1:] if i > 0)))
        print(f"Label com menor quantidade: {min_lbl_idx} (quantidade: {filtered_initial_set[-1][min_lbl_idx]})")

        # Filtrar as sentenças relevantes
        initial_set_l = [x for x in filtered_initial_set[:-1] if x[min_lbl_idx] > 0]

        # Ordenar as sentenças pela quantidade da palavra desejada (min_lbl_idx), em ordem decrescente
        initial_set_l.sort(key=lambda x: x[min_lbl_idx], reverse=True)

        print(f"\nSentenças ordenadas pela quantidade da palavra desejada (label {min_lbl_idx}):")
        for idx, item in enumerate(initial_set_l):
            print(f"  {idx + 1}: {item}")

        for sentence in initial_set_l:
            # Verificar os tamanhos das partições
            partition_sizes = [sum(sum(doc[1:]) for doc in partition[1:]) for partition in sub_set]
            partitions_below_limit = [i for i, size in enumerate(partition_sizes) if size < 1225]

            # Escolher a partição com menor valor total
            if partitions_below_limit:
                target_partition_idx = min(partitions_below_limit, key=lambda i: partition_sizes[i])
            else:
                target_partition_idx = partition_sizes.index(min(partition_sizes))

            # Adicionar a sentença na partição escolhida
            sub_set[target_partition_idx].append(sentence)
            filtered_initial_set.pop(filtered_initial_set.index(sentence))

            # Atualizar o desejo de cada label na partição
            sub_set[target_partition_idx][0][1:] = [
                i - j for i, j in zip(sub_set[target_partition_idx][0][1:], sentence[1:])
            ]

            # Atualizar os valores em filtered_initial_set
            filtered_initial_set[-1] = ['-'] + [sum(x) for x in zip(*(row[1:] for row in filtered_initial_set[:-1]))]

            # Imprimir status atualizado
            total_entities_in_partition = partition_sizes[target_partition_idx] + sum(sentence[1:])
            print(f"\nSentença adicionada: {sentence}")
            print(f"Partição {target_partition_idx} agora tem {total_entities_in_partition} entidades.")

            contador += 1

            # Recalcular a label com menor quantidade
            min_lbl_idx = filtered_initial_set[-1].index(min((i for i in filtered_initial_set[-1][1:] if i > 0)))

    except ValueError:
        # Caso ValueError, processar as sentenças restantes sem basear-se na label
        initial_set_l = filtered_initial_set[:-1]

        print(f"\nConteúdo de initial_set_l (ValueError handler, {len(initial_set_l)} elementos):")
        for idx, item in enumerate(initial_set_l):
            print(f"  {idx + 1}: {item}")

        for sentence in initial_set_l:
            # Verificar os tamanhos das partições
            partition_sizes = [sum(sum(doc[1:]) for doc in partition[1:]) for partition in sub_set]
            partitions_below_limit = [i for i, size in enumerate(partition_sizes) if size < 1300]

            # Escolher a partição com menor valor total
            if partitions_below_limit:
                target_partition_idx = min(partitions_below_limit, key=lambda i: partition_sizes[i])
            else:
                target_partition_idx = partition_sizes.index(min(partition_sizes))

            # Adicionar a sentença na partição escolhida
            sub_set[target_partition_idx].append(sentence)
            filtered_initial_set.pop(filtered_initial_set.index(sentence))

            # Atualizar os valores em filtered_initial_set
            filtered_initial_set[-1] = ['-'] + [sum(x) for x in zip(*(row[1:] for row in filtered_initial_set[:-1]))]

            # Imprimir status atualizado
            total_entities_in_partition = partition_sizes[target_partition_idx] + sum(sentence[1:])
            print(f"\nSentença adicionada: {sentence}")
            print(f"Partição {target_partition_idx} agora tem {total_entities_in_partition} entidades.")

    print(f"\nEstado atualizado de filtered_initial_set: {filtered_initial_set[-1]}")
    print(f"Total de sentenças processadas nesta iteração: {contador}")
# Out:
# Tamanho atual de filtered_initial_set: 130
# Label com menor quantidade: 2 (quantidade: 337)
#
# Sentenças ordenadas pela quantidade da palavra desejada (label 2):
#   1: [89, 4, 32, 16, 42, 17, 20, 63, 35, 0]
#   2: [38, 9, 31, 4, 60, 27, 30, 56, 26, 0]
#   3: [60, 5, 20, 6, 42, 13, 19, 69, 26, 0]
#   4: [2, 5, 16, 12, 51, 4, 7, 40, 19, 1]
#   5: [50, 14, 14, 5, 32, 26, 100, 22, 20, 7]
#   6: [76, 1, 13, 1, 15, 0, 2, 26, 8, 3]
#   7: [79, 0, 11, 0, 9, 1, 4, 10, 2, 0]
#   8: [41, 5, 8, 12, 41, 18, 46, 49, 35, 16]
#   9: [44, 1, 8, 1, 6, 0, 0, 24, 1, 11]
#   10: [46, 2, 8, 7, 57, 7, 32, 56, 41, 7]
#   11: [82, 0, 8, 0, 9, 2, 6, 20, 14, 2]
#   12: [92, 0, 8, 0, 6, 0, 0, 18, 5, 1]
#   13: [114, 25, 8, 0, 16, 11, 17, 39, 15, 0]
#   14: [0, 6, 7, 7, 11, 3, 5, 25, 13, 1]
#   15: [78, 5, 7, 0, 8, 7, 0, 39, 8, 0]
#   16: [108, 0, 7, 0, 20, 5, 5, 43, 22, 16]
#   17: [1, 0, 5, 13, 2, 0, 0, 21, 7, 11]
#   18: [3, 1, 5, 0, 4, 0, 0, 1, 3, 2]
#   19: [6, 1, 5, 4, 9, 4, 11, 12, 4, 2]
#   20: [14, 0, 5, 0, 3, 2, 2, 17, 9, 2]
#   21: [52, 0, 5, 0, 3, 0, 0, 9, 2, 9]
#   22: [90, 0, 5, 0, 6, 1, 7, 43, 18, 1]
#   23: [94, 4, 5, 1, 7, 0, 26, 5, 7, 3]
#   24: [101, 0, 5, 0, 14, 1, 0, 5, 15, 4]
#   25: [18, 4, 4, 0, 14, 1, 16, 14, 11, 1]
#   26: [26, 5, 4, 10, 15, 0, 7, 19, 9, 0]
#   27: [65, 1, 4, 1, 3, 3, 3, 4, 6, 1]
#   28: [72, 0, 4, 9, 10, 3, 18, 6, 17, 0]
#   29: [75, 2, 4, 0, 7, 21, 40, 39, 9, 3]
#   30: [81, 0, 4, 0, 16, 0, 1, 40, 9, 2]
#   31: [116, 2, 4, 12, 37, 8, 13, 51, 27, 2]
#   32: [33, 1, 3, 0, 11, 0, 0, 19, 2, 7]
#   33: [42, 2, 3, 0, 1, 0, 4, 2, 8, 4]
#   34: [66, 0, 3, 0, 20, 3, 2, 20, 21, 3]
#   35: [73, 9, 3, 0, 14, 3, 3, 9, 9, 1]
#   36: [97, 0, 3, 0, 22, 9, 0, 6, 12, 8]
#   37: [106, 1, 3, 0, 21, 0, 37, 18, 5, 0]
#   38: [107, 3, 3, 0, 22, 1, 6, 10, 13, 2]
#   39: [119, 0, 3, 0, 5, 0, 0, 22, 9, 11]
#   40: [123, 5, 3, 0, 17, 35, 45, 7, 17, 2]
#   41: [9, 0, 2, 1, 6, 0, 0, 4, 6, 1]
#   42: [15, 0, 2, 10, 6, 0, 6, 2, 8, 7]
#   43: [22, 0, 2, 0, 12, 1, 6, 23, 6, 0]
#   44: [24, 0, 2, 0, 8, 0, 5, 8, 6, 0]
#   45: [27, 19, 2, 0, 2, 26, 27, 4, 2, 1]
#   46: [30, 0, 2, 0, 9, 0, 12, 12, 5, 0]
#   47: [96, 1, 2, 0, 8, 0, 0, 7, 2, 0]
#   48: [109, 30, 2, 1, 12, 3, 1, 27, 12, 0]
#   49: [113, 0, 2, 5, 0, 0, 9, 3, 5, 0]
#   50: [124, 0, 2, 1, 13, 2, 3, 17, 13, 0]
#   51: [32, 0, 1, 0, 5, 0, 2, 8, 7, 4]
#   52: [36, 3, 1, 1, 3, 0, 0, 3, 1, 2]
#   53: [37, 0, 1, 0, 15, 1, 8, 16, 3, 2]
#   54: [48, 0, 1, 0, 6, 0, 2, 4, 10, 7]
#   55: [54, 1, 1, 1, 11, 4, 24, 11, 15, 2]
#   56: [55, 0, 1, 2, 7, 4, 2, 1, 2, 0]
#   57: [61, 15, 1, 1, 17, 21, 24, 173, 24, 7]
#   58: [62, 1, 1, 0, 8, 4, 5, 18, 14, 2]
#   59: [67, 1, 1, 6, 4, 10, 2, 12, 5, 4]
#   60: [84, 1, 1, 0, 1, 10, 2, 6, 7, 2]
#   61: [85, 1, 1, 0, 11, 3, 18, 20, 13, 1]
#   62: [86, 1, 1, 0, 15, 1, 0, 42, 6, 2]
#   63: [95, 2, 1, 2, 7, 3, 2, 23, 8, 1]
#   64: [103, 1, 1, 9, 3, 0, 0, 2, 3, 0]
#   65: [112, 8, 1, 20, 5, 23, 6, 80, 12, 0]
#   66: [125, 3, 1, 0, 3, 10, 10, 4, 13, 1]
#
# Sentença adicionada: [89, 4, 32, 16, 42, 17, 20, 63, 35, 0]
# Partição 0 agora tem 229 entidades.
#
# Sentença adicionada: [38, 9, 31, 4, 60, 27, 30, 56, 26, 0]
# Partição 1 agora tem 243 entidades.
#
# Sentença adicionada: [60, 5, 20, 6, 42, 13, 19, 69, 26, 0]
# Partição 2 agora tem 200 entidades.
#
# Sentença adicionada: [2, 5, 16, 12, 51, 4, 7, 40, 19, 1]
# Partição 3 agora tem 155 entidades.
#
# Sentença adicionada: [50, 14, 14, 5, 32, 26, 100, 22, 20, 7]
# Partição 4 agora tem 240 entidades.
#
# Sentença adicionada: [76, 1, 13, 1, 15, 0, 2, 26, 8, 3]
# Partição 5 agora tem 69 entidades.
#
# Sentença adicionada: [79, 0, 11, 0, 9, 1, 4, 10, 2, 0]
# Partição 6 agora tem 37 entidades.
#
# Sentença adicionada: [41, 5, 8, 12, 41, 18, 46, 49, 35, 16]
# Partição 7 agora tem 230 entidades.
#
# Sentença adicionada: [44, 1, 8, 1, 6, 0, 0, 24, 1, 11]
# Partição 8 agora tem 52 entidades.
#
# Sentença adicionada: [46, 2, 8, 7, 57, 7, 32, 56, 41, 7]
# Partição 9 agora tem 217 entidades.
#
# Sentença adicionada: [82, 0, 8, 0, 9, 2, 6, 20, 14, 2]
# Partição 6 agora tem 98 entidades.
#
# Sentença adicionada: [92, 0, 8, 0, 6, 0, 0, 18, 5, 1]
# Partição 8 agora tem 90 entidades.
#
# Sentença adicionada: [114, 25, 8, 0, 16, 11, 17, 39, 15, 0]
# Partição 5 agora tem 200 entidades.
#
# Sentença adicionada: [0, 6, 7, 7, 11, 3, 5, 25, 13, 1]
# Partição 8 agora tem 168 entidades.
#
# Sentença adicionada: [78, 5, 7, 0, 8, 7, 0, 39, 8, 0]
# Partição 6 agora tem 172 entidades.
#
# Sentença adicionada: [108, 0, 7, 0, 20, 5, 5, 43, 22, 16]
# Partição 3 agora tem 273 entidades.
#
# Sentença adicionada: [1, 0, 5, 13, 2, 0, 0, 21, 7, 11]
# Partição 8 agora tem 227 entidades.
#
# Sentença adicionada: [3, 1, 5, 0, 4, 0, 0, 1, 3, 2]
# Partição 6 agora tem 188 entidades.
#
# Sentença adicionada: [6, 1, 5, 4, 9, 4, 11, 12, 4, 2]
# Partição 6 agora tem 240 entidades.
#
# Sentença adicionada: [14, 0, 5, 0, 3, 2, 2, 17, 9, 2]
# Partição 2 agora tem 240 entidades.
#
# Sentença adicionada: [52, 0, 5, 0, 3, 0, 0, 9, 2, 9]
# Partição 5 agora tem 228 entidades.
#
# Sentença adicionada: [90, 0, 5, 0, 6, 1, 7, 43, 18, 1]
# Partição 9 agora tem 298 entidades.
#
# Sentença adicionada: [94, 4, 5, 1, 7, 0, 26, 5, 7, 3]
# Partição 8 agora tem 285 entidades.
#
# Sentença adicionada: [101, 0, 5, 0, 14, 1, 0, 5, 15, 4]
# Partição 5 agora tem 272 entidades.
#
# Sentença adicionada: [18, 4, 4, 0, 14, 1, 16, 14, 11, 1]
# Partição 0 agora tem 294 entidades.
#
# Sentença adicionada: [26, 5, 4, 10, 15, 0, 7, 19, 9, 0]
# Partição 7 agora tem 299 entidades.
#
# Sentença adicionada: [65, 1, 4, 1, 3, 3, 3, 4, 6, 1]
# Partição 2 agora tem 266 entidades.
#
# Sentença adicionada: [72, 0, 4, 9, 10, 3, 18, 6, 17, 0]
# Partição 4 agora tem 307 entidades.
#
# Sentença adicionada: [75, 2, 4, 0, 7, 21, 40, 39, 9, 3]
# Partição 6 agora tem 365 entidades.
#
# Sentença adicionada: [81, 0, 4, 0, 16, 0, 1, 40, 9, 2]
# Partição 1 agora tem 315 entidades.
#
# Sentença adicionada: [116, 2, 4, 12, 37, 8, 13, 51, 27, 2]
# Partição 2 agora tem 422 entidades.
#
# Sentença adicionada: [33, 1, 3, 0, 11, 0, 0, 19, 2, 7]
# Partição 5 agora tem 315 entidades.
#
# Sentença adicionada: [42, 2, 3, 0, 1, 0, 4, 2, 8, 4]
# Partição 3 agora tem 297 entidades.
#
# Sentença adicionada: [66, 0, 3, 0, 20, 3, 2, 20, 21, 3]
# Partição 8 agora tem 357 entidades.
#
# Sentença adicionada: [73, 9, 3, 0, 14, 3, 3, 9, 9, 1]
# Partição 0 agora tem 345 entidades.
#
# Sentença adicionada: [97, 0, 3, 0, 22, 9, 0, 6, 12, 8]
# Partição 3 agora tem 357 entidades.
#
# Sentença adicionada: [106, 1, 3, 0, 21, 0, 37, 18, 5, 0]
# Partição 9 agora tem 383 entidades.
#
# Sentença adicionada: [107, 3, 3, 0, 22, 1, 6, 10, 13, 2]
# Partição 7 agora tem 359 entidades.
#
# Sentença adicionada: [119, 0, 3, 0, 5, 0, 0, 22, 9, 11]
# Partição 4 agora tem 357 entidades.
#
# Sentença adicionada: [123, 5, 3, 0, 17, 35, 45, 7, 17, 2]
# Partição 1 agora tem 446 entidades.
#
# Sentença adicionada: [9, 0, 2, 1, 6, 0, 0, 4, 6, 1]
# Partição 5 agora tem 335 entidades.
#
# Sentença adicionada: [15, 0, 2, 10, 6, 0, 6, 2, 8, 7]
# Partição 5 agora tem 376 entidades.
#
# Sentença adicionada: [22, 0, 2, 0, 12, 1, 6, 23, 6, 0]
# Partição 0 agora tem 395 entidades.
#
# Sentença adicionada: [24, 0, 2, 0, 8, 0, 5, 8, 6, 0]
# Partição 3 agora tem 386 entidades.
#
# Sentença adicionada: [27, 19, 2, 0, 2, 26, 27, 4, 2, 1]
# Partição 4 agora tem 440 entidades.
#
# Sentença adicionada: [30, 0, 2, 0, 9, 0, 12, 12, 5, 0]
# Partição 8 agora tem 397 entidades.
#
# Sentença adicionada: [96, 1, 2, 0, 8, 0, 0, 7, 2, 0]
# Partição 7 agora tem 379 entidades.
#
# Sentença adicionada: [109, 30, 2, 1, 12, 3, 1, 27, 12, 0]
# Partição 6 agora tem 453 entidades.
#
# Sentença adicionada: [113, 0, 2, 5, 0, 0, 9, 3, 5, 0]
# Partição 5 agora tem 400 entidades.
#
# Sentença adicionada: [124, 0, 2, 1, 13, 2, 3, 17, 13, 0]
# Partição 7 agora tem 430 entidades.
#
# Sentença adicionada: [32, 0, 1, 0, 5, 0, 2, 8, 7, 4]
# Partição 9 agora tem 410 entidades.
#
# Sentença adicionada: [36, 3, 1, 1, 3, 0, 0, 3, 1, 2]
# Partição 3 agora tem 400 entidades.
#
# Sentença adicionada: [37, 0, 1, 0, 15, 1, 8, 16, 3, 2]
# Partição 0 agora tem 441 entidades.
#
# Sentença adicionada: [48, 0, 1, 0, 6, 0, 2, 4, 10, 7]
# Partição 8 agora tem 427 entidades.
#
# Sentença adicionada: [54, 1, 1, 1, 11, 4, 24, 11, 15, 2]
# Partição 3 agora tem 470 entidades.
#
# Sentença adicionada: [55, 0, 1, 2, 7, 4, 2, 1, 2, 0]
# Partição 5 agora tem 419 entidades.
#
# Sentença adicionada: [61, 15, 1, 1, 17, 21, 24, 173, 24, 7]
# Partição 9 agora tem 693 entidades.
#
# Sentença adicionada: [62, 1, 1, 0, 8, 4, 5, 18, 14, 2]
# Partição 5 agora tem 472 entidades.
#
# Sentença adicionada: [67, 1, 1, 6, 4, 10, 2, 12, 5, 4]
# Partição 2 agora tem 467 entidades.
#
# Sentença adicionada: [84, 1, 1, 0, 1, 10, 2, 6, 7, 2]
# Partição 8 agora tem 457 entidades.
#
# Sentença adicionada: [85, 1, 1, 0, 11, 3, 18, 20, 13, 1]
# Partição 7 agora tem 498 entidades.
#
# Sentença adicionada: [86, 1, 1, 0, 15, 1, 0, 42, 6, 2]
# Partição 4 agora tem 508 entidades.
#
# Sentença adicionada: [95, 2, 1, 2, 7, 3, 2, 23, 8, 1]
# Partição 0 agora tem 490 entidades.
#
# Sentença adicionada: [103, 1, 1, 9, 3, 0, 0, 2, 3, 0]
# Partição 1 agora tem 465 entidades.
#
# Sentença adicionada: [112, 8, 1, 20, 5, 23, 6, 80, 12, 0]
# Partição 6 agora tem 608 entidades.
#
# Sentença adicionada: [125, 3, 1, 0, 3, 10, 10, 4, 13, 1]
# Partição 8 agora tem 502 entidades.
#
# Estado atualizado de filtered_initial_set: ['-', 171, 0, 164, 548, 135, 370, 563, 452, 160]
# Total de sentenças processadas nesta iteração: 66
#
# Tamanho atual de filtered_initial_set: 64
# Label com menor quantidade: 5 (quantidade: 135)
#
# Sentenças ordenadas pela quantidade da palavra desejada (label 5):
#   1: [12, 0, 0, 0, 3, 23, 15, 0, 7, 0]
#   2: [68, 2, 0, 1, 2, 18, 1, 18, 12, 1]
#   3: [8, 10, 0, 5, 47, 12, 18, 57, 50, 5]
#   4: [40, 2, 0, 0, 0, 12, 0, 33, 8, 0]
#   5: [47, 5, 0, 3, 6, 9, 2, 15, 12, 0]
#   6: [105, 0, 0, 0, 2, 8, 3, 17, 5, 2]
#   7: [11, 9, 0, 7, 3, 6, 0, 20, 6, 0]
#   8: [115, 1, 0, 2, 2, 6, 3, 4, 1, 0]
#   9: [39, 0, 0, 0, 11, 5, 8, 8, 9, 0]
#   10: [20, 0, 0, 0, 7, 3, 7, 7, 6, 3]
#   11: [57, 6, 0, 1, 6, 3, 7, 38, 10, 0]
#   12: [98, 1, 0, 0, 4, 3, 3, 10, 2, 0]
#   13: [13, 0, 0, 0, 1, 2, 17, 9, 5, 0]
#   14: [28, 5, 0, 0, 9, 2, 0, 9, 6, 0]
#   15: [43, 0, 0, 0, 0, 2, 0, 5, 6, 1]
#   16: [51, 1, 0, 10, 1, 2, 4, 0, 3, 0]
#   17: [64, 0, 0, 0, 3, 2, 15, 15, 8, 0]
#   18: [70, 12, 0, 6, 15, 2, 5, 19, 12, 0]
#   19: [80, 2, 0, 0, 1, 2, 0, 9, 3, 0]
#   20: [102, 0, 0, 0, 1, 2, 15, 11, 7, 1]
#   21: [128, 5, 0, 0, 3, 2, 8, 3, 3, 0]
#   22: [4, 2, 0, 3, 4, 1, 4, 0, 3, 0]
#   23: [5, 48, 0, 4, 23, 1, 0, 4, 10, 0]
#   24: [19, 1, 0, 0, 9, 1, 1, 0, 7, 1]
#   25: [31, 3, 0, 0, 5, 1, 35, 21, 15, 0]
#   26: [45, 0, 0, 0, 11, 1, 2, 3, 4, 5]
#   27: [59, 0, 0, 0, 1, 1, 3, 9, 9, 0]
#   28: [71, 1, 0, 0, 14, 1, 5, 18, 6, 1]
#   29: [99, 2, 0, 0, 17, 1, 1, 18, 7, 3]
#   30: [104, 0, 0, 4, 27, 1, 16, 1, 4, 1]
#
# Sentença adicionada: [12, 0, 0, 0, 3, 23, 15, 0, 7, 0]
# Partição 1 agora tem 513 entidades.
#
# Sentença adicionada: [68, 2, 0, 1, 2, 18, 1, 18, 12, 1]
# Partição 2 agora tem 522 entidades.
#
# Sentença adicionada: [8, 10, 0, 5, 47, 12, 18, 57, 50, 5]
# Partição 3 agora tem 674 entidades.
#
# Sentença adicionada: [40, 2, 0, 0, 0, 12, 0, 33, 8, 0]
# Partição 5 agora tem 527 entidades.
#
# Sentença adicionada: [47, 5, 0, 3, 6, 9, 2, 15, 12, 0]
# Partição 0 agora tem 542 entidades.
#
# Sentença adicionada: [105, 0, 0, 0, 2, 8, 3, 17, 5, 2]
# Partição 7 agora tem 535 entidades.
#
# Sentença adicionada: [11, 9, 0, 7, 3, 6, 0, 20, 6, 0]
# Partição 8 agora tem 553 entidades.
#
# Sentença adicionada: [115, 1, 0, 2, 2, 6, 3, 4, 1, 0]
# Partição 4 agora tem 527 entidades.
#
# Sentença adicionada: [39, 0, 0, 0, 11, 5, 8, 8, 9, 0]
# Partição 1 agora tem 554 entidades.
#
# Sentença adicionada: [20, 0, 0, 0, 7, 3, 7, 7, 6, 3]
# Partição 2 agora tem 555 entidades.
#
# Sentença adicionada: [57, 6, 0, 1, 6, 3, 7, 38, 10, 0]
# Partição 4 agora tem 598 entidades.
#
# Sentença adicionada: [98, 1, 0, 0, 4, 3, 3, 10, 2, 0]
# Partição 5 agora tem 550 entidades.
#
# Sentença adicionada: [13, 0, 0, 0, 1, 2, 17, 9, 5, 0]
# Partição 7 agora tem 569 entidades.
#
# Sentença adicionada: [28, 5, 0, 0, 9, 2, 0, 9, 6, 0]
# Partição 0 agora tem 573 entidades.
#
# Sentença adicionada: [43, 0, 0, 0, 0, 2, 0, 5, 6, 1]
# Partição 5 agora tem 564 entidades.
#
# Sentença adicionada: [51, 1, 0, 10, 1, 2, 4, 0, 3, 0]
# Partição 8 agora tem 574 entidades.
#
# Sentença adicionada: [64, 0, 0, 0, 3, 2, 15, 15, 8, 0]
# Partição 1 agora tem 597 entidades.
#
# Sentença adicionada: [70, 12, 0, 6, 15, 2, 5, 19, 12, 0]
# Partição 2 agora tem 626 entidades.
#
# Sentença adicionada: [80, 2, 0, 0, 1, 2, 0, 9, 3, 0]
# Partição 5 agora tem 581 entidades.
#
# Sentença adicionada: [102, 0, 0, 0, 1, 2, 15, 11, 7, 1]
# Partição 7 agora tem 606 entidades.
#
# Sentença adicionada: [128, 5, 0, 0, 3, 2, 8, 3, 3, 0]
# Partição 0 agora tem 597 entidades.
#
# Sentença adicionada: [4, 2, 0, 3, 4, 1, 4, 0, 3, 0]
# Partição 8 agora tem 591 entidades.
#
# Sentença adicionada: [5, 48, 0, 4, 23, 1, 0, 4, 10, 0]
# Partição 5 agora tem 671 entidades.
#
# Sentença adicionada: [19, 1, 0, 0, 9, 1, 1, 0, 7, 1]
# Partição 8 agora tem 611 entidades.
#
# Sentença adicionada: [31, 3, 0, 0, 5, 1, 35, 21, 15, 0]
# Partição 0 agora tem 677 entidades.
#
# Sentença adicionada: [45, 0, 0, 0, 11, 1, 2, 3, 4, 5]
# Partição 1 agora tem 623 entidades.
#
# Sentença adicionada: [59, 0, 0, 0, 1, 1, 3, 9, 9, 0]
# Partição 4 agora tem 621 entidades.
#
# Sentença adicionada: [71, 1, 0, 0, 14, 1, 5, 18, 6, 1]
# Partição 7 agora tem 652 entidades.
#
# Sentença adicionada: [99, 2, 0, 0, 17, 1, 1, 18, 7, 3]
# Partição 6 agora tem 657 entidades.
#
# Sentença adicionada: [104, 0, 0, 4, 27, 1, 16, 1, 4, 1]
# Partição 8 agora tem 665 entidades.
#
# Estado atualizado de filtered_initial_set: ['-', 53, 0, 118, 310, 0, 172, 182, 206, 136]
# Total de sentenças processadas nesta iteração: 30
#
# Tamanho atual de filtered_initial_set: 34
# Label com menor quantidade: 1 (quantidade: 53)
#
# Sentenças ordenadas pela quantidade da palavra desejada (label 1):
#   1: [120, 16, 0, 1, 4, 0, 0, 3, 6, 0]
#   2: [53, 5, 0, 7, 2, 0, 10, 0, 0, 0]
#   3: [74, 5, 0, 3, 9, 0, 0, 17, 15, 0]
#   4: [21, 4, 0, 0, 19, 0, 11, 3, 14, 3]
#   5: [77, 4, 0, 40, 73, 0, 0, 6, 12, 4]
#   6: [121, 4, 0, 0, 1, 0, 10, 5, 3, 0]
#   7: [93, 3, 0, 1, 7, 0, 8, 14, 4, 2]
#   8: [118, 3, 0, 1, 0, 0, 13, 15, 3, 2]
#   9: [25, 2, 0, 8, 2, 0, 1, 3, 3, 7]
#   10: [88, 2, 0, 13, 3, 0, 4, 0, 1, 0]
#   11: [100, 2, 0, 2, 6, 0, 0, 5, 4, 2]
#   12: [17, 1, 0, 0, 33, 0, 9, 14, 15, 1]
#   13: [83, 1, 0, 0, 8, 0, 0, 5, 8, 4]
#   14: [117, 1, 0, 0, 0, 0, 1, 0, 0, 0]
#
# Sentença adicionada: [120, 16, 0, 1, 4, 0, 0, 3, 6, 0]
# Partição 4 agora tem 651 entidades.
#
# Sentença adicionada: [53, 5, 0, 7, 2, 0, 10, 0, 0, 0]
# Partição 1 agora tem 647 entidades.
#
# Sentença adicionada: [74, 5, 0, 3, 9, 0, 0, 17, 15, 0]
# Partição 2 agora tem 675 entidades.
#
# Sentença adicionada: [21, 4, 0, 0, 19, 0, 11, 3, 14, 3]
# Partição 1 agora tem 701 entidades.
#
# Sentença adicionada: [77, 4, 0, 40, 73, 0, 0, 6, 12, 4]
# Partição 4 agora tem 790 entidades.
#
# Sentença adicionada: [121, 4, 0, 0, 1, 0, 10, 5, 3, 0]
# Partição 7 agora tem 675 entidades.
#
# Sentença adicionada: [93, 3, 0, 1, 7, 0, 8, 14, 4, 2]
# Partição 6 agora tem 696 entidades.
#
# Sentença adicionada: [118, 3, 0, 1, 0, 0, 13, 15, 3, 2]
# Partição 8 agora tem 702 entidades.
#
# Sentença adicionada: [25, 2, 0, 8, 2, 0, 1, 3, 3, 7]
# Partição 5 agora tem 697 entidades.
#
# Sentença adicionada: [88, 2, 0, 13, 3, 0, 4, 0, 1, 0]
# Partição 3 agora tem 697 entidades.
#
# Sentença adicionada: [100, 2, 0, 2, 6, 0, 0, 5, 4, 2]
# Partição 2 agora tem 696 entidades.
#
# Sentença adicionada: [17, 1, 0, 0, 33, 0, 9, 14, 15, 1]
# Partição 7 agora tem 748 entidades.
#
# Sentença adicionada: [83, 1, 0, 0, 8, 0, 0, 5, 8, 4]
# Partição 0 agora tem 703 entidades.
#
# Sentença adicionada: [117, 1, 0, 0, 0, 0, 1, 0, 0, 0]
# Partição 9 agora tem 695 entidades.
#
# Estado atualizado de filtered_initial_set: ['-', 0, 0, 42, 143, 0, 105, 92, 118, 111]
# Total de sentenças processadas nesta iteração: 14
#
# Tamanho atual de filtered_initial_set: 20
# Label com menor quantidade: 3 (quantidade: 42)
#
# Sentenças ordenadas pela quantidade da palavra desejada (label 3):
#   1: [127, 0, 0, 11, 20, 0, 3, 17, 9, 3]
#   2: [69, 0, 0, 7, 0, 0, 4, 0, 8, 8]
#   3: [16, 0, 0, 6, 27, 0, 2, 1, 4, 11]
#   4: [56, 0, 0, 4, 1, 0, 3, 2, 2, 11]
#   5: [34, 0, 0, 3, 5, 0, 2, 3, 2, 2]
#   6: [111, 0, 0, 3, 3, 0, 1, 0, 2, 6]
#   7: [126, 0, 0, 3, 14, 0, 0, 4, 9, 0]
#   8: [35, 0, 0, 2, 5, 0, 3, 0, 7, 6]
#   9: [7, 0, 0, 1, 5, 0, 2, 11, 3, 3]
#   10: [10, 0, 0, 1, 19, 0, 12, 14, 21, 13]
#   11: [29, 0, 0, 1, 1, 0, 7, 0, 7, 6]
#
# Sentença adicionada: [127, 0, 0, 11, 20, 0, 3, 17, 9, 3]
# Partição 9 agora tem 758 entidades.
#
# Sentença adicionada: [69, 0, 0, 7, 0, 0, 4, 0, 8, 8]
# Partição 2 agora tem 723 entidades.
#
# Sentença adicionada: [16, 0, 0, 6, 27, 0, 2, 1, 4, 11]
# Partição 6 agora tem 747 entidades.
#
# Sentença adicionada: [56, 0, 0, 4, 1, 0, 3, 2, 2, 11]
# Partição 3 agora tem 720 entidades.
#
# Sentença adicionada: [34, 0, 0, 3, 5, 0, 2, 3, 2, 2]
# Partição 5 agora tem 714 entidades.
#
# Sentença adicionada: [111, 0, 0, 3, 3, 0, 1, 0, 2, 6]
# Partição 1 agora tem 716 entidades.
#
# Sentença adicionada: [126, 0, 0, 3, 14, 0, 0, 4, 9, 0]
# Partição 8 agora tem 732 entidades.
#
# Sentença adicionada: [35, 0, 0, 2, 5, 0, 3, 0, 7, 6]
# Partição 0 agora tem 726 entidades.
#
# Sentença adicionada: [7, 0, 0, 1, 5, 0, 2, 11, 3, 3]
# Partição 5 agora tem 739 entidades.
#
# Sentença adicionada: [10, 0, 0, 1, 19, 0, 12, 14, 21, 13]
# Partição 1 agora tem 796 entidades.
#
# Sentença adicionada: [29, 0, 0, 1, 1, 0, 7, 0, 7, 6]
# Partição 3 agora tem 742 entidades.
#
# Estado atualizado de filtered_initial_set: ['-', 0, 0, 0, 43, 0, 66, 40, 44, 42]
# Total de sentenças processadas nesta iteração: 11
#
# Tamanho atual de filtered_initial_set: 9
# Label com menor quantidade: 7 (quantidade: 40)
#
# Sentenças ordenadas pela quantidade da palavra desejada (label 7):
#   1: [110, 0, 0, 0, 11, 0, 10, 24, 3, 1]
#   2: [122, 0, 0, 0, 18, 0, 1, 6, 5, 2]
#   3: [58, 0, 0, 0, 2, 0, 0, 5, 0, 0]
#   4: [23, 0, 0, 0, 0, 0, 17, 2, 5, 1]
#   5: [87, 0, 0, 0, 3, 0, 4, 2, 3, 1]
#   6: [63, 0, 0, 0, 7, 0, 19, 1, 24, 36]
#
# Sentença adicionada: [110, 0, 0, 0, 11, 0, 10, 24, 3, 1]
# Partição 2 agora tem 772 entidades.
#
# Sentença adicionada: [122, 0, 0, 0, 18, 0, 1, 6, 5, 2]
# Partição 0 agora tem 758 entidades.
#
# Sentença adicionada: [58, 0, 0, 0, 2, 0, 0, 5, 0, 0]
# Partição 8 agora tem 739 entidades.
#
# Sentença adicionada: [23, 0, 0, 0, 0, 0, 17, 2, 5, 1]
# Partição 5 agora tem 764 entidades.
#
# Sentença adicionada: [87, 0, 0, 0, 3, 0, 4, 2, 3, 1]
# Partição 8 agora tem 752 entidades.
#
# Sentença adicionada: [63, 0, 0, 0, 7, 0, 19, 1, 24, 36]
# Partição 3 agora tem 829 entidades.
#
# Estado atualizado de filtered_initial_set: ['-', 0, 0, 0, 2, 0, 15, 0, 4, 1]
# Total de sentenças processadas nesta iteração: 6
#
# Tamanho atual de filtered_initial_set: 3
# Label com menor quantidade: 9 (quantidade: 1)
#
# Sentenças ordenadas pela quantidade da palavra desejada (label 9):
#   1: [49, 0, 0, 0, 1, 0, 4, 0, 3, 1]
#
# Sentença adicionada: [49, 0, 0, 0, 1, 0, 4, 0, 3, 1]
# Partição 6 agora tem 756 entidades.
#
# Estado atualizado de filtered_initial_set: ['-', 0, 0, 0, 1, 0, 11, 0, 1, 0]
# Total de sentenças processadas nesta iteração: 1
#
# Tamanho atual de filtered_initial_set: 2
# Label com menor quantidade: 4 (quantidade: 1)
#
# Sentenças ordenadas pela quantidade da palavra desejada (label 4):
#   1: [91, 0, 0, 0, 1, 0, 11, 0, 1, 0]
#
# Sentença adicionada: [91, 0, 0, 0, 1, 0, 11, 0, 1, 0]
# Partição 7 agora tem 761 entidades.
#
# Conteúdo de initial_set_l (ValueError handler, 0 elementos):
#
# Estado atualizado de filtered_initial_set: ['-']
# Total de sentenças processadas nesta iteração: 1

# %%
filtered_initial_set
# Out:
# [['-']]

# %%
for sub in sub_set:
    print('tam: {} - lbs:{}'.format(len(sub[1:]), sub[0]))
# Out:
# tam: 13 - lbs:['-', 0.20000000000000284, -9.299999999999997, 11.5, -12.699999999999989, 9.700000000000003, 4.0, 2.0999999999999943, -8.099999999999994, 18.200000000000003]
# tam: 12 - lbs:['-', 14.200000000000003, -5.299999999999997, 10.5, -21.69999999999999, -43.3, -42.0, 61.099999999999994, -0.09999999999999432, 4.200000000000003]
# tam: 12 - lbs:['-', 8.200000000000003, -0.29999999999999716, -9.5, 6.300000000000011, -9.299999999999997, 42.0, -33.900000000000006, -13.099999999999994, 11.200000000000003]
# tam: 12 - lbs:['-', 15.200000000000003, 0.7000000000000028, -2.5, -29.69999999999999, 15.700000000000003, 12.0, 36.099999999999994, -47.099999999999994, -55.8]
# tam: 10 - lbs:['-', -22.799999999999997, 9.700000000000003, -23.5, -4.699999999999989, -16.299999999999997, -50.0, 53.099999999999994, 27.900000000000006, 10.200000000000003]
# tam: 19 - lbs:['-', -44.8, -8.299999999999997, -0.5, 19.30000000000001, 9.700000000000003, 42.0, 3.0999999999999943, 0.9000000000000057, -11.799999999999997]
# tam: 12 - lbs:['-', -13.799999999999997, -9.299999999999997, 2.5, 30.30000000000001, -12.299999999999997, 25.0, -51.900000000000006, 37.900000000000006, 9.200000000000003]
# tam: 13 - lbs:['-', 17.200000000000003, 13.700000000000003, 11.5, -17.69999999999999, 12.700000000000003, -42.0, 13.099999999999994, -7.099999999999994, 11.200000000000003]
# tam: 19 - lbs:['-', 7.200000000000003, -7.299999999999997, -15.5, 11.300000000000011, 12.700000000000003, 7.0, 23.099999999999994, -7.099999999999994, -9.799999999999997]
# tam: 7 - lbs:['-', 19.200000000000003, 15.700000000000003, 15.5, 19.30000000000001, 20.700000000000003, 2.0, -105.9, 15.900000000000006, 13.200000000000003]

# %%
for sub in sub_set:
    
    print (sub)
# Out:
# [['-', 0.20000000000000284, -9.299999999999997, 11.5, -12.699999999999989, 9.700000000000003, 4.0, 2.0999999999999943, -8.099999999999994, 18.200000000000003], [89, 4, 32, 16, 42, 17, 20, 63, 35, 0], [18, 4, 4, 0, 14, 1, 16, 14, 11, 1], [73, 9, 3, 0, 14, 3, 3, 9, 9, 1], [22, 0, 2, 0, 12, 1, 6, 23, 6, 0], [37, 0, 1, 0, 15, 1, 8, 16, 3, 2], [95, 2, 1, 2, 7, 3, 2, 23, 8, 1], [47, 5, 0, 3, 6, 9, 2, 15, 12, 0], [28, 5, 0, 0, 9, 2, 0, 9, 6, 0], [128, 5, 0, 0, 3, 2, 8, 3, 3, 0], [31, 3, 0, 0, 5, 1, 35, 21, 15, 0], [83, 1, 0, 0, 8, 0, 0, 5, 8, 4], [35, 0, 0, 2, 5, 0, 3, 0, 7, 6], [122, 0, 0, 0, 18, 0, 1, 6, 5, 2]]
# [['-', 14.200000000000003, -5.299999999999997, 10.5, -21.69999999999999, -43.3, -42.0, 61.099999999999994, -0.09999999999999432, 4.200000000000003], [38, 9, 31, 4, 60, 27, 30, 56, 26, 0], [81, 0, 4, 0, 16, 0, 1, 40, 9, 2], [123, 5, 3, 0, 17, 35, 45, 7, 17, 2], [103, 1, 1, 9, 3, 0, 0, 2, 3, 0], [12, 0, 0, 0, 3, 23, 15, 0, 7, 0], [39, 0, 0, 0, 11, 5, 8, 8, 9, 0], [64, 0, 0, 0, 3, 2, 15, 15, 8, 0], [45, 0, 0, 0, 11, 1, 2, 3, 4, 5], [53, 5, 0, 7, 2, 0, 10, 0, 0, 0], [21, 4, 0, 0, 19, 0, 11, 3, 14, 3], [111, 0, 0, 3, 3, 0, 1, 0, 2, 6], [10, 0, 0, 1, 19, 0, 12, 14, 21, 13]]
# [['-', 8.200000000000003, -0.29999999999999716, -9.5, 6.300000000000011, -9.299999999999997, 42.0, -33.900000000000006, -13.099999999999994, 11.200000000000003], [60, 5, 20, 6, 42, 13, 19, 69, 26, 0], [14, 0, 5, 0, 3, 2, 2, 17, 9, 2], [65, 1, 4, 1, 3, 3, 3, 4, 6, 1], [116, 2, 4, 12, 37, 8, 13, 51, 27, 2], [67, 1, 1, 6, 4, 10, 2, 12, 5, 4], [68, 2, 0, 1, 2, 18, 1, 18, 12, 1], [20, 0, 0, 0, 7, 3, 7, 7, 6, 3], [70, 12, 0, 6, 15, 2, 5, 19, 12, 0], [74, 5, 0, 3, 9, 0, 0, 17, 15, 0], [100, 2, 0, 2, 6, 0, 0, 5, 4, 2], [69, 0, 0, 7, 0, 0, 4, 0, 8, 8], [110, 0, 0, 0, 11, 0, 10, 24, 3, 1]]
# [['-', 15.200000000000003, 0.7000000000000028, -2.5, -29.69999999999999, 15.700000000000003, 12.0, 36.099999999999994, -47.099999999999994, -55.8], [2, 5, 16, 12, 51, 4, 7, 40, 19, 1], [108, 0, 7, 0, 20, 5, 5, 43, 22, 16], [42, 2, 3, 0, 1, 0, 4, 2, 8, 4], [97, 0, 3, 0, 22, 9, 0, 6, 12, 8], [24, 0, 2, 0, 8, 0, 5, 8, 6, 0], [36, 3, 1, 1, 3, 0, 0, 3, 1, 2], [54, 1, 1, 1, 11, 4, 24, 11, 15, 2], [8, 10, 0, 5, 47, 12, 18, 57, 50, 5], [88, 2, 0, 13, 3, 0, 4, 0, 1, 0], [56, 0, 0, 4, 1, 0, 3, 2, 2, 11], [29, 0, 0, 1, 1, 0, 7, 0, 7, 6], [63, 0, 0, 0, 7, 0, 19, 1, 24, 36]]
# [['-', -22.799999999999997, 9.700000000000003, -23.5, -4.699999999999989, -16.299999999999997, -50.0, 53.099999999999994, 27.900000000000006, 10.200000000000003], [50, 14, 14, 5, 32, 26, 100, 22, 20, 7], [72, 0, 4, 9, 10, 3, 18, 6, 17, 0], [119, 0, 3, 0, 5, 0, 0, 22, 9, 11], [27, 19, 2, 0, 2, 26, 27, 4, 2, 1], [86, 1, 1, 0, 15, 1, 0, 42, 6, 2], [115, 1, 0, 2, 2, 6, 3, 4, 1, 0], [57, 6, 0, 1, 6, 3, 7, 38, 10, 0], [59, 0, 0, 0, 1, 1, 3, 9, 9, 0], [120, 16, 0, 1, 4, 0, 0, 3, 6, 0], [77, 4, 0, 40, 73, 0, 0, 6, 12, 4]]
# [['-', -44.8, -8.299999999999997, -0.5, 19.30000000000001, 9.700000000000003, 42.0, 3.0999999999999943, 0.9000000000000057, -11.799999999999997], [76, 1, 13, 1, 15, 0, 2, 26, 8, 3], [114, 25, 8, 0, 16, 11, 17, 39, 15, 0], [52, 0, 5, 0, 3, 0, 0, 9, 2, 9], [101, 0, 5, 0, 14, 1, 0, 5, 15, 4], [33, 1, 3, 0, 11, 0, 0, 19, 2, 7], [9, 0, 2, 1, 6, 0, 0, 4, 6, 1], [15, 0, 2, 10, 6, 0, 6, 2, 8, 7], [113, 0, 2, 5, 0, 0, 9, 3, 5, 0], [55, 0, 1, 2, 7, 4, 2, 1, 2, 0], [62, 1, 1, 0, 8, 4, 5, 18, 14, 2], [40, 2, 0, 0, 0, 12, 0, 33, 8, 0], [98, 1, 0, 0, 4, 3, 3, 10, 2, 0], [43, 0, 0, 0, 0, 2, 0, 5, 6, 1], [80, 2, 0, 0, 1, 2, 0, 9, 3, 0], [5, 48, 0, 4, 23, 1, 0, 4, 10, 0], [25, 2, 0, 8, 2, 0, 1, 3, 3, 7], [34, 0, 0, 3, 5, 0, 2, 3, 2, 2], [7, 0, 0, 1, 5, 0, 2, 11, 3, 3], [23, 0, 0, 0, 0, 0, 17, 2, 5, 1]]
# [['-', -13.799999999999997, -9.299999999999997, 2.5, 30.30000000000001, -12.299999999999997, 25.0, -51.900000000000006, 37.900000000000006, 9.200000000000003], [79, 0, 11, 0, 9, 1, 4, 10, 2, 0], [82, 0, 8, 0, 9, 2, 6, 20, 14, 2], [78, 5, 7, 0, 8, 7, 0, 39, 8, 0], [3, 1, 5, 0, 4, 0, 0, 1, 3, 2], [6, 1, 5, 4, 9, 4, 11, 12, 4, 2], [75, 2, 4, 0, 7, 21, 40, 39, 9, 3], [109, 30, 2, 1, 12, 3, 1, 27, 12, 0], [112, 8, 1, 20, 5, 23, 6, 80, 12, 0], [99, 2, 0, 0, 17, 1, 1, 18, 7, 3], [93, 3, 0, 1, 7, 0, 8, 14, 4, 2], [16, 0, 0, 6, 27, 0, 2, 1, 4, 11], [49, 0, 0, 0, 1, 0, 4, 0, 3, 1]]
# [['-', 17.200000000000003, 13.700000000000003, 11.5, -17.69999999999999, 12.700000000000003, -42.0, 13.099999999999994, -7.099999999999994, 11.200000000000003], [41, 5, 8, 12, 41, 18, 46, 49, 35, 16], [26, 5, 4, 10, 15, 0, 7, 19, 9, 0], [107, 3, 3, 0, 22, 1, 6, 10, 13, 2], [96, 1, 2, 0, 8, 0, 0, 7, 2, 0], [124, 0, 2, 1, 13, 2, 3, 17, 13, 0], [85, 1, 1, 0, 11, 3, 18, 20, 13, 1], [105, 0, 0, 0, 2, 8, 3, 17, 5, 2], [13, 0, 0, 0, 1, 2, 17, 9, 5, 0], [102, 0, 0, 0, 1, 2, 15, 11, 7, 1], [71, 1, 0, 0, 14, 1, 5, 18, 6, 1], [121, 4, 0, 0, 1, 0, 10, 5, 3, 0], [17, 1, 0, 0, 33, 0, 9, 14, 15, 1], [91, 0, 0, 0, 1, 0, 11, 0, 1, 0]]
# [['-', 7.200000000000003, -7.299999999999997, -15.5, 11.300000000000011, 12.700000000000003, 7.0, 23.099999999999994, -7.099999999999994, -9.799999999999997], [44, 1, 8, 1, 6, 0, 0, 24, 1, 11], [92, 0, 8, 0, 6, 0, 0, 18, 5, 1], [0, 6, 7, 7, 11, 3, 5, 25, 13, 1], [1, 0, 5, 13, 2, 0, 0, 21, 7, 11], [94, 4, 5, 1, 7, 0, 26, 5, 7, 3], [66, 0, 3, 0, 20, 3, 2, 20, 21, 3], [30, 0, 2, 0, 9, 0, 12, 12, 5, 0], [48, 0, 1, 0, 6, 0, 2, 4, 10, 7], [84, 1, 1, 0, 1, 10, 2, 6, 7, 2], [125, 3, 1, 0, 3, 10, 10, 4, 13, 1], [11, 9, 0, 7, 3, 6, 0, 20, 6, 0], [51, 1, 0, 10, 1, 2, 4, 0, 3, 0], [4, 2, 0, 3, 4, 1, 4, 0, 3, 0], [19, 1, 0, 0, 9, 1, 1, 0, 7, 1], [104, 0, 0, 4, 27, 1, 16, 1, 4, 1], [118, 3, 0, 1, 0, 0, 13, 15, 3, 2], [126, 0, 0, 3, 14, 0, 0, 4, 9, 0], [58, 0, 0, 0, 2, 0, 0, 5, 0, 0], [87, 0, 0, 0, 3, 0, 4, 2, 3, 1]]
# [['-', 19.200000000000003, 15.700000000000003, 15.5, 19.30000000000001, 20.700000000000003, 2.0, -105.9, 15.900000000000006, 13.200000000000003], [46, 2, 8, 7, 57, 7, 32, 56, 41, 7], [90, 0, 5, 0, 6, 1, 7, 43, 18, 1], [106, 1, 3, 0, 21, 0, 37, 18, 5, 0], [32, 0, 1, 0, 5, 0, 2, 8, 7, 4], [61, 15, 1, 1, 17, 21, 24, 173, 24, 7], [117, 1, 0, 0, 0, 0, 1, 0, 0, 0], [127, 0, 0, 11, 20, 0, 3, 17, 9, 3]]

# %%
len(sub_set[-1])
# Out:
# 8

# %%
# Iterando sobre cada subconjunto em sub_set
for idx, s_set in enumerate(sub_set):
    # Construindo o caminho do arquivo para o subconjunto, com extensão .txt
    file_path = f"../Base de Dados/HAREM/divisions/second/iterative/division_{idx}.txt"
    
    # Abrindo o arquivo para o subconjunto
    with open(file_path, 'w+', encoding='utf-8') as fp:
        # Iterando sobre cada documento no subconjunto, excluindo a linha de contagens (assumindo que está na posição 0)
        for set_doc in s_set[1:]:
            # Obter o nome do documento usando o índice do documento
            doc_name = list(data_por_sentenca_por_doc.keys())[set_doc[0]]
            doc_sentences = data_por_sentenca_por_doc[doc_name]

            # Escrever cada sentença do documento no arquivo
            for sentence in doc_sentences:
                for tk_class in sentence:
                    # Gravar cada elemento da sentença, com separador adequado
                    fp.write(config['col_sep'].join(map(str, tk_class)) + '\n')
                # Quebra de linha entre sentenças
                fp.write('\n')
    
    print(f"Subconjunto {idx} salvo com sucesso em {file_path}")
# Out:
# Subconjunto 0 salvo com sucesso em ../Base de Dados/HAREM/divisions/second/iterative/division_0.txt
# Subconjunto 1 salvo com sucesso em ../Base de Dados/HAREM/divisions/second/iterative/division_1.txt
# Subconjunto 2 salvo com sucesso em ../Base de Dados/HAREM/divisions/second/iterative/division_2.txt
# Subconjunto 3 salvo com sucesso em ../Base de Dados/HAREM/divisions/second/iterative/division_3.txt
# Subconjunto 4 salvo com sucesso em ../Base de Dados/HAREM/divisions/second/iterative/division_4.txt
# Subconjunto 5 salvo com sucesso em ../Base de Dados/HAREM/divisions/second/iterative/division_5.txt
# Subconjunto 6 salvo com sucesso em ../Base de Dados/HAREM/divisions/second/iterative/division_6.txt
# Subconjunto 7 salvo com sucesso em ../Base de Dados/HAREM/divisions/second/iterative/division_7.txt
# Subconjunto 8 salvo com sucesso em ../Base de Dados/HAREM/divisions/second/iterative/division_8.txt
# Subconjunto 9 salvo com sucesso em ../Base de Dados/HAREM/divisions/second/iterative/division_9.txt

# %%
import os
from collections import Counter
import matplotlib.pyplot as plt

# Diretório onde as partições estão salvas
base_dir = "../Base de Dados/HAREM/divisions/second/iterative/"

# Inicializando o dicionário para armazenar contagens de entidades por partição
qtd_classes_por_div = {}
total_entidades_por_div = {}

# Iterando sobre cada arquivo de partição
for file_name in sorted(os.listdir(base_dir)):
    partition_path = os.path.join(base_dir, file_name)

    # Verificar se é um arquivo (não um diretório) e se o nome do arquivo termina com '.txt'
    if os.path.isfile(partition_path) and file_name.endswith('.txt'):
        # Inicializando o contador para esta partição
        labels_count = Counter()

        # Lendo o arquivo da partição
        with open(partition_path, 'r', encoding='utf-8') as file:
            for line in file:
                line = line.strip()
                if line:  # Se a linha não estiver vazia
                    token_data = line.split()  # Separar os elementos da linha
                    label = token_data[-1]  # O rótulo é o último elemento

                    # Filtrar apenas os rótulos que começam com 'B-' e simplificar
                    if label.startswith("B-"):
                        simplified_label = label.split("-")[-1]  # Extrair a entidade (ex.: 'PER', 'LOC')
                        labels_count[simplified_label] += 1

        # Armazenar as contagens para a partição atual
        qtd_classes_por_div[file_name] = labels_count
        total_entidades_por_div[file_name] = sum(labels_count.values())

# Calculando o total geral de todas as partições
total_entidades_geral = sum(total_entidades_por_div.values())

# Exibindo os totais por partição e o total geral
print("Totais de entidades por partição:")
for div_name, total in total_entidades_por_div.items():
    print(f"  {div_name}: {total} entidades")

print(f"\nTotal geral de entidades em todas as partições: {total_entidades_geral} entidades\n")

# Gerando os gráficos para cada partição
for div_name, labels_count in qtd_classes_por_div.items():
    # Ordenar os rótulos alfabeticamente
    sorted_labels = sorted(labels_count.items())
    classes = [label for label, _ in sorted_labels]
    qtd = [count for _, count in sorted_labels]

    plt.figure(figsize=(10, 6))
    plt.barh(classes, qtd, color="pink")
    
    # Adicionando os valores nas barras
    for i, count in enumerate(qtd):
        plt.text(count, i, str(count), va="center_baseline", ha="right", fontsize=10)

    plt.title(f"Entities per Class in Partition: {div_name}", fontsize=15)
    plt.xlabel("Number of Entities", fontweight="bold", fontsize=12)
    plt.ylabel("Classes", fontweight="bold", fontsize=12)
    
    # Salvando o gráfico
    output_path = os.path.join(base_dir, f"entities_per_class_{div_name}.png")
    plt.savefig(output_path, dpi=300, format="png", bbox_inches="tight")
    
    print(f"Gráfico salvo: {output_path}")
    # Exibir o gráfico (opcional)
    # plt.show()

print("Todos os gráficos foram gerados e salvos com sucesso!")
# Out:
# Totais de entidades por partição:
#   division_0.txt: 766 entidades
#   division_1.txt: 813 entidades
#   division_2.txt: 778 entidades
#   division_3.txt: 848 entidades
#   division_4.txt: 797 entidades
#   division_5.txt: 769 entidades
#   division_6.txt: 758 entidades
#   division_7.txt: 767 entidades
#   division_8.txt: 758 entidades
#   division_9.txt: 763 entidades
#
# Total geral de entidades em todas as partições: 7817 entidades
#
# Gráfico salvo: ../Base de Dados/HAREM/divisions/second/iterative/entities_per_class_division_0.txt.png
# Gráfico salvo: ../Base de Dados/HAREM/divisions/second/iterative/entities_per_class_division_1.txt.png
# Gráfico salvo: ../Base de Dados/HAREM/divisions/second/iterative/entities_per_class_division_2.txt.png
# Gráfico salvo: ../Base de Dados/HAREM/divisions/second/iterative/entities_per_class_division_3.txt.png
# Gráfico salvo: ../Base de Dados/HAREM/divisions/second/iterative/entities_per_class_division_4.txt.png
# Gráfico salvo: ../Base de Dados/HAREM/divisions/second/iterative/entities_per_class_division_5.txt.png
# Gráfico salvo: ../Base de Dados/HAREM/divisions/second/iterative/entities_per_class_division_6.txt.png
# Gráfico salvo: ../Base de Dados/HAREM/divisions/second/iterative/entities_per_class_division_7.txt.png
# Gráfico salvo: ../Base de Dados/HAREM/divisions/second/iterative/entities_per_class_division_8.txt.png
# Gráfico salvo: ../Base de Dados/HAREM/divisions/second/iterative/entities_per_class_division_9.txt.png
# Todos os gráficos foram gerados e salvos com sucesso!
